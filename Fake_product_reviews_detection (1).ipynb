# %%
import tensorflow as tf
from tensorflow.keras.layers import LSTM, GRU, Dense, Embedding, Dropout,Bidirectional
from tensorflow.keras.preprocessing import text, sequence 
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
#for text cleaning
import string
import re
import nltk
nltk.download('all')
from nltk.tokenize import word_tokenize,sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import gensim
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

import tensorflow as tf
from tensorflow.keras.preprocessing import text, sequence
from tensorflow.keras.preprocessing.text import one_hot
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Dense, LSTM, Dropout, GRU
from tensorflow.keras.callbacks import History 

from wordcloud import WordCloud, STOPWORDS


#for visualization
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/abc.zip.
# [nltk_data]    | Downloading package alpino to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/alpino.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers/averaged_perceptron_tagger_ru.zip.
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/basque_grammars.zip.
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/biocreative_ppi.zip.
# [nltk_data]    | Downloading package bllip_wsj_no_aux to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping models/bllip_wsj_no_aux.zip.
# [nltk_data]    | Downloading package book_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/book_grammars.zip.
# [nltk_data]    | Downloading package brown to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/brown.zip.
# [nltk_data]    | Downloading package brown_tei to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/brown_tei.zip.
# [nltk_data]    | Downloading package cess_cat to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cess_cat.zip.
# [nltk_data]    | Downloading package cess_esp to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cess_esp.zip.
# [nltk_data]    | Downloading package chat80 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/chat80.zip.
# [nltk_data]    | Downloading package city_database to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/city_database.zip.
# [nltk_data]    | Downloading package cmudict to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cmudict.zip.
# [nltk_data]    | Downloading package comparative_sentences to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/comparative_sentences.zip.
# [nltk_data]    | Downloading package comtrans to /root/nltk_data...
# [nltk_data]    | Downloading package conll2000 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/conll2000.zip.
# [nltk_data]    | Downloading package conll2002 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/conll2002.zip.
# [nltk_data]    | Downloading package conll2007 to /root/nltk_data...
# [nltk_data]    | Downloading package crubadan to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/crubadan.zip.
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/dependency_treebank.zip.
# [nltk_data]    | Downloading package dolch to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/dolch.zip.
# [nltk_data]    | Downloading package europarl_raw to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/europarl_raw.zip.
# [nltk_data]    | Downloading package extended_omw to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package floresta to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/floresta.zip.
# [nltk_data]    | Downloading package framenet_v15 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/framenet_v15.zip.
# [nltk_data]    | Downloading package framenet_v17 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/framenet_v17.zip.
# [nltk_data]    | Downloading package gazetteers to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gazetteers.zip.
# [nltk_data]    | Downloading package genesis to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/genesis.zip.
# [nltk_data]    | Downloading package gutenberg to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gutenberg.zip.
# [nltk_data]    | Downloading package ieer to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/ieer.zip.
# [nltk_data]    | Downloading package inaugural to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/inaugural.zip.
# [nltk_data]    | Downloading package indian to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/indian.zip.
# [nltk_data]    | Downloading package jeita to /root/nltk_data...
# [nltk_data]    | Downloading package kimmo to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/kimmo.zip.
# [nltk_data]    | Downloading package knbc to /root/nltk_data...
# [nltk_data]    | Downloading package large_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/large_grammars.zip.
# [nltk_data]    | Downloading package lin_thesaurus to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/lin_thesaurus.zip.
# [nltk_data]    | Downloading package mac_morpho to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/mac_morpho.zip.
# [nltk_data]    | Downloading package machado to /root/nltk_data...
# [nltk_data]    | Downloading package masc_tagged to /root/nltk_data...
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping chunkers/maxent_ne_chunker.zip.
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/maxent_treebank_pos_tagger.zip.
# [nltk_data]    | Downloading package moses_sample to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping models/moses_sample.zip.
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/movie_reviews.zip.
# [nltk_data]    | Downloading package mte_teip5 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/mte_teip5.zip.
# [nltk_data]    | Downloading package mwa_ppdb to /root/nltk_data...
# [nltk_data]    |   Unzipping misc/mwa_ppdb.zip.
# [nltk_data]    | Downloading package names to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/names.zip.
# [nltk_data]    | Downloading package nombank.1.0 to /root/nltk_data...
# [nltk_data]    | Downloading package nonbreaking_prefixes to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/nonbreaking_prefixes.zip.
# [nltk_data]    | Downloading package nps_chat to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/nps_chat.zip.
# [nltk_data]    | Downloading package omw to /root/nltk_data...
# [nltk_data]    | Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]    | Downloading package opinion_lexicon to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/opinion_lexicon.zip.
# [nltk_data]    | Downloading package panlex_swadesh to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package paradigms to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/paradigms.zip.
# [nltk_data]    | Downloading package pe08 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/pe08.zip.
# [nltk_data]    | Downloading package perluniprops to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping misc/perluniprops.zip.
# [nltk_data]    | Downloading package pil to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/pil.zip.
# [nltk_data]    | Downloading package pl196x to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/pl196x.zip.
# [nltk_data]    | Downloading package porter_test to /root/nltk_data...
# [nltk_data]    |   Unzipping stemmers/porter_test.zip.
# [nltk_data]    | Downloading package ppattach to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/ppattach.zip.
# [nltk_data]    | Downloading package problem_reports to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/problem_reports.zip.
# [nltk_data]    | Downloading package product_reviews_1 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/product_reviews_1.zip.
# [nltk_data]    | Downloading package product_reviews_2 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/product_reviews_2.zip.
# [nltk_data]    | Downloading package propbank to /root/nltk_data...
# [nltk_data]    | Downloading package pros_cons to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/pros_cons.zip.
# [nltk_data]    | Downloading package ptb to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/ptb.zip.
# [nltk_data]    | Downloading package punkt to /root/nltk_data...
# [nltk_data]    |   Unzipping tokenizers/punkt.zip.
# [nltk_data]    | Downloading package qc to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/qc.zip.
# [nltk_data]    | Downloading package reuters to /root/nltk_data...
# [nltk_data]    | Downloading package rslp to /root/nltk_data...
# [nltk_data]    |   Unzipping stemmers/rslp.zip.
# [nltk_data]    | Downloading package rte to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/rte.zip.
# [nltk_data]    | Downloading package sample_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/sample_grammars.zip.
# [nltk_data]    | Downloading package semcor to /root/nltk_data...
# [nltk_data]    | Downloading package senseval to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/senseval.zip.
# [nltk_data]    | Downloading package sentence_polarity to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/sentence_polarity.zip.
# [nltk_data]    | Downloading package sentiwordnet to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/sentiwordnet.zip.
# [nltk_data]    | Downloading package shakespeare to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/shakespeare.zip.
# [nltk_data]    | Downloading package sinica_treebank to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/sinica_treebank.zip.
# [nltk_data]    | Downloading package smultron to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/smultron.zip.
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package spanish_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/spanish_grammars.zip.
# [nltk_data]    | Downloading package state_union to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/state_union.zip.
# [nltk_data]    | Downloading package stopwords to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/stopwords.zip.
# [nltk_data]    | Downloading package subjectivity to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/subjectivity.zip.
# [nltk_data]    | Downloading package swadesh to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/swadesh.zip.
# [nltk_data]    | Downloading package switchboard to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/switchboard.zip.
# [nltk_data]    | Downloading package tagsets to /root/nltk_data...
# [nltk_data]    |   Unzipping help/tagsets.zip.
# [nltk_data]    | Downloading package timit to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/timit.zip.
# [nltk_data]    | Downloading package toolbox to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/toolbox.zip.
# [nltk_data]    | Downloading package treebank to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/treebank.zip.
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/twitter_samples.zip.
# [nltk_data]    | Downloading package udhr to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/udhr.zip.
# [nltk_data]    | Downloading package udhr2 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/udhr2.zip.
# [nltk_data]    | Downloading package unicode_samples to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/unicode_samples.zip.
# [nltk_data]    | Downloading package universal_tagset to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/universal_tagset.zip.
# [nltk_data]    | Downloading package universal_treebanks_v20 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package vader_lexicon to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package verbnet to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/verbnet.zip.
# [nltk_data]    | Downloading package verbnet3 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/verbnet3.zip.
# [nltk_data]    | Downloading package webtext to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/webtext.zip.
# [nltk_data]    | Downloading package wmt15_eval to /root/nltk_data...
# [nltk_data]    |   Unzipping models/wmt15_eval.zip.
# [nltk_data]    | Downloading package word2vec_sample to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping models/word2vec_sample.zip.
# [nltk_data]    | Downloading package wordnet to /root/nltk_data...
# [nltk_data]    | Downloading package wordnet2021 to /root/nltk_data...
# [nltk_data]    | Downloading package wordnet31 to /root/nltk_data...
# [nltk_data]    | Downloading package wordnet_ic to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/wordnet_ic.zip.
# [nltk_data]    | Downloading package words to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/words.zip.
# [nltk_data]    | Downloading package ycoe to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/ycoe.zip.
# [nltk_data]    |
# [nltk_data]  Done downloading collection all

# %%
# %%time
reviews_data= pd.read_csv("/content/sample_data/fake reviews dataset.csv")
# Out:
# CPU times: user 148 ms, sys: 73.9 ms, total: 222 ms
# Wall time: 227 ms

# %%
reviews_data.head()
# Out:
#              category  rating label  \
# 0  Home_and_Kitchen_5     5.0    CG
# 1  Home_and_Kitchen_5     5.0    CG
# 2  Home_and_Kitchen_5     5.0    CG
# 3  Home_and_Kitchen_5     1.0    CG
# 4  Home_and_Kitchen_5     5.0    CG
#
#                                                text_
# 0  Love this!  Well made, sturdy, and very comfor...
# 1  love it, a great upgrade from the original.  I...
# 2  This pillow saved my back. I love the look and...
# 3  Missing information on how to use it, but it i...
# 4  Very nice set. Good quality. We have had the s...

# %%
reviews_data.shape
# Out:
# (40432, 4)

# %%
reviews_data.describe()
# Out:
#              rating
# count  40432.000000
# mean       4.256579
# std        1.144354
# min        1.000000
# 25%        4.000000
# 50%        5.000000
# 75%        5.000000
# max        5.000000

# %%
reviews_data.label.value_counts()
# Out:
# CG    20216
# OR    20216
# Name: label, dtype: int64

# %%
reviews_data.isna().sum()
# Out:
# category    0
# rating      0
# label       0
# text_       0
# dtype: int64

# %%
reviews_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40432 entries, 0 to 40431
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   category  40432 non-null  object
#  1   rating    40432 non-null  float64
#  2   label     40432 non-null  object
#  3   text_     40432 non-null  object
# dtypes: float64(1), object(3)
# memory usage: 1.2+ MB

# %%
reviews_data.rating.value_counts()
# Out:
# 5.0    24559
# 4.0     7965
# 3.0     3786
# 1.0     2155
# 2.0     1967
# Name: rating, dtype: int64

# %%
plt.figure(figsize=(15,8))
labels = reviews_data['rating'].value_counts().keys()
values = reviews_data['rating'].value_counts().values
plt.pie(values,labels=labels,shadow=True,autopct='%1.1f%%')
plt.title('Review rating proportion',fontweight='bold',fontsize=25,pad=20,color='crimson')
plt.show()

# %%
reviews_data.label = reviews_data.label.map(dict(CG=0, OR=1))

# %%
import seaborn as sns
fig = sns.countplot(x="label",data=reviews_data)
fig

# %%
plt.figure(figsize=(10,5))
sns.countplot(x= "rating", hue = "label", data=reviews_data)

# %% [markdown]
# #Text Preprocessing

# %%
# %%time
def clean_text(txt):
    """""
    cleans the input text in the following steps
    1- replace contractions
    2- removing punctuation
    3- spliting into words
    4- removing stopwords
    5- removing leftover punctuations
    """""
    contraction_dict = {"ain't": "is not", "aren't": "are not","can't": "cannot", "'cause": "because", "could've": "could have", "couldn't": "could not", "didn't": "did not",  "doesn't": "does not", "don't": "do not", "hadn't": "had not", "hasn't": "has not", "haven't": "have not", "he'd": "he would","he'll": "he will", "he's": "he is", "how'd": "how did", "how'd'y": "how do you", "how'll": "how will", "how's": "how is",  "I'd": "I would", "I'd've": "I would have", "I'll": "I will", "I'll've": "I will have","I'm": "I am", "I've": "I have", "i'd": "i would", "i'd've": "i would have", "i'll": "i will",  "i'll've": "i will have","i'm": "i am", "i've": "i have", "isn't": "is not", "it'd": "it would", "it'd've": "it would have", "it'll": "it will", "it'll've": "it will have","it's": "it is", "let's": "let us", "ma'am": "madam", "mayn't": "may not", "might've": "might have","mightn't": "might not","mightn't've": "might not have", "must've": "must have", "mustn't": "must not", "mustn't've": "must not have", "needn't": "need not", "needn't've": "need not have","o'clock": "of the clock", "oughtn't": "ought not", "oughtn't've": "ought not have", "shan't": "shall not", "sha'n't": "shall not", "shan't've": "shall not have", "she'd": "she would", "she'd've": "she would have", "she'll": "she will", "she'll've": "she will have", "she's": "she is", "should've": "should have", "shouldn't": "should not", "shouldn't've": "should not have", "so've": "so have","so's": "so as", "this's": "this is","that'd": "that would", "that'd've": "that would have", "that's": "that is", "there'd": "there would", "there'd've": "there would have", "there's": "there is", "here's": "here is","they'd": "they would", "they'd've": "they would have", "they'll": "they will", "they'll've": "they will have", "they're": "they are", "they've": "they have", "to've": "to have", "wasn't": "was not", "we'd": "we would", "we'd've": "we would have", "we'll": "we will", "we'll've": "we will have", "we're": "we are", "we've": "we have", "weren't": "were not", "what'll": "what will", "what'll've": "what will have", "what're": "what are",  "what's": "what is", "what've": "what have", "when's": "when is", "when've": "when have", "where'd": "where did", "where's": "where is", "where've": "where have", "who'll": "who will", "who'll've": "who will have", "who's": "who is", "who've": "who have", "why's": "why is", "why've": "why have", "will've": "will have", "won't": "will not", "won't've": "will not have", "would've": "would have", "wouldn't": "would not", "wouldn't've": "would not have", "y'all": "you all", "y'all'd": "you all would","y'all'd've": "you all would have","y'all're": "you all are","y'all've": "you all have","you'd": "you would", "you'd've": "you would have", "you'll": "you will", "you'll've": "you will have", "you're": "you are", "you've": "you have"}
    def _get_contractions(contraction_dict):
        contraction_re = re.compile('(%s)' % '|'.join(contraction_dict.keys()))
        return contraction_dict, contraction_re

    def replace_contractions(text):
        contractions, contractions_re = _get_contractions(contraction_dict)
        def replace(match):
            return contractions[match.group(0)]
        return contractions_re.sub(replace, text)

    # replace contractions and convert to lowercase
    txt = txt.lower()
    txt = replace_contractions(txt)
    
    #remove punctuations
    txt  = "".join([char for char in txt if char not in string.punctuation])
    txt = re.sub('[0-9]+', '', txt)
    
    # split into words
    words = word_tokenize(txt)
    
    # remove stopwords
    stop_words = set(stopwords.words('english'))
    words = [w for w in words if not w in stop_words]
    
    # removing leftover punctuations
    words = [word for word in words if word.isalpha()]

    lemmatizer = nltk.stem.WordNetLemmatizer()
    def lemmatize_text(txt):
        return [lemmatizer.lemmatize(w) for w in words]

    cleaned_text = ' '.join(words)
    return cleaned_text
    
reviews_data['text_'] = reviews_data['text_'].apply(lambda txt: clean_text(txt))
# Out:
# CPU times: user 24.5 s, sys: 785 ms, total: 25.2 s
# Wall time: 25.3 s

# %%
reviews_data.text_.head(1)
# Out:
# 0    love well made sturdy comfortable love itvery ...
# Name: text_, dtype: object

# %%
type(reviews_data.text_)
# Out:
# pandas.core.series.Series

# %%
reviews_data['text_'] = reviews_data['text_'].astype(str)

# %%
#Real words highlight
plt.figure(figsize=(15,15))
wc=WordCloud(max_words=2000, width=1600, height=700, stopwords=STOPWORDS).generate("".join(reviews_data[reviews_data.label==1].text_))
plt.imshow(wc, interpolation="bilinear")

# %%
#Fake words highlight
plt.figure(figsize=(15,15))
wc=WordCloud(max_words=2000, width=1600, height=700, stopwords=STOPWORDS).generate("".join(reviews_data[reviews_data.label==0].text_))
plt.imshow(wc, interpolation="bilinear")

# %%
X= [d.split() for d in reviews_data['text_'].to_list()]
print(X[0])
# Out:
# ['love', 'well', 'made', 'sturdy', 'comfortable', 'love', 'itvery', 'pretty']

# %%
print(len(X))
# Out:
# 40432

# %%
DIM=100
w2v_model = gensim.models.Word2Vec(sentences = X, size = DIM, window =4,min_count=1)

# %%
len(w2v_model.wv.vocab)
# Out:
# 48177

# %%
w2v_model['recommend']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """Entry point for launching an IPython kernel.
# array([-0.94409263, -2.2435334 , -0.83782595, -1.7853155 ,  3.421669  ,
#        -0.02830799, -1.0208348 , -2.2588592 ,  0.16240402, -2.020514  ,
#        -1.2670081 ,  0.4393603 , -0.38757816,  1.4769443 , -1.2632567 ,
#         1.5543505 ,  1.2811842 ,  1.797962  ,  0.8056965 , -0.917469  ,
#        -0.05928653, -1.1503613 ,  0.2805878 , -1.3951883 ,  0.56356615,
#        -1.0968035 , -0.07473684, -2.619564  , -2.5676246 ,  1.5350245 ,
#        -1.0733614 ,  2.7650745 , -1.0353765 , -0.6257014 ,  2.4529002 ,
#        -1.8375633 , -1.4266475 ,  1.6633477 , -1.6249322 , -0.24563953,
#         0.41211367,  2.5526137 ,  0.89021164, -1.9929891 ,  0.26140568,
#        -0.37117216, -1.1031588 ,  4.290114  , -0.08724394,  2.3733544 ,
#         0.87189794, -2.145255  ,  1.3801899 , -1.462824  , -0.7781026 ,
#         0.30637008,  0.685702  ,  0.96788216,  0.64808595,  0.6301396 ,
#        -1.2114671 ,  3.1436214 ,  3.9330914 , -3.1927147 , -0.3981869 ,
#         1.2659292 ,  0.7136223 , -0.45914888, -2.0893888 ,  0.5682668 ,
#         2.3869116 , -0.17572457, -3.6711662 ,  1.9543669 ,  1.624489  ,
#        -2.0284057 , -0.438696  ,  0.5786093 ,  0.3447733 , -0.7862948 ,
#        -0.9102504 , -1.7580675 , -0.23304468,  0.46314996, -0.46054   ,
#         1.7657816 ,  0.7742417 ,  0.4523943 ,  0.17689462,  0.4587402 ,
#         1.1349095 ,  1.8103852 , -2.0709455 , -0.374455  , -0.34147748,
#         0.40231025, -0.56323564, -1.4203337 ,  3.240762  ,  1.7963595 ],
#       dtype=float32)

# %%
w2v_model['well']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """Entry point for launching an IPython kernel.
# array([ 0.34186417,  0.00758959,  0.8443086 , -0.8663829 ,  0.52505517,
#         0.94314504,  1.0865595 , -1.4079441 , -3.313089  , -0.6668592 ,
#         0.24410945, -0.9291286 ,  0.11172088, -0.674333  , -1.6453091 ,
#         1.7267793 , -0.55293924,  1.1694062 ,  0.39642233, -0.46398455,
#        -1.5959232 , -0.54476684, -0.40148756, -1.3607438 ,  0.1674885 ,
#        -1.1035709 , -1.4580891 , -0.19830658, -0.0817371 , -0.14606419,
#        -2.4739661 ,  1.935322  , -0.8102244 ,  1.1864399 , -0.07989155,
#         2.3581104 , -1.325584  , -0.45717806, -2.8739421 , -0.17350425,
#         0.7228677 ,  1.1357214 ,  1.5411433 , -1.5926542 ,  0.44423264,
#         0.27933845,  1.1434466 ,  1.1183498 ,  0.5276343 ,  0.5996679 ,
#         1.8312662 , -0.1980265 ,  0.95519775,  0.4665372 , -1.3259705 ,
#        -1.1952578 , -0.1867969 , -0.11342087,  0.6190812 ,  1.1147217 ,
#        -0.6576663 ,  1.3997562 ,  0.49127138,  0.44724026, -0.24648191,
#         0.09494364,  1.0002891 , -2.1681426 , -0.63719857, -1.0313908 ,
#        -0.59386927,  1.9617765 , -2.841481  , -0.29850352,  0.77551997,
#        -0.12086265,  0.15352553, -0.71975315,  0.9923125 ,  0.12337201,
#        -1.0443615 , -0.137293  ,  1.5014201 ,  1.1401187 , -1.2723651 ,
#        -0.4216688 ,  1.4264094 ,  0.6010676 ,  0.7160295 , -1.0040481 ,
#         1.3809991 , -0.27054015, -0.3382872 ,  1.1184175 ,  0.9242348 ,
#        -0.3709159 , -1.6186918 , -1.2341958 ,  1.787551  , -0.62101114],
#       dtype=float32)

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
tokenizer=Tokenizer()
tokenizer.fit_on_texts(X)
X=tokenizer.texts_to_sequences(X)
X
# Out:
# [[6, 7, 31, 113, 48, 6, 1297, 72],
#  [6, 1, 1948, 339, 548, 100, 86],
#  [654, 1740, 73, 6, 76, 95, 654],
#  [951, 572, 16, 1, 26, 42],
#  [20, 65, 3, 28, 65, 34, 180],
#  [154, 105, 3748],
#  [46, 616, 75, 118, 11, 450],
#  [265, 37, 7, 76, 1, 6, 9469, 1752, 287],
#  [1, 90, 2270, 21, 10, 75, 9, 25],
#  [98, 24, 5241, 7, 31, 18, 527],
#  [682, 877, 4, 84, 15],
#  [878, 4, 175, 499, 550, 915, 4],
#  [460, 91, 12849, 1, 26],
#  [869, 28, 5, 492, 314, 1684],
#  [159, 268, 1102, 11358, 84, 273, 78, 40],
#  [260, 1158, 120, 42, 822, 190, 180],
#  [6, 46, 25, 555, 14869, 3, 28],
#  [76, 224, 20, 84, 15, 1346, 4],
#  [350, 5, 492, 6, 76, 95, 654],
#  [127, 5, 107, 13, 238, 6, 1599],
#  [1, 11, 3115, 14870, 180],
#  [682, 21, 16, 6, 295, 18, 1894],
#  [350, 2082, 6, 76, 95, 654],
#  [558, 154, 6, 76, 95, 654],
#  [757, 189, 287, 1552, 84, 15, 879],
#  [21, 16, 162, 21, 36, 56, 5089, 22, 329],
#  [7345, 131, 193, 127],
#  [20, 26, 853, 580, 234, 63, 314, 203, 271],
#  [3, 17, 163, 65, 76, 9, 29, 4, 79],
#  [303, 8804, 1079, 208, 84, 273, 78, 40],
#  [110, 23, 841, 6, 76, 292, 298],
#  [350, 59, 243, 2084, 2960, 3757, 1675],
#  [3, 207, 5, 2760, 2921, 271, 711, 148, 4],
#  ...]

# %%
tokenizer.word_index
# Out:
# {'great': 1,
#  'book': 2,
#  'good': 3,
#  'one': 4,
#  'would': 5,
#  'love': 6,
#  'well': 7,
#  'story': 8,
#  'like': 9,
#  'read': 10,
#  'little': 11,
#  'get': 12,
#  'recommend': 13,
#  'characters': 14,
#  'really': 15,
#  'use': 16,
#  'bought': 17,
#  'also': 18,
#  'movie': 19,
#  'nice': 20,
#  'easy': 21,
#  'small': 22,
#  'time': 23,
#  'loves': 24,
#  'size': 25,
#  'product': 26,
#  'bit': 27,
#  'quality': 28,
#  'first': 29,
#  'lot': 30,
#  'made': 31,
#  'series': 32,
#  'used': 33,
#  'two': 34,
#  'much': 35,
#  'way': 36,
#  'fit': 37,
#  'loved': 38,
#  'works': 39,
#  'put': 40,
#  'work': 41,
#  'price': 42,
#  'still': 43,
#  'could': 44,
#  'light': 45,
#  'perfect': 46,
#  'dog': 47,
#  'comfortable': 48,
#  'see': 49,
#  'long': 50,
#  'enjoyed': 51,
#  'think': 52,
#  'old': 53,
#  'happy': 54,
#  'keep': 55,
#  'make': 56,
#  'anyone': 57,
#  'author': 58,
#  'looking': 59,
#  'reading': 60,
#  'got': 61,
#  'best': 62,
#  'plastic': 63,
#  'buy': 64,
#  'set': 65,
#  'better': 66,
#  'next': 67,
#  'go': 68,
#  'liked': 69,
#  'want': 70,
#  'even': 71,
#  'pretty': 72,
#  'back': 73,
#  'books': 74,
#  'thing': 75,
#  'look': 76,
#  'know': 77,
#  'hard': 78,
#  'sure': 79,
#  'using': 80,
#  'enough': 81,
#  'year': 82,
#  'going': 83,
#  'problem': 84,
#  'large': 85,
#  'years': 86,
#  'new': 87,
#  'fun': 88,
#  'definitely': 89,
#  'big': 90,
#  'say': 91,
#  'review': 92,
#  'last': 93,
#  'find': 94,
#  'feel': 95,
#  'strong': 96,
#  'written': 97,
#  'son': 98,
#  'another': 99,
#  'couple': 100,
#  'fan': 101,
#  'around': 102,
#  'thought': 103,
#  'need': 104,
#  'different': 105,
#  'many': 106,
#  'highly': 107,
#  'found': 108,
#  'interesting': 109,
#  'received': 110,
#  'wear': 111,
#  'right': 112,
#  'sturdy': 113,
#  'people': 114,
#  'toy': 115,
#  'top': 116,
#  'part': 117,
#  'wish': 118,
#  'ordered': 119,
#  'excellent': 120,
#  'life': 121,
#  'fact': 122,
#  'color': 123,
#  'never': 124,
#  'take': 125,
#  'day': 126,
#  'stars': 127,
#  'acting': 128,
#  'film': 129,
#  'replace': 130,
#  'reason': 131,
#  'things': 132,
#  'wait': 133,
#  'play': 134,
#  'case': 135,
#  'ending': 136,
#  'daughter': 137,
#  'fits': 138,
#  'bag': 139,
#  'looks': 140,
#  'dogs': 141,
#  'since': 142,
#  'pieces': 143,
#  'water': 144,
#  'able': 145,
#  'box': 146,
#  'perfectly': 147,
#  'purchase': 148,
#  'material': 149,
#  'every': 150,
#  'give': 151,
#  'watch': 152,
#  'purchased': 153,
#  'wanted': 154,
#  'developed': 155,
#  'together': 156,
#  'worth': 157,
#  'times': 158,
#  'makes': 159,
#  'bad': 160,
#  'honest': 161,
#  'seems': 162,
#  'second': 163,
#  'always': 164,
#  'sound': 165,
#  'ever': 166,
#  'food': 167,
#  'bright': 168,
#  'soft': 169,
#  'forward': 170,
#  'end': 171,
#  'pair': 172,
#  'fine': 173,
#  'hold': 174,
#  'kids': 175,
#  'plot': 176,
#  'something': 177,
#  'real': 178,
#  'short': 179,
#  'months': 180,
#  'family': 181,
#  'getting': 182,
#  'without': 183,
#  'though': 184,
#  'line': 185,
#  'comes': 186,
#  'game': 187,
#  'friend': 188,
#  'come': 189,
#  'ones': 190,
#  'job': 191,
#  'told': 192,
#  'gave': 193,
#  'clean': 194,
#  'cute': 195,
#  'pleased': 196,
#  'cat': 197,
#  'solid': 198,
#  'far': 199,
#  'must': 200,
#  'man': 201,
#  'money': 202,
#  'however': 203,
#  'wide': 204,
#  'saw': 205,
#  'gift': 206,
#  'expected': 207,
#  'house': 208,
#  'came': 209,
#  'issues': 210,
#  'several': 211,
#  'action': 212,
#  'place': 213,
#  'quite': 214,
#  'world': 215,
#  'room': 216,
#  'smaller': 217,
#  'tried': 218,
#  'exchange': 219,
#  'character': 220,
#  'glad': 221,
#  'worked': 222,
#  'cover': 223,
#  'beautiful': 224,
#  'shoes': 225,
#  'writing': 226,
#  'order': 227,
#  'kept': 228,
#  'yet': 229,
#  'us': 230,
#  'amazing': 231,
#  'needed': 232,
#  'try': 233,
#  'thin': 234,
#  'young': 235,
#  'disappointed': 236,
#  'side': 237,
#  'item': 238,
#  'enjoy': 239,
#  'favorite': 240,
#  'woman': 241,
#  'problems': 242,
#  'easily': 243,
#  'cats': 244,
#  'buying': 245,
#  'actually': 246,
#  'difficult': 247,
#  'days': 248,
#  'working': 249,
#  'full': 250,
#  'tight': 251,
#  'show': 252,
#  'deal': 253,
#  'away': 254,
#  'overall': 255,
#  'main': 256,
#  'christmas': 257,
#  'design': 258,
#  'high': 259,
#  'absolutely': 260,
#  'free': 261,
#  'probably': 262,
#  'head': 263,
#  'huge': 264,
#  'done': 265,
#  'home': 266,
#  'tool': 267,
#  'may': 268,
#  'awesome': 269,
#  'battery': 270,
#  'handle': 271,
#  'camera': 272,
#  'kind': 273,
#  'front': 274,
#  'amazon': 275,
#  'bottom': 276,
#  'turn': 277,
#  'heavy': 278,
#  'everything': 279,
#  'history': 280,
#  'hot': 281,
#  'reviews': 282,
#  'said': 283,
#  'larger': 284,
#  'took': 285,
#  'three': 286,
#  'extra': 287,
#  'takes': 288,
#  'parts': 289,
#  'clear': 290,
#  'anything': 291,
#  'husband': 292,
#  'seen': 293,
#  'night': 294,
#  'colors': 295,
#  'fast': 296,
#  'help': 297,
#  'likes': 298,
#  'update': 299,
#  'hope': 300,
#  'gets': 301,
#  'tv': 302,
#  'wonderful': 303,
#  'picture': 304,
#  'less': 305,
#  'idea': 306,
#  'almost': 307,
#  'movies': 308,
#  'addition': 309,
#  'others': 310,
#  'simple': 311,
#  'super': 312,
#  'whole': 313,
#  'piece': 314,
#  'might': 315,
#  'longer': 316,
#  'durable': 317,
#  'open': 318,
#  'weight': 319,
#  'blade': 320,
#  'seem': 321,
#  'quick': 322,
#  'especially': 323,
#  'stories': 324,
#  'girl': 325,
#  'hand': 326,
#  'start': 327,
#  'felt': 328,
#  'person': 329,
#  'knife': 330,
#  'needs': 331,
#  'past': 332,
#  'change': 333,
#  'bulb': 334,
#  'cheap': 335,
#  'romance': 336,
#  'value': 337,
#  'car': 338,
#  'original': 339,
#  'trying': 340,
#  'point': 341,
#  'instructions': 342,
#  'style': 343,
#  'version': 344,
#  'copy': 345,
#  'nothing': 346,
#  'unit': 347,
#  'holds': 348,
#  'power': 349,
#  'exactly': 350,
#  'install': 351,
#  'mystery': 352,
#  'let': 353,
#  'excited': 354,
#  'ok': 355,
#  'month': 356,
#  'thick': 357,
#  'hours': 358,
#  'funny': 359,
#  'phone': 360,
#  'kitchen': 361,
#  'given': 362,
#  'materials': 363,
#  'shoe': 364,
#  'feet': 365,
#  'store': 366,
#  'went': 367,
#  'wife': 368,
#  'bed': 369,
#  'cable': 370,
#  'star': 371,
#  'inside': 372,
#  'left': 373,
#  'carry': 374,
#  'novel': 375,
#  'drive': 376,
#  'tell': 377,
#  'friends': 378,
#  'wants': 379,
#  'true': 380,
#  'music': 381,
#  'interested': 382,
#  'expensive': 383,
#  'goes': 384,
#  'already': 385,
#  'run': 386,
#  'dvd': 387,
#  'slow': 388,
#  'white': 389,
#  'half': 390,
#  'guy': 391,
#  'arrived': 392,
#  'black': 393,
#  'started': 394,
#  'weeks': 395,
#  'finish': 396,
#  'special': 397,
#  'keeps': 398,
#  'quickly': 399,
#  'stuff': 400,
#  'iti': 401,
#  'lights': 402,
#  'making': 403,
#  'cut': 404,
#  'sweet': 405,
#  'lens': 406,
#  'wearing': 407,
#  'issue': 408,
#  'lots': 409,
#  'ago': 410,
#  'although': 411,
#  'foot': 412,
#  'reader': 413,
#  'child': 414,
#  'mind': 415,
#  'medium': 416,
#  'understand': 417,
#  'hands': 418,
#  'lives': 419,
#  'broken': 420,
#  'entertaining': 421,
#  'older': 422,
#  'door': 423,
#  'dress': 424,
#  'beginning': 425,
#  'maybe': 426,
#  'warm': 427,
#  'collection': 428,
#  'return': 429,
#  'along': 430,
#  'third': 431,
#  'stay': 432,
#  'instead': 433,
#  'screen': 434,
#  'admit': 435,
#  'believable': 436,
#  'everyone': 437,
#  'decided': 438,
#  'wrong': 439,
#  'minutes': 440,
#  'heart': 441,
#  'feels': 442,
#  'replacement': 443,
#  'loose': 444,
#  'middle': 445,
#  'cool': 446,
#  'finally': 447,
#  'watching': 448,
#  'cup': 449,
#  'space': 450,
#  'brand': 451,
#  'lost': 452,
#  'close': 453,
#  'coffee': 454,
#  'least': 455,
#  'playing': 456,
#  'ring': 457,
#  'batteries': 458,
#  'area': 459,
#  'someone': 460,
#  'low': 461,
#  'rather': 462,
#  'dark': 463,
#  'learn': 464,
#  'add': 465,
#  'seemed': 466,
#  'happens': 467,
#  'litter': 468,
#  'else': 469,
#  'cold': 470,
#  'bike': 471,
#  'screw': 472,
#  'usually': 473,
#  'metal': 474,
#  'children': 475,
#  'easier': 476,
#  'bigger': 477,
#  'impressed': 478,
#  'believe': 479,
#  'move': 480,
#  'computer': 481,
#  'week': 482,
#  'type': 483,
#  'either': 484,
#  'regular': 485,
#  'care': 486,
#  'turns': 487,
#  'pack': 488,
#  'ended': 489,
#  'often': 490,
#  'pocket': 491,
#  'expect': 492,
#  'toys': 493,
#  'rest': 494,
#  'says': 495,
#  'war': 496,
#  'usb': 497,
#  'figure': 498,
#  'tools': 499,
#  'relationship': 500,
#  'lid': 501,
#  'installed': 502,
#  'switch': 503,
#  'amount': 504,
#  'running': 505,
#  'fabric': 506,
#  'eat': 507,
#  'surprised': 508,
#  'sharp': 509,
#  'stand': 510,
#  'scenes': 511,
#  'guess': 512,
#  'puppy': 513,
#  'wall': 514,
#  'shirt': 515,
#  'live': 516,
#  'adjustable': 517,
#  'name': 518,
#  'control': 519,
#  'model': 520,
#  'effects': 521,
#  'etc': 522,
#  'setting': 523,
#  'nicely': 524,
#  'length': 525,
#  'okay': 526,
#  'baby': 527,
#  'button': 528,
#  'products': 529,
#  'uses': 530,
#  'four': 531,
#  'shows': 532,
#  'break': 533,
#  'follow': 534,
#  'pull': 535,
#  'hit': 536,
#  'ipad': 537,
#  'future': 538,
#  'lbs': 539,
#  'birthday': 540,
#  'ear': 541,
#  'support': 542,
#  'sometimes': 543,
#  'town': 544,
#  'plays': 545,
#  'led': 546,
#  'held': 547,
#  'mine': 548,
#  'built': 549,
#  'included': 550,
#  'season': 551,
#  'shape': 552,
#  'device': 553,
#  'collar': 554,
#  'entire': 555,
#  'predictable': 556,
#  'fall': 557,
#  'fantastic': 558,
#  'company': 559,
#  'air': 560,
#  'leave': 561,
#  'hoping': 562,
#  'strap': 563,
#  'storyline': 564,
#  'course': 565,
#  'dry': 566,
#  'watched': 567,
#  'system': 568,
#  'kit': 569,
#  'gives': 570,
#  'plus': 571,
#  'information': 572,
#  'single': 573,
#  'treats': 574,
#  'broke': 575,
#  'outside': 576,
#  'enjoys': 577,
#  'completely': 578,
#  'enjoyable': 579,
#  'yes': 580,
#  'floor': 581,
#  'extremely': 582,
#  'similar': 583,
#  'feature': 584,
#  'thinking': 585,
#  'ball': 586,
#  'father': 587,
#  'charge': 588,
#  'gun': 589,
#  'x': 590,
#  'important': 591,
#  'edge': 592,
#  'laptop': 593,
#  'shipping': 594,
#  'lightweight': 595,
#  'recommended': 596,
#  'grip': 597,
#  'become': 598,
#  'smell': 599,
#  'standard': 600,
#  'giving': 601,
#  'experience': 602,
#  'authors': 603,
#  'bathroom': 604,
#  'mount': 605,
#  'cost': 606,
#  'compact': 607,
#  'women': 608,
#  'heroine': 609,
#  'speaker': 610,
#  'living': 611,
#  'complaint': 612,
#  'tall': 613,
#  'interest': 614,
#  'items': 615,
#  'touch': 616,
#  'level': 617,
#  'taking': 618,
#  'coming': 619,
#  'twists': 620,
#  'keyboard': 621,
#  'blue': 622,
#  'designed': 623,
#  'keeping': 624,
#  'bulbs': 625,
#  'school': 626,
#  'based': 627,
#  'purchasing': 628,
#  'replaced': 629,
#  'pictures': 630,
#  'soon': 631,
#  'seat': 632,
#  'slightly': 633,
#  'putting': 634,
#  'downside': 635,
#  'pain': 636,
#  'harness': 637,
#  'notch': 638,
#  'sense': 639,
#  'helps': 640,
#  'within': 641,
#  'bottle': 642,
#  'played': 643,
#  'range': 644,
#  'bosch': 645,
#  'shower': 646,
#  'filter': 647,
#  'straps': 648,
#  'boy': 649,
#  'apart': 650,
#  'treat': 651,
#  'difference': 652,
#  'socks': 653,
#  'pillow': 654,
#  'trip': 655,
#  'thank': 656,
#  'described': 657,
#  'trouble': 658,
#  'video': 659,
#  'boring': 660,
#  'onei': 661,
#  'truly': 662,
#  'holding': 663,
#  'charger': 664,
#  'later': 665,
#  'wood': 666,
#  'inch': 667,
#  'looked': 668,
#  'mix': 669,
#  'sitting': 670,
#  'professional': 671,
#  'view': 672,
#  'eyes': 673,
#  'basic': 674,
#  'boots': 675,
#  'turned': 676,
#  'blades': 677,
#  'starts': 678,
#  'mother': 679,
#  'decent': 680,
#  'matter': 681,
#  'advertised': 682,
#  'red': 683,
#  'kid': 684,
#  'chance': 685,
#  'continue': 686,
#  'body': 687,
#  'remove': 688,
#  'card': 689,
#  'owned': 690,
#  'worn': 691,
#  'hair': 692,
#  'loud': 693,
#  'words': 694,
#  'opinion': 695,
#  'poor': 696,
#  'totally': 697,
#  'driver': 698,
#  'heat': 699,
#  'pages': 700,
#  'expecting': 701,
#  'pan': 702,
#  'due': 703,
#  'happened': 704,
#  'features': 705,
#  'player': 706,
#  'picky': 707,
#  'opening': 708,
#  'steel': 709,
#  'five': 710,
#  'knew': 711,
#  'bags': 712,
#  'stick': 713,
#  'twist': 714,
#  'flashlight': 715,
#  'moving': 716,
#  'sex': 717,
#  'useful': 718,
#  'complete': 719,
#  'machine': 720,
#  'rubber': 721,
#  'suspense': 722,
#  'party': 723,
#  'fans': 724,
#  'local': 725,
#  'sets': 726,
#  'remember': 727,
#  'wash': 728,
#  'daughters': 729,
#  'simply': 730,
#  'previous': 731,
#  'safe': 732,
#  'garage': 733,
#  'stop': 734,
#  'brands': 735,
#  'starting': 736,
#  'write': 737,
#  'page': 738,
#  'pay': 739,
#  'taste': 740,
#  'waist': 741,
#  'grandson': 742,
#  'legs': 743,
#  'sad': 744,
#  'sony': 745,
#  'historical': 746,
#  'realistic': 747,
#  'wanting': 748,
#  'cheaper': 749,
#  'normally': 750,
#  'men': 751,
#  'waste': 752,
#  'age': 753,
#  'tiny': 754,
#  'number': 755,
#  'worry': 756,
#  'supposed': 757,
#  'cord': 758,
#  'bulky': 759,
#  'waiting': 760,
#  'imagine': 761,
#  'today': 762,
#  'american': 763,
#  'build': 764,
#  'fairly': 765,
#  'girls': 766,
#  'cards': 767,
#  'variety': 768,
#  'human': 769,
#  'glass': 770,
#  'happen': 771,
#  'learning': 772,
#  'please': 773,
#  'throw': 774,
#  'pants': 775,
#  'smooth': 776,
#  'tree': 777,
#  'group': 778,
#  'sensitive': 779,
#  'belt': 780,
#  'humor': 781,
#  'fiction': 782,
#  'band': 783,
#  'tank': 784,
#  'oh': 785,
#  'table': 786,
#  'sexy': 787,
#  'service': 788,
#  'otherwise': 789,
#  'quiet': 790,
#  'hole': 791,
#  'feeling': 792,
#  'adjust': 793,
#  'portable': 794,
#  'hear': 795,
#  'superb': 796,
#  'actors': 797,
#  'holes': 798,
#  'cast': 799,
#  'headphones': 800,
#  'summer': 801,
#  'face': 802,
#  'kindle': 803,
#  'storage': 804,
#  'travel': 805,
#  'detail': 806,
#  'powerful': 807,
#  'gloves': 808,
#  'walk': 809,
#  'secure': 810,
#  'guys': 811,
#  'wears': 812,
#  'writer': 813,
#  'noticed': 814,
#  'speakers': 815,
#  'plenty': 816,
#  'volume': 817,
#  'assemble': 818,
#  'heavier': 819,
#  'remote': 820,
#  'twice': 821,
#  'wooden': 822,
#  'zipper': 823,
#  'sons': 824,
#  'save': 825,
#  'base': 826,
#  'stuck': 827,
#  'lock': 828,
#  'sit': 829,
#  'mm': 830,
#  'chemistry': 831,
#  'leather': 832,
#  'sent': 833,
#  'art': 834,
#  'ways': 835,
#  'cups': 836,
#  'including': 837,
#  'choice': 838,
#  'screws': 839,
#  'means': 840,
#  'flat': 841,
#  'check': 842,
#  'unfortunately': 843,
#  'wow': 844,
#  'added': 845,
#  'seeing': 846,
#  'immediately': 847,
#  'finding': 848,
#  'drill': 849,
#  'classic': 850,
#  'board': 851,
#  'scene': 852,
#  'seller': 853,
#  'early': 854,
#  'office': 855,
#  'straight': 856,
#  'mouse': 857,
#  'arc': 858,
#  'finished': 859,
#  'moments': 860,
#  'pockets': 861,
#  'sink': 862,
#  'note': 863,
#  'wire': 864,
#  'films': 865,
#  'pros': 866,
#  'plan': 867,
#  'negative': 868,
#  'flimsy': 869,
#  'description': 870,
#  'ends': 871,
#  'sides': 872,
#  'attention': 873,
#  'discount': 874,
#  'lamp': 875,
#  'mat': 876,
#  'th': 877,
#  'handy': 878,
#  'vacuum': 879,
#  'pricey': 880,
#  'behind': 881,
#  'gotten': 882,
#  'chewer': 883,
#  'pick': 884,
#  'unless': 885,
#  'paid': 886,
#  'option': 887,
#  'helpful': 888,
#  'ride': 889,
#  'fire': 890,
#  'normal': 891,
#  'john': 892,
#  'hero': 893,
#  'suction': 894,
#  'bra': 895,
#  'lb': 896,
#  'booki': 897,
#  'accurate': 898,
#  'ice': 899,
#  'snug': 900,
#  'available': 901,
#  'games': 902,
#  'chain': 903,
#  'female': 904,
#  'adapter': 905,
#  'puzzle': 906,
#  'hour': 907,
#  'usual': 908,
#  'shot': 909,
#  'hat': 910,
#  'certainly': 911,
#  'smart': 912,
#  'protect': 913,
#  'jeans': 914,
#  'package': 915,
#  'noise': 916,
#  'stiff': 917,
#  'usa': 918,
#  'pads': 919,
#  'yellow': 920,
#  'mean': 921,
#  'construction': 922,
#  'rating': 923,
#  'provided': 924,
#  'hooked': 925,
#  'leash': 926,
#  'properly': 927,
#  'filled': 928,
#  'deep': 929,
#  'learned': 930,
#  'plug': 931,
#  'chew': 932,
#  'bar': 933,
#  'daily': 934,
#  'returned': 935,
#  'lab': 936,
#  'connection': 937,
#  'xl': 938,
#  'bowl': 939,
#  'granddaughter': 940,
#  'alone': 941,
#  'pump': 942,
#  'taken': 943,
#  'mostly': 944,
#  'compared': 945,
#  'stays': 946,
#  'pet': 947,
#  'details': 948,
#  'crazy': 949,
#  'tape': 950,
#  'missing': 951,
#  'everyday': 952,
#  'paint': 953,
#  'weather': 954,
#  'cleaning': 955,
#  'sizes': 956,
#  'spend': 957,
#  'slip': 958,
#  'annoying': 959,
#  'sleep': 960,
#  'press': 961,
#  'push': 962,
#  'readi': 963,
#  'mess': 964,
#  'walking': 965,
#  'prefer': 966,
#  'realize': 967,
#  'performance': 968,
#  'narrow': 969,
#  'complaints': 970,
#  'likable': 971,
#  'fell': 972,
#  'heard': 973,
#  'brother': 974,
#  'cons': 975,
#  'typical': 976,
#  'science': 977,
#  'worried': 978,
#  'green': 979,
#  'german': 980,
#  'pro': 981,
#  'turning': 982,
#  'stretchy': 983,
#  'hang': 984,
#  'condition': 985,
#  'test': 986,
#  'except': 987,
#  'sounds': 988,
#  'unbiased': 989,
#  'painting': 990,
#  'height': 991,
#  'runs': 992,
#  'recently': 993,
#  'tough': 994,
#  'saying': 995,
#  'ms': 996,
#  'somewhat': 997,
#  'rate': 998,
#  'datahookproductlinklinked': 999,
#  'lead': 1000,
#  ...}

# %%
plt.hist([len(x) for x in X],bins=500)
plt.show()

# %%
n=np.array([len(x) for x in X])
len(n[n<=200]) #There around 40k reviews which has words within 150
# Out:
# 40428

# %%
#get size of vocabulary
vocabulary=set()
for text in X:
   for word in text:
     if word  not in vocabulary:
       vocabulary.add(word)

vocab_length=len(vocabulary)
 #get max length of sequence
max_seq_length=0
for text in X:
   if len(text)>max_seq_length:
     max_seq_length=len(text)    
#results
print("vocab length:",vocab_length)
print("max sequence length:",max_seq_length)
# Out:
# vocab length: 48177
# max sequence length: 222

# %%
max_len=150
X=pad_sequences(X,maxlen=max_len)
len(X[1]) #The sentences are trimmed to 1000 for each ofthe 44k news articles now
# Out:
# 150

# %%
tokenizer.num_words

# %%
vocab_size=len(tokenizer.word_index)+1   #Adding an extra zero vector to capture unknown words to avoid the error it throws 
#vocab_size = tokenizer.num_words + 1
print('Vocabulary Size: %d' % vocab_size)
vocab=tokenizer.word_index
vocab
# Out:
# Vocabulary Size: 48178
# {'great': 1,
#  'book': 2,
#  'good': 3,
#  'one': 4,
#  'would': 5,
#  'love': 6,
#  'well': 7,
#  'story': 8,
#  'like': 9,
#  'read': 10,
#  'little': 11,
#  'get': 12,
#  'recommend': 13,
#  'characters': 14,
#  'really': 15,
#  'use': 16,
#  'bought': 17,
#  'also': 18,
#  'movie': 19,
#  'nice': 20,
#  'easy': 21,
#  'small': 22,
#  'time': 23,
#  'loves': 24,
#  'size': 25,
#  'product': 26,
#  'bit': 27,
#  'quality': 28,
#  'first': 29,
#  'lot': 30,
#  'made': 31,
#  'series': 32,
#  'used': 33,
#  'two': 34,
#  'much': 35,
#  'way': 36,
#  'fit': 37,
#  'loved': 38,
#  'works': 39,
#  'put': 40,
#  'work': 41,
#  'price': 42,
#  'still': 43,
#  'could': 44,
#  'light': 45,
#  'perfect': 46,
#  'dog': 47,
#  'comfortable': 48,
#  'see': 49,
#  'long': 50,
#  'enjoyed': 51,
#  'think': 52,
#  'old': 53,
#  'happy': 54,
#  'keep': 55,
#  'make': 56,
#  'anyone': 57,
#  'author': 58,
#  'looking': 59,
#  'reading': 60,
#  'got': 61,
#  'best': 62,
#  'plastic': 63,
#  'buy': 64,
#  'set': 65,
#  'better': 66,
#  'next': 67,
#  'go': 68,
#  'liked': 69,
#  'want': 70,
#  'even': 71,
#  'pretty': 72,
#  'back': 73,
#  'books': 74,
#  'thing': 75,
#  'look': 76,
#  'know': 77,
#  'hard': 78,
#  'sure': 79,
#  'using': 80,
#  'enough': 81,
#  'year': 82,
#  'going': 83,
#  'problem': 84,
#  'large': 85,
#  'years': 86,
#  'new': 87,
#  'fun': 88,
#  'definitely': 89,
#  'big': 90,
#  'say': 91,
#  'review': 92,
#  'last': 93,
#  'find': 94,
#  'feel': 95,
#  'strong': 96,
#  'written': 97,
#  'son': 98,
#  'another': 99,
#  'couple': 100,
#  'fan': 101,
#  'around': 102,
#  'thought': 103,
#  'need': 104,
#  'different': 105,
#  'many': 106,
#  'highly': 107,
#  'found': 108,
#  'interesting': 109,
#  'received': 110,
#  'wear': 111,
#  'right': 112,
#  'sturdy': 113,
#  'people': 114,
#  'toy': 115,
#  'top': 116,
#  'part': 117,
#  'wish': 118,
#  'ordered': 119,
#  'excellent': 120,
#  'life': 121,
#  'fact': 122,
#  'color': 123,
#  'never': 124,
#  'take': 125,
#  'day': 126,
#  'stars': 127,
#  'acting': 128,
#  'film': 129,
#  'replace': 130,
#  'reason': 131,
#  'things': 132,
#  'wait': 133,
#  'play': 134,
#  'case': 135,
#  'ending': 136,
#  'daughter': 137,
#  'fits': 138,
#  'bag': 139,
#  'looks': 140,
#  'dogs': 141,
#  'since': 142,
#  'pieces': 143,
#  'water': 144,
#  'able': 145,
#  'box': 146,
#  'perfectly': 147,
#  'purchase': 148,
#  'material': 149,
#  'every': 150,
#  'give': 151,
#  'watch': 152,
#  'purchased': 153,
#  'wanted': 154,
#  'developed': 155,
#  'together': 156,
#  'worth': 157,
#  'times': 158,
#  'makes': 159,
#  'bad': 160,
#  'honest': 161,
#  'seems': 162,
#  'second': 163,
#  'always': 164,
#  'sound': 165,
#  'ever': 166,
#  'food': 167,
#  'bright': 168,
#  'soft': 169,
#  'forward': 170,
#  'end': 171,
#  'pair': 172,
#  'fine': 173,
#  'hold': 174,
#  'kids': 175,
#  'plot': 176,
#  'something': 177,
#  'real': 178,
#  'short': 179,
#  'months': 180,
#  'family': 181,
#  'getting': 182,
#  'without': 183,
#  'though': 184,
#  'line': 185,
#  'comes': 186,
#  'game': 187,
#  'friend': 188,
#  'come': 189,
#  'ones': 190,
#  'job': 191,
#  'told': 192,
#  'gave': 193,
#  'clean': 194,
#  'cute': 195,
#  'pleased': 196,
#  'cat': 197,
#  'solid': 198,
#  'far': 199,
#  'must': 200,
#  'man': 201,
#  'money': 202,
#  'however': 203,
#  'wide': 204,
#  'saw': 205,
#  'gift': 206,
#  'expected': 207,
#  'house': 208,
#  'came': 209,
#  'issues': 210,
#  'several': 211,
#  'action': 212,
#  'place': 213,
#  'quite': 214,
#  'world': 215,
#  'room': 216,
#  'smaller': 217,
#  'tried': 218,
#  'exchange': 219,
#  'character': 220,
#  'glad': 221,
#  'worked': 222,
#  'cover': 223,
#  'beautiful': 224,
#  'shoes': 225,
#  'writing': 226,
#  'order': 227,
#  'kept': 228,
#  'yet': 229,
#  'us': 230,
#  'amazing': 231,
#  'needed': 232,
#  'try': 233,
#  'thin': 234,
#  'young': 235,
#  'disappointed': 236,
#  'side': 237,
#  'item': 238,
#  'enjoy': 239,
#  'favorite': 240,
#  'woman': 241,
#  'problems': 242,
#  'easily': 243,
#  'cats': 244,
#  'buying': 245,
#  'actually': 246,
#  'difficult': 247,
#  'days': 248,
#  'working': 249,
#  'full': 250,
#  'tight': 251,
#  'show': 252,
#  'deal': 253,
#  'away': 254,
#  'overall': 255,
#  'main': 256,
#  'christmas': 257,
#  'design': 258,
#  'high': 259,
#  'absolutely': 260,
#  'free': 261,
#  'probably': 262,
#  'head': 263,
#  'huge': 264,
#  'done': 265,
#  'home': 266,
#  'tool': 267,
#  'may': 268,
#  'awesome': 269,
#  'battery': 270,
#  'handle': 271,
#  'camera': 272,
#  'kind': 273,
#  'front': 274,
#  'amazon': 275,
#  'bottom': 276,
#  'turn': 277,
#  'heavy': 278,
#  'everything': 279,
#  'history': 280,
#  'hot': 281,
#  'reviews': 282,
#  'said': 283,
#  'larger': 284,
#  'took': 285,
#  'three': 286,
#  'extra': 287,
#  'takes': 288,
#  'parts': 289,
#  'clear': 290,
#  'anything': 291,
#  'husband': 292,
#  'seen': 293,
#  'night': 294,
#  'colors': 295,
#  'fast': 296,
#  'help': 297,
#  'likes': 298,
#  'update': 299,
#  'hope': 300,
#  'gets': 301,
#  'tv': 302,
#  'wonderful': 303,
#  'picture': 304,
#  'less': 305,
#  'idea': 306,
#  'almost': 307,
#  'movies': 308,
#  'addition': 309,
#  'others': 310,
#  'simple': 311,
#  'super': 312,
#  'whole': 313,
#  'piece': 314,
#  'might': 315,
#  'longer': 316,
#  'durable': 317,
#  'open': 318,
#  'weight': 319,
#  'blade': 320,
#  'seem': 321,
#  'quick': 322,
#  'especially': 323,
#  'stories': 324,
#  'girl': 325,
#  'hand': 326,
#  'start': 327,
#  'felt': 328,
#  'person': 329,
#  'knife': 330,
#  'needs': 331,
#  'past': 332,
#  'change': 333,
#  'bulb': 334,
#  'cheap': 335,
#  'romance': 336,
#  'value': 337,
#  'car': 338,
#  'original': 339,
#  'trying': 340,
#  'point': 341,
#  'instructions': 342,
#  'style': 343,
#  'version': 344,
#  'copy': 345,
#  'nothing': 346,
#  'unit': 347,
#  'holds': 348,
#  'power': 349,
#  'exactly': 350,
#  'install': 351,
#  'mystery': 352,
#  'let': 353,
#  'excited': 354,
#  'ok': 355,
#  'month': 356,
#  'thick': 357,
#  'hours': 358,
#  'funny': 359,
#  'phone': 360,
#  'kitchen': 361,
#  'given': 362,
#  'materials': 363,
#  'shoe': 364,
#  'feet': 365,
#  'store': 366,
#  'went': 367,
#  'wife': 368,
#  'bed': 369,
#  'cable': 370,
#  'star': 371,
#  'inside': 372,
#  'left': 373,
#  'carry': 374,
#  'novel': 375,
#  'drive': 376,
#  'tell': 377,
#  'friends': 378,
#  'wants': 379,
#  'true': 380,
#  'music': 381,
#  'interested': 382,
#  'expensive': 383,
#  'goes': 384,
#  'already': 385,
#  'run': 386,
#  'dvd': 387,
#  'slow': 388,
#  'white': 389,
#  'half': 390,
#  'guy': 391,
#  'arrived': 392,
#  'black': 393,
#  'started': 394,
#  'weeks': 395,
#  'finish': 396,
#  'special': 397,
#  'keeps': 398,
#  'quickly': 399,
#  'stuff': 400,
#  'iti': 401,
#  'lights': 402,
#  'making': 403,
#  'cut': 404,
#  'sweet': 405,
#  'lens': 406,
#  'wearing': 407,
#  'issue': 408,
#  'lots': 409,
#  'ago': 410,
#  'although': 411,
#  'foot': 412,
#  'reader': 413,
#  'child': 414,
#  'mind': 415,
#  'medium': 416,
#  'understand': 417,
#  'hands': 418,
#  'lives': 419,
#  'broken': 420,
#  'entertaining': 421,
#  'older': 422,
#  'door': 423,
#  'dress': 424,
#  'beginning': 425,
#  'maybe': 426,
#  'warm': 427,
#  'collection': 428,
#  'return': 429,
#  'along': 430,
#  'third': 431,
#  'stay': 432,
#  'instead': 433,
#  'screen': 434,
#  'admit': 435,
#  'believable': 436,
#  'everyone': 437,
#  'decided': 438,
#  'wrong': 439,
#  'minutes': 440,
#  'heart': 441,
#  'feels': 442,
#  'replacement': 443,
#  'loose': 444,
#  'middle': 445,
#  'cool': 446,
#  'finally': 447,
#  'watching': 448,
#  'cup': 449,
#  'space': 450,
#  'brand': 451,
#  'lost': 452,
#  'close': 453,
#  'coffee': 454,
#  'least': 455,
#  'playing': 456,
#  'ring': 457,
#  'batteries': 458,
#  'area': 459,
#  'someone': 460,
#  'low': 461,
#  'rather': 462,
#  'dark': 463,
#  'learn': 464,
#  'add': 465,
#  'seemed': 466,
#  'happens': 467,
#  'litter': 468,
#  'else': 469,
#  'cold': 470,
#  'bike': 471,
#  'screw': 472,
#  'usually': 473,
#  'metal': 474,
#  'children': 475,
#  'easier': 476,
#  'bigger': 477,
#  'impressed': 478,
#  'believe': 479,
#  'move': 480,
#  'computer': 481,
#  'week': 482,
#  'type': 483,
#  'either': 484,
#  'regular': 485,
#  'care': 486,
#  'turns': 487,
#  'pack': 488,
#  'ended': 489,
#  'often': 490,
#  'pocket': 491,
#  'expect': 492,
#  'toys': 493,
#  'rest': 494,
#  'says': 495,
#  'war': 496,
#  'usb': 497,
#  'figure': 498,
#  'tools': 499,
#  'relationship': 500,
#  'lid': 501,
#  'installed': 502,
#  'switch': 503,
#  'amount': 504,
#  'running': 505,
#  'fabric': 506,
#  'eat': 507,
#  'surprised': 508,
#  'sharp': 509,
#  'stand': 510,
#  'scenes': 511,
#  'guess': 512,
#  'puppy': 513,
#  'wall': 514,
#  'shirt': 515,
#  'live': 516,
#  'adjustable': 517,
#  'name': 518,
#  'control': 519,
#  'model': 520,
#  'effects': 521,
#  'etc': 522,
#  'setting': 523,
#  'nicely': 524,
#  'length': 525,
#  'okay': 526,
#  'baby': 527,
#  'button': 528,
#  'products': 529,
#  'uses': 530,
#  'four': 531,
#  'shows': 532,
#  'break': 533,
#  'follow': 534,
#  'pull': 535,
#  'hit': 536,
#  'ipad': 537,
#  'future': 538,
#  'lbs': 539,
#  'birthday': 540,
#  'ear': 541,
#  'support': 542,
#  'sometimes': 543,
#  'town': 544,
#  'plays': 545,
#  'led': 546,
#  'held': 547,
#  'mine': 548,
#  'built': 549,
#  'included': 550,
#  'season': 551,
#  'shape': 552,
#  'device': 553,
#  'collar': 554,
#  'entire': 555,
#  'predictable': 556,
#  'fall': 557,
#  'fantastic': 558,
#  'company': 559,
#  'air': 560,
#  'leave': 561,
#  'hoping': 562,
#  'strap': 563,
#  'storyline': 564,
#  'course': 565,
#  'dry': 566,
#  'watched': 567,
#  'system': 568,
#  'kit': 569,
#  'gives': 570,
#  'plus': 571,
#  'information': 572,
#  'single': 573,
#  'treats': 574,
#  'broke': 575,
#  'outside': 576,
#  'enjoys': 577,
#  'completely': 578,
#  'enjoyable': 579,
#  'yes': 580,
#  'floor': 581,
#  'extremely': 582,
#  'similar': 583,
#  'feature': 584,
#  'thinking': 585,
#  'ball': 586,
#  'father': 587,
#  'charge': 588,
#  'gun': 589,
#  'x': 590,
#  'important': 591,
#  'edge': 592,
#  'laptop': 593,
#  'shipping': 594,
#  'lightweight': 595,
#  'recommended': 596,
#  'grip': 597,
#  'become': 598,
#  'smell': 599,
#  'standard': 600,
#  'giving': 601,
#  'experience': 602,
#  'authors': 603,
#  'bathroom': 604,
#  'mount': 605,
#  'cost': 606,
#  'compact': 607,
#  'women': 608,
#  'heroine': 609,
#  'speaker': 610,
#  'living': 611,
#  'complaint': 612,
#  'tall': 613,
#  'interest': 614,
#  'items': 615,
#  'touch': 616,
#  'level': 617,
#  'taking': 618,
#  'coming': 619,
#  'twists': 620,
#  'keyboard': 621,
#  'blue': 622,
#  'designed': 623,
#  'keeping': 624,
#  'bulbs': 625,
#  'school': 626,
#  'based': 627,
#  'purchasing': 628,
#  'replaced': 629,
#  'pictures': 630,
#  'soon': 631,
#  'seat': 632,
#  'slightly': 633,
#  'putting': 634,
#  'downside': 635,
#  'pain': 636,
#  'harness': 637,
#  'notch': 638,
#  'sense': 639,
#  'helps': 640,
#  'within': 641,
#  'bottle': 642,
#  'played': 643,
#  'range': 644,
#  'bosch': 645,
#  'shower': 646,
#  'filter': 647,
#  'straps': 648,
#  'boy': 649,
#  'apart': 650,
#  'treat': 651,
#  'difference': 652,
#  'socks': 653,
#  'pillow': 654,
#  'trip': 655,
#  'thank': 656,
#  'described': 657,
#  'trouble': 658,
#  'video': 659,
#  'boring': 660,
#  'onei': 661,
#  'truly': 662,
#  'holding': 663,
#  'charger': 664,
#  'later': 665,
#  'wood': 666,
#  'inch': 667,
#  'looked': 668,
#  'mix': 669,
#  'sitting': 670,
#  'professional': 671,
#  'view': 672,
#  'eyes': 673,
#  'basic': 674,
#  'boots': 675,
#  'turned': 676,
#  'blades': 677,
#  'starts': 678,
#  'mother': 679,
#  'decent': 680,
#  'matter': 681,
#  'advertised': 682,
#  'red': 683,
#  'kid': 684,
#  'chance': 685,
#  'continue': 686,
#  'body': 687,
#  'remove': 688,
#  'card': 689,
#  'owned': 690,
#  'worn': 691,
#  'hair': 692,
#  'loud': 693,
#  'words': 694,
#  'opinion': 695,
#  'poor': 696,
#  'totally': 697,
#  'driver': 698,
#  'heat': 699,
#  'pages': 700,
#  'expecting': 701,
#  'pan': 702,
#  'due': 703,
#  'happened': 704,
#  'features': 705,
#  'player': 706,
#  'picky': 707,
#  'opening': 708,
#  'steel': 709,
#  'five': 710,
#  'knew': 711,
#  'bags': 712,
#  'stick': 713,
#  'twist': 714,
#  'flashlight': 715,
#  'moving': 716,
#  'sex': 717,
#  'useful': 718,
#  'complete': 719,
#  'machine': 720,
#  'rubber': 721,
#  'suspense': 722,
#  'party': 723,
#  'fans': 724,
#  'local': 725,
#  'sets': 726,
#  'remember': 727,
#  'wash': 728,
#  'daughters': 729,
#  'simply': 730,
#  'previous': 731,
#  'safe': 732,
#  'garage': 733,
#  'stop': 734,
#  'brands': 735,
#  'starting': 736,
#  'write': 737,
#  'page': 738,
#  'pay': 739,
#  'taste': 740,
#  'waist': 741,
#  'grandson': 742,
#  'legs': 743,
#  'sad': 744,
#  'sony': 745,
#  'historical': 746,
#  'realistic': 747,
#  'wanting': 748,
#  'cheaper': 749,
#  'normally': 750,
#  'men': 751,
#  'waste': 752,
#  'age': 753,
#  'tiny': 754,
#  'number': 755,
#  'worry': 756,
#  'supposed': 757,
#  'cord': 758,
#  'bulky': 759,
#  'waiting': 760,
#  'imagine': 761,
#  'today': 762,
#  'american': 763,
#  'build': 764,
#  'fairly': 765,
#  'girls': 766,
#  'cards': 767,
#  'variety': 768,
#  'human': 769,
#  'glass': 770,
#  'happen': 771,
#  'learning': 772,
#  'please': 773,
#  'throw': 774,
#  'pants': 775,
#  'smooth': 776,
#  'tree': 777,
#  'group': 778,
#  'sensitive': 779,
#  'belt': 780,
#  'humor': 781,
#  'fiction': 782,
#  'band': 783,
#  'tank': 784,
#  'oh': 785,
#  'table': 786,
#  'sexy': 787,
#  'service': 788,
#  'otherwise': 789,
#  'quiet': 790,
#  'hole': 791,
#  'feeling': 792,
#  'adjust': 793,
#  'portable': 794,
#  'hear': 795,
#  'superb': 796,
#  'actors': 797,
#  'holes': 798,
#  'cast': 799,
#  'headphones': 800,
#  'summer': 801,
#  'face': 802,
#  'kindle': 803,
#  'storage': 804,
#  'travel': 805,
#  'detail': 806,
#  'powerful': 807,
#  'gloves': 808,
#  'walk': 809,
#  'secure': 810,
#  'guys': 811,
#  'wears': 812,
#  'writer': 813,
#  'noticed': 814,
#  'speakers': 815,
#  'plenty': 816,
#  'volume': 817,
#  'assemble': 818,
#  'heavier': 819,
#  'remote': 820,
#  'twice': 821,
#  'wooden': 822,
#  'zipper': 823,
#  'sons': 824,
#  'save': 825,
#  'base': 826,
#  'stuck': 827,
#  'lock': 828,
#  'sit': 829,
#  'mm': 830,
#  'chemistry': 831,
#  'leather': 832,
#  'sent': 833,
#  'art': 834,
#  'ways': 835,
#  'cups': 836,
#  'including': 837,
#  'choice': 838,
#  'screws': 839,
#  'means': 840,
#  'flat': 841,
#  'check': 842,
#  'unfortunately': 843,
#  'wow': 844,
#  'added': 845,
#  'seeing': 846,
#  'immediately': 847,
#  'finding': 848,
#  'drill': 849,
#  'classic': 850,
#  'board': 851,
#  'scene': 852,
#  'seller': 853,
#  'early': 854,
#  'office': 855,
#  'straight': 856,
#  'mouse': 857,
#  'arc': 858,
#  'finished': 859,
#  'moments': 860,
#  'pockets': 861,
#  'sink': 862,
#  'note': 863,
#  'wire': 864,
#  'films': 865,
#  'pros': 866,
#  'plan': 867,
#  'negative': 868,
#  'flimsy': 869,
#  'description': 870,
#  'ends': 871,
#  'sides': 872,
#  'attention': 873,
#  'discount': 874,
#  'lamp': 875,
#  'mat': 876,
#  'th': 877,
#  'handy': 878,
#  'vacuum': 879,
#  'pricey': 880,
#  'behind': 881,
#  'gotten': 882,
#  'chewer': 883,
#  'pick': 884,
#  'unless': 885,
#  'paid': 886,
#  'option': 887,
#  'helpful': 888,
#  'ride': 889,
#  'fire': 890,
#  'normal': 891,
#  'john': 892,
#  'hero': 893,
#  'suction': 894,
#  'bra': 895,
#  'lb': 896,
#  'booki': 897,
#  'accurate': 898,
#  'ice': 899,
#  'snug': 900,
#  'available': 901,
#  'games': 902,
#  'chain': 903,
#  'female': 904,
#  'adapter': 905,
#  'puzzle': 906,
#  'hour': 907,
#  'usual': 908,
#  'shot': 909,
#  'hat': 910,
#  'certainly': 911,
#  'smart': 912,
#  'protect': 913,
#  'jeans': 914,
#  'package': 915,
#  'noise': 916,
#  'stiff': 917,
#  'usa': 918,
#  'pads': 919,
#  'yellow': 920,
#  'mean': 921,
#  'construction': 922,
#  'rating': 923,
#  'provided': 924,
#  'hooked': 925,
#  'leash': 926,
#  'properly': 927,
#  'filled': 928,
#  'deep': 929,
#  'learned': 930,
#  'plug': 931,
#  'chew': 932,
#  'bar': 933,
#  'daily': 934,
#  'returned': 935,
#  'lab': 936,
#  'connection': 937,
#  'xl': 938,
#  'bowl': 939,
#  'granddaughter': 940,
#  'alone': 941,
#  'pump': 942,
#  'taken': 943,
#  'mostly': 944,
#  'compared': 945,
#  'stays': 946,
#  'pet': 947,
#  'details': 948,
#  'crazy': 949,
#  'tape': 950,
#  'missing': 951,
#  'everyday': 952,
#  'paint': 953,
#  'weather': 954,
#  'cleaning': 955,
#  'sizes': 956,
#  'spend': 957,
#  'slip': 958,
#  'annoying': 959,
#  'sleep': 960,
#  'press': 961,
#  'push': 962,
#  'readi': 963,
#  'mess': 964,
#  'walking': 965,
#  'prefer': 966,
#  'realize': 967,
#  'performance': 968,
#  'narrow': 969,
#  'complaints': 970,
#  'likable': 971,
#  'fell': 972,
#  'heard': 973,
#  'brother': 974,
#  'cons': 975,
#  'typical': 976,
#  'science': 977,
#  'worried': 978,
#  'green': 979,
#  'german': 980,
#  'pro': 981,
#  'turning': 982,
#  'stretchy': 983,
#  'hang': 984,
#  'condition': 985,
#  'test': 986,
#  'except': 987,
#  'sounds': 988,
#  'unbiased': 989,
#  'painting': 990,
#  'height': 991,
#  'runs': 992,
#  'recently': 993,
#  'tough': 994,
#  'saying': 995,
#  'ms': 996,
#  'somewhat': 997,
#  'rate': 998,
#  'datahookproductlinklinked': 999,
#  'lead': 1000,
#  ...}

# %%
def get_weight_matrix(model): #Weight matrix is created to map the embedding vectors and its words
  weight_matrix=np.zeros((vocab_size,DIM))
  for word,i in vocab.items():
    weight_matrix[i]=model.wv[word]
  return weight_matrix

# %%
embedding_vectors=get_weight_matrix(w2v_model)
embedding_vectors.shape
# Out:
# (48178, 100)

# %%
##Train and test data creation
X_train, X_test, Y_train, Y_test = train_test_split(X, reviews_data['label'],test_size=0.2,stratify = reviews_data['label'],random_state=1)
# find the length of the largest sentence in training data
#max_len = xtrain.apply(lambda x: len(xtrain)).max()
#print(f'Max number of words in a text in training data: {max_len}')
X_train.shape
# Out:
# (32345, 150)

# %%
X_test.shape
# Out:
# (8087, 150)

# %% [markdown]
# #Modelling using Passive Aggressive Classifier for Word2vec

# %%
from sklearn.linear_model import PassiveAggressiveClassifier
from sklearn.metrics import accuracy_score,confusion_matrix
linear_clf = PassiveAggressiveClassifier(random_state=42)
linear_clf.fit(X_train, Y_train.ravel())
pred = linear_clf.predict(X_test)
score = accuracy_score(Y_test,pred)
print(score)
print(confusion_matrix(Y_test,pred))
print(classification_report(Y_test, pred))
# Out:
# 0.5423519228391245
# [[2381 1662]
#  [2039 2005]]
#               precision    recall  f1-score   support
#
#            0       0.54      0.59      0.56      4043
#            1       0.55      0.50      0.52      4044
#
#     accuracy                           0.54      8087
#    macro avg       0.54      0.54      0.54      8087
# weighted avg       0.54      0.54      0.54      8087

# %% [markdown]
# #Modelling using SVM classifier for Word2vec

# %%
from sklearn.svm import SVC
clf = SVC()
# train the model
clf.fit(X_train,Y_train)
# use the model to predict the testing instances
y_pred = clf.predict(np.array(X_test))
# generate the classification report
print(classification_report(Y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.85      0.78      4043
#            1       0.82      0.68      0.74      4044
#
#     accuracy                           0.76      8087
#    macro avg       0.77      0.76      0.76      8087
# weighted avg       0.77      0.76      0.76      8087

# %% [markdown]
# #Modelling using Bi LSTM for Word2vec

# %%
from tensorflow.keras.optimizers import Adam
def set_model(embedding_vectors):
    model = Sequential()
    model.add(Embedding(embedding_vectors.shape[0], 
                        output_dim=embedding_vectors.shape[1],
                        weights=[embedding_vectors], 
                        input_length=max_len, 
                        trainable=False))
    model.add(Bidirectional(LSTM(units=64)))
    model.add(Dropout(0.4))
    model.add(Dense(1, activation='sigmoid'))
    opt =Adam(learning_rate=0.001)
    model.compile(optimizer=opt, loss='binary_crossentropy', metrics=['acc'])
    return model

# %%
# %%time
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
model = set_model(embedding_vectors = embedding_vectors)
model.summary()
from keras.callbacks import Callback, EarlyStopping,ReduceLROnPlateau
#reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, min_lr=1e-6, verbose=1)
early_stop = EarlyStopping(monitor='val_loss', min_delta=0, patience=1, mode='auto')
mc = ModelCheckpoint('best_model.h5', monitor='val_acc', mode='max', verbose=1, save_best_only=True)
batch_size = 64
epochs  = 8
history = model.fit(X_train,Y_train,validation_data=(X_test,Y_test), batch_size = batch_size, epochs = epochs,callbacks=[early_stop,mc])
saved_model = load_model('best_model.h5')
# evaluate the model
_, train_acc = saved_model.evaluate(X_train, Y_train, verbose=0)
_, test_acc = saved_model.evaluate(X_test, Y_test, verbose=0)
print('Train: %.3f, Test: %.3f' % (train_acc, test_acc))
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_3 (Embedding)     (None, 150, 100)          4817800
#
#  bidirectional_3 (Bidirectio  (None, 128)              84480
#  nal)
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 4,902,409
# Trainable params: 84,609
# Non-trainable params: 4,817,800
# _________________________________________________________________
# Epoch 1/8
# 506/506 [==============================] - ETA: 0s - loss: 0.3388 - acc: 0.8459
# Epoch 1: val_acc improved from -inf to 0.88636, saving model to best_model.h5
# 506/506 [==============================] - 142s 274ms/step - loss: 0.3388 - acc: 0.8459 - val_loss: 0.2687 - val_acc: 0.8864
# Epoch 2/8
# 506/506 [==============================] - ETA: 0s - loss: 0.2551 - acc: 0.8887
# Epoch 2: val_acc improved from 0.88636 to 0.90145, saving model to best_model.h5
# 506/506 [==============================] - 139s 274ms/step - loss: 0.2551 - acc: 0.8887 - val_loss: 0.2301 - val_acc: 0.9014
# Epoch 3/8
# 506/506 [==============================] - ETA: 0s - loss: 0.2318 - acc: 0.9004
# Epoch 3: val_acc improved from 0.90145 to 0.90441, saving model to best_model.h5
# 506/506 [==============================] - 137s 270ms/step - loss: 0.2318 - acc: 0.9004 - val_loss: 0.2231 - val_acc: 0.9044
# Epoch 4/8
# 506/506 [==============================] - ETA: 0s - loss: 0.2148 - acc: 0.9082
# Epoch 4: val_acc did not improve from 0.90441
# 506/506 [==============================] - 137s 271ms/step - loss: 0.2148 - acc: 0.9082 - val_loss: 0.2480 - val_acc: 0.8878
# Train: 0.912, Test: 0.904
# CPU times: user 17min 5s, sys: 1min 6s, total: 18min 12s
# Wall time: 10min 14s

# %%
def plot_loss_epochs(history):
    epochs = np.arange(1,len(history.history['acc']) + 1,1)
    train_acc = history.history['acc']
    train_loss = history.history['loss']
    val_acc = history.history['val_acc']
    val_loss = history.history['val_loss']

    fig , ax = plt.subplots(1,2, figsize=(7,3))
    ax[0].plot(epochs , train_acc , '.-' , label = 'Train Accuracy')
    ax[0].plot(epochs , val_acc , '.-' , label = 'Validation Accuracy')
    ax[0].set_title('Train & Validation Accuracy')
    ax[0].legend()
    ax[0].set_xlabel("Epochs")
    ax[0].set_ylabel("Accuracy")

    ax[1].plot(epochs , train_loss , '.-' , label = 'Train Loss')
    ax[1].plot(epochs , val_loss , '.-' , label = 'Validation Loss')
    ax[1].set_title('Train & Validation Loss')
    ax[1].legend()
    ax[1].set_xlabel("Epochs")
    ax[1].set_ylabel("Loss")
    fig.tight_layout()
    fig.show()
plot_loss_epochs(history)

# %%
import seaborn as sns
#text_test_tok = tokenizer.texts_to_sequences(xtest)
pred = (model.predict(X_test) > 0.5).astype("int32")
print("accuracy:",accuracy_score(Y_test,pred)*100)
print(classification_report(Y_test, pred, target_names = ['Fake','Real'])) 
cm = pd.DataFrame(confusion_matrix(Y_test,pred))

fig , ax = plt.subplots(figsize = (2,2))
ax = sns.heatmap(cm, annot = True, xticklabels = ['Fake','Real'] , yticklabels = ['Fake','Real'], cbar = False, fmt='')
ax.set_xlabel("Predicted"); ax.set_ylabel("Actual"); fig.show()
# Out:
# 253/253 [==============================] - 12s 43ms/step
# accuracy: 88.78446890070484
#               precision    recall  f1-score   support
#
#         Fake       0.84      0.96      0.90      4044
#         Real       0.95      0.81      0.88      4043
#
#     accuracy                           0.89      8087
#    macro avg       0.90      0.89      0.89      8087
# weighted avg       0.90      0.89      0.89      8087

# %%
#x=['NEW YORK/WASHINGTON (Reuters) - The new U.S. tax code targets high-tax states and may be unconstitutional, New York Governor Andrew Cuomo said on Thursday,saying that the bill may violate New York residentsâ€™ rights to due process and equal protection.  The sweeping Republican tax bill signed into law by U.S. President Donald Trump on Friday introduces a cap, of $10,000,  on deductions of state and local income and property taxes, known as SALT. The tax overhaul was the partyâ€™s first major legislative victory since Trump took office in January.  The SALT provision will hit many taxpayers in states with high incomes, high property values and high taxes, like New York, New Jersey and California. Those states are generally Democratic leaning.  â€œIâ€™m not even sure what they did is legally constitutional and thatâ€™s something weâ€™re looking at now,â€ Cuomo said in an interview with CNN. In an interview with CNBC, Cuomo suggested why the bill may be unconstitutional.  â€œPolitics does not trump the law,â€ Cuomo said on CNBC. â€œYou have the constitution, you have the law, you have due process, you have equal protection. You canâ€™t use politics just because the majority controls to override the law.â€ The Fifth Amendment of the Constitution, better known for its protection against self-incrimination, also protects individuals from seizure of life, liberty or property without due process and has been interpreted by the Supreme Court as guaranteeing equal protection by the law.  Cuomo and California Governor Jerry Brown, both Democrats, have previously said they were exploring legal challenges to SALT deduction limits.  Law professors have said legal challenges would likely rest on arguing that the provision interferes with the protection of statesâ€™ rights under the U.S. Constitutionâ€™s 10th Amendment. Tax attorneys said Cuomoâ€™s legal argument against the tax bill could be that it discriminates and places an unjust tax burden on states that heavily voted for Democrats in the past - known as â€œblue states.â€ â€œThe de facto effect of this legislation is to discriminate against blue states and particularly from (Cuomoâ€™s) perspective the state of New York,â€ said Joseph Callahan, an attorney with the law firm Mackay, Caswell & Callahan in New York.  But some tax experts noted the U.S. Supreme Court has interpreted the 16th Amendment to give Congress broad latitude to tax as it sees fit. In a frequently cited 1934 decision, the Supreme Court called tax deductions a â€œlegislative graceâ€ rather than a vested right. â€œI donâ€™t understand how they think they have a valid lawsuit here,â€ David Gamage, a professor of tax law at Indiana Universityâ€™s Maurer School of Law, told Reuters last week, speaking generally about governors in blue states that could challenge the tax bill.  Cuomo also said on Thursday that New York is proposing a restructuring of its tax code. He provided no details.  A group of 13 law professors on Dec. 18 published a paper suggesting ways that high-tax states could minimize the effects of the SALT deduction cap.  Their suggestions included shifting more of the tax burden onto businesses in the form of higher employer-side payroll taxes, since the federal tax billâ€™s cap on SALT deductions only applies to individuals and not businesses. States also could raise taxes on pass-through entities, which the federal tax bill specifically benefits with a lower rate on a portion of their income. On Friday, Cuomo said he would allow state residents to make a partial or full pre-payment on their property tax bill before Jan. 1, allowing taxpapyers to deduct such payments for 2017 before the cap kicks in, prompting a wave of residents to pay early.  However, the U.S. Internal Revenue Service on Wednesday advised homeowners that the pre-payment of 2018 property taxes may not be deductible.']
x=['These towels are real nice, and I love the feel of them.  They have a nice feel']
x=tokenizer.texts_to_sequences(x)
x=pad_sequences(x,maxlen=max_len)

# %%
(model.predict(x) >0.5).astype(int)
# Out:
# 1/1 [==============================] - 0s 28ms/step
# array([[0]])

# %% [markdown]
# # GLOVE

# %%
# create tokenizer object
tokenizer = Tokenizer()
tokenizer.fit_on_texts(reviews_data['text_'].tolist())

word_index = tokenizer.word_index
vocab_size = len(tokenizer.word_index) + 1
print("Vocabulary Size :", vocab_size)
# Out:
# Vocabulary Size : 48178

# %%
x_train = pad_sequences(tokenizer.texts_to_sequences(reviews_data['text_'].tolist()),
                        maxlen = max_len)
# x_test = pad_sequences(tokenizer.texts_to_sequences(test_data.title),
#                        maxlen = max_sequence_length)

print("Training X Shape:",x_train.shape)
# Out:
# Training X Shape: (40432, 150)

# %%
print(x_train)
# Out:
# [[    0     0     0 ...     6  1297    72]
#  [    0     0     0 ...   548   100    86]
#  [    0     0     0 ...    76    95   654]
#  ...
#  [  326   237 16595 ...  1378 14999  2926]
#  [    0     0     0 ...    48    76     1]
#  [   76   671  1176 ...   111   809   126]]

# %%
word_index
# Out:
# {'great': 1,
#  'book': 2,
#  'good': 3,
#  'one': 4,
#  'would': 5,
#  'love': 6,
#  'well': 7,
#  'story': 8,
#  'like': 9,
#  'read': 10,
#  'little': 11,
#  'get': 12,
#  'recommend': 13,
#  'characters': 14,
#  'really': 15,
#  'use': 16,
#  'bought': 17,
#  'also': 18,
#  'movie': 19,
#  'nice': 20,
#  'easy': 21,
#  'small': 22,
#  'time': 23,
#  'loves': 24,
#  'size': 25,
#  'product': 26,
#  'bit': 27,
#  'quality': 28,
#  'first': 29,
#  'lot': 30,
#  'made': 31,
#  'series': 32,
#  'used': 33,
#  'two': 34,
#  'much': 35,
#  'way': 36,
#  'fit': 37,
#  'loved': 38,
#  'works': 39,
#  'put': 40,
#  'work': 41,
#  'price': 42,
#  'still': 43,
#  'could': 44,
#  'light': 45,
#  'perfect': 46,
#  'dog': 47,
#  'comfortable': 48,
#  'see': 49,
#  'long': 50,
#  'enjoyed': 51,
#  'think': 52,
#  'old': 53,
#  'happy': 54,
#  'keep': 55,
#  'make': 56,
#  'anyone': 57,
#  'author': 58,
#  'looking': 59,
#  'reading': 60,
#  'got': 61,
#  'best': 62,
#  'plastic': 63,
#  'buy': 64,
#  'set': 65,
#  'better': 66,
#  'next': 67,
#  'go': 68,
#  'liked': 69,
#  'want': 70,
#  'even': 71,
#  'pretty': 72,
#  'back': 73,
#  'books': 74,
#  'thing': 75,
#  'look': 76,
#  'know': 77,
#  'hard': 78,
#  'sure': 79,
#  'using': 80,
#  'enough': 81,
#  'year': 82,
#  'going': 83,
#  'problem': 84,
#  'large': 85,
#  'years': 86,
#  'new': 87,
#  'fun': 88,
#  'definitely': 89,
#  'big': 90,
#  'say': 91,
#  'review': 92,
#  'last': 93,
#  'find': 94,
#  'feel': 95,
#  'strong': 96,
#  'written': 97,
#  'son': 98,
#  'another': 99,
#  'couple': 100,
#  'fan': 101,
#  'around': 102,
#  'thought': 103,
#  'need': 104,
#  'different': 105,
#  'many': 106,
#  'highly': 107,
#  'found': 108,
#  'interesting': 109,
#  'received': 110,
#  'wear': 111,
#  'right': 112,
#  'sturdy': 113,
#  'people': 114,
#  'toy': 115,
#  'top': 116,
#  'part': 117,
#  'wish': 118,
#  'ordered': 119,
#  'excellent': 120,
#  'life': 121,
#  'fact': 122,
#  'color': 123,
#  'never': 124,
#  'take': 125,
#  'day': 126,
#  'stars': 127,
#  'acting': 128,
#  'film': 129,
#  'replace': 130,
#  'reason': 131,
#  'things': 132,
#  'wait': 133,
#  'play': 134,
#  'case': 135,
#  'ending': 136,
#  'daughter': 137,
#  'fits': 138,
#  'bag': 139,
#  'looks': 140,
#  'dogs': 141,
#  'since': 142,
#  'pieces': 143,
#  'water': 144,
#  'able': 145,
#  'box': 146,
#  'perfectly': 147,
#  'purchase': 148,
#  'material': 149,
#  'every': 150,
#  'give': 151,
#  'watch': 152,
#  'purchased': 153,
#  'wanted': 154,
#  'developed': 155,
#  'together': 156,
#  'worth': 157,
#  'times': 158,
#  'makes': 159,
#  'bad': 160,
#  'honest': 161,
#  'seems': 162,
#  'second': 163,
#  'always': 164,
#  'sound': 165,
#  'ever': 166,
#  'food': 167,
#  'bright': 168,
#  'soft': 169,
#  'forward': 170,
#  'end': 171,
#  'pair': 172,
#  'fine': 173,
#  'hold': 174,
#  'kids': 175,
#  'plot': 176,
#  'something': 177,
#  'real': 178,
#  'short': 179,
#  'months': 180,
#  'family': 181,
#  'getting': 182,
#  'without': 183,
#  'though': 184,
#  'line': 185,
#  'comes': 186,
#  'game': 187,
#  'friend': 188,
#  'come': 189,
#  'ones': 190,
#  'job': 191,
#  'told': 192,
#  'gave': 193,
#  'clean': 194,
#  'cute': 195,
#  'pleased': 196,
#  'cat': 197,
#  'solid': 198,
#  'far': 199,
#  'must': 200,
#  'man': 201,
#  'money': 202,
#  'however': 203,
#  'wide': 204,
#  'saw': 205,
#  'gift': 206,
#  'expected': 207,
#  'house': 208,
#  'came': 209,
#  'issues': 210,
#  'several': 211,
#  'action': 212,
#  'place': 213,
#  'quite': 214,
#  'world': 215,
#  'room': 216,
#  'smaller': 217,
#  'tried': 218,
#  'exchange': 219,
#  'character': 220,
#  'glad': 221,
#  'worked': 222,
#  'cover': 223,
#  'beautiful': 224,
#  'shoes': 225,
#  'writing': 226,
#  'order': 227,
#  'kept': 228,
#  'yet': 229,
#  'us': 230,
#  'amazing': 231,
#  'needed': 232,
#  'try': 233,
#  'thin': 234,
#  'young': 235,
#  'disappointed': 236,
#  'side': 237,
#  'item': 238,
#  'enjoy': 239,
#  'favorite': 240,
#  'woman': 241,
#  'problems': 242,
#  'easily': 243,
#  'cats': 244,
#  'buying': 245,
#  'actually': 246,
#  'difficult': 247,
#  'days': 248,
#  'working': 249,
#  'full': 250,
#  'tight': 251,
#  'show': 252,
#  'deal': 253,
#  'away': 254,
#  'overall': 255,
#  'main': 256,
#  'christmas': 257,
#  'design': 258,
#  'high': 259,
#  'absolutely': 260,
#  'free': 261,
#  'probably': 262,
#  'head': 263,
#  'huge': 264,
#  'done': 265,
#  'home': 266,
#  'tool': 267,
#  'may': 268,
#  'awesome': 269,
#  'battery': 270,
#  'handle': 271,
#  'camera': 272,
#  'kind': 273,
#  'front': 274,
#  'amazon': 275,
#  'bottom': 276,
#  'turn': 277,
#  'heavy': 278,
#  'everything': 279,
#  'history': 280,
#  'hot': 281,
#  'reviews': 282,
#  'said': 283,
#  'larger': 284,
#  'took': 285,
#  'three': 286,
#  'extra': 287,
#  'takes': 288,
#  'parts': 289,
#  'clear': 290,
#  'anything': 291,
#  'husband': 292,
#  'seen': 293,
#  'night': 294,
#  'colors': 295,
#  'fast': 296,
#  'help': 297,
#  'likes': 298,
#  'update': 299,
#  'hope': 300,
#  'gets': 301,
#  'tv': 302,
#  'wonderful': 303,
#  'picture': 304,
#  'less': 305,
#  'idea': 306,
#  'almost': 307,
#  'movies': 308,
#  'addition': 309,
#  'others': 310,
#  'simple': 311,
#  'super': 312,
#  'whole': 313,
#  'piece': 314,
#  'might': 315,
#  'longer': 316,
#  'durable': 317,
#  'open': 318,
#  'weight': 319,
#  'blade': 320,
#  'seem': 321,
#  'quick': 322,
#  'especially': 323,
#  'stories': 324,
#  'girl': 325,
#  'hand': 326,
#  'start': 327,
#  'felt': 328,
#  'person': 329,
#  'knife': 330,
#  'needs': 331,
#  'past': 332,
#  'change': 333,
#  'bulb': 334,
#  'cheap': 335,
#  'romance': 336,
#  'value': 337,
#  'car': 338,
#  'original': 339,
#  'trying': 340,
#  'point': 341,
#  'instructions': 342,
#  'style': 343,
#  'version': 344,
#  'copy': 345,
#  'nothing': 346,
#  'unit': 347,
#  'holds': 348,
#  'power': 349,
#  'exactly': 350,
#  'install': 351,
#  'mystery': 352,
#  'let': 353,
#  'excited': 354,
#  'ok': 355,
#  'month': 356,
#  'thick': 357,
#  'hours': 358,
#  'funny': 359,
#  'phone': 360,
#  'kitchen': 361,
#  'given': 362,
#  'materials': 363,
#  'shoe': 364,
#  'feet': 365,
#  'store': 366,
#  'went': 367,
#  'wife': 368,
#  'bed': 369,
#  'cable': 370,
#  'star': 371,
#  'inside': 372,
#  'left': 373,
#  'carry': 374,
#  'novel': 375,
#  'drive': 376,
#  'tell': 377,
#  'friends': 378,
#  'wants': 379,
#  'true': 380,
#  'music': 381,
#  'interested': 382,
#  'expensive': 383,
#  'goes': 384,
#  'already': 385,
#  'run': 386,
#  'dvd': 387,
#  'slow': 388,
#  'white': 389,
#  'half': 390,
#  'guy': 391,
#  'arrived': 392,
#  'black': 393,
#  'started': 394,
#  'weeks': 395,
#  'finish': 396,
#  'special': 397,
#  'keeps': 398,
#  'quickly': 399,
#  'stuff': 400,
#  'iti': 401,
#  'lights': 402,
#  'making': 403,
#  'cut': 404,
#  'sweet': 405,
#  'lens': 406,
#  'wearing': 407,
#  'issue': 408,
#  'lots': 409,
#  'ago': 410,
#  'although': 411,
#  'foot': 412,
#  'reader': 413,
#  'child': 414,
#  'mind': 415,
#  'medium': 416,
#  'understand': 417,
#  'hands': 418,
#  'lives': 419,
#  'broken': 420,
#  'entertaining': 421,
#  'older': 422,
#  'door': 423,
#  'dress': 424,
#  'beginning': 425,
#  'maybe': 426,
#  'warm': 427,
#  'collection': 428,
#  'return': 429,
#  'along': 430,
#  'third': 431,
#  'stay': 432,
#  'instead': 433,
#  'screen': 434,
#  'admit': 435,
#  'believable': 436,
#  'everyone': 437,
#  'decided': 438,
#  'wrong': 439,
#  'minutes': 440,
#  'heart': 441,
#  'feels': 442,
#  'replacement': 443,
#  'loose': 444,
#  'middle': 445,
#  'cool': 446,
#  'finally': 447,
#  'watching': 448,
#  'cup': 449,
#  'space': 450,
#  'brand': 451,
#  'lost': 452,
#  'close': 453,
#  'coffee': 454,
#  'least': 455,
#  'playing': 456,
#  'ring': 457,
#  'batteries': 458,
#  'area': 459,
#  'someone': 460,
#  'low': 461,
#  'rather': 462,
#  'dark': 463,
#  'learn': 464,
#  'add': 465,
#  'seemed': 466,
#  'happens': 467,
#  'litter': 468,
#  'else': 469,
#  'cold': 470,
#  'bike': 471,
#  'screw': 472,
#  'usually': 473,
#  'metal': 474,
#  'children': 475,
#  'easier': 476,
#  'bigger': 477,
#  'impressed': 478,
#  'believe': 479,
#  'move': 480,
#  'computer': 481,
#  'week': 482,
#  'type': 483,
#  'either': 484,
#  'regular': 485,
#  'care': 486,
#  'turns': 487,
#  'pack': 488,
#  'ended': 489,
#  'often': 490,
#  'pocket': 491,
#  'expect': 492,
#  'toys': 493,
#  'rest': 494,
#  'says': 495,
#  'war': 496,
#  'usb': 497,
#  'figure': 498,
#  'tools': 499,
#  'relationship': 500,
#  'lid': 501,
#  'installed': 502,
#  'switch': 503,
#  'amount': 504,
#  'running': 505,
#  'fabric': 506,
#  'eat': 507,
#  'surprised': 508,
#  'sharp': 509,
#  'stand': 510,
#  'scenes': 511,
#  'guess': 512,
#  'puppy': 513,
#  'wall': 514,
#  'shirt': 515,
#  'live': 516,
#  'adjustable': 517,
#  'name': 518,
#  'control': 519,
#  'model': 520,
#  'effects': 521,
#  'etc': 522,
#  'setting': 523,
#  'nicely': 524,
#  'length': 525,
#  'okay': 526,
#  'baby': 527,
#  'button': 528,
#  'products': 529,
#  'uses': 530,
#  'four': 531,
#  'shows': 532,
#  'break': 533,
#  'follow': 534,
#  'pull': 535,
#  'hit': 536,
#  'ipad': 537,
#  'future': 538,
#  'lbs': 539,
#  'birthday': 540,
#  'ear': 541,
#  'support': 542,
#  'sometimes': 543,
#  'town': 544,
#  'plays': 545,
#  'led': 546,
#  'held': 547,
#  'mine': 548,
#  'built': 549,
#  'included': 550,
#  'season': 551,
#  'shape': 552,
#  'device': 553,
#  'collar': 554,
#  'entire': 555,
#  'predictable': 556,
#  'fall': 557,
#  'fantastic': 558,
#  'company': 559,
#  'air': 560,
#  'leave': 561,
#  'hoping': 562,
#  'strap': 563,
#  'storyline': 564,
#  'course': 565,
#  'dry': 566,
#  'watched': 567,
#  'system': 568,
#  'kit': 569,
#  'gives': 570,
#  'plus': 571,
#  'information': 572,
#  'single': 573,
#  'treats': 574,
#  'broke': 575,
#  'outside': 576,
#  'enjoys': 577,
#  'completely': 578,
#  'enjoyable': 579,
#  'yes': 580,
#  'floor': 581,
#  'extremely': 582,
#  'similar': 583,
#  'feature': 584,
#  'thinking': 585,
#  'ball': 586,
#  'father': 587,
#  'charge': 588,
#  'gun': 589,
#  'x': 590,
#  'important': 591,
#  'edge': 592,
#  'laptop': 593,
#  'shipping': 594,
#  'lightweight': 595,
#  'recommended': 596,
#  'grip': 597,
#  'become': 598,
#  'smell': 599,
#  'standard': 600,
#  'giving': 601,
#  'experience': 602,
#  'authors': 603,
#  'bathroom': 604,
#  'mount': 605,
#  'cost': 606,
#  'compact': 607,
#  'women': 608,
#  'heroine': 609,
#  'speaker': 610,
#  'living': 611,
#  'complaint': 612,
#  'tall': 613,
#  'interest': 614,
#  'items': 615,
#  'touch': 616,
#  'level': 617,
#  'taking': 618,
#  'coming': 619,
#  'twists': 620,
#  'keyboard': 621,
#  'blue': 622,
#  'designed': 623,
#  'keeping': 624,
#  'bulbs': 625,
#  'school': 626,
#  'based': 627,
#  'purchasing': 628,
#  'replaced': 629,
#  'pictures': 630,
#  'soon': 631,
#  'seat': 632,
#  'slightly': 633,
#  'putting': 634,
#  'downside': 635,
#  'pain': 636,
#  'harness': 637,
#  'notch': 638,
#  'sense': 639,
#  'helps': 640,
#  'within': 641,
#  'bottle': 642,
#  'played': 643,
#  'range': 644,
#  'bosch': 645,
#  'shower': 646,
#  'filter': 647,
#  'straps': 648,
#  'boy': 649,
#  'apart': 650,
#  'treat': 651,
#  'difference': 652,
#  'socks': 653,
#  'pillow': 654,
#  'trip': 655,
#  'thank': 656,
#  'described': 657,
#  'trouble': 658,
#  'video': 659,
#  'boring': 660,
#  'onei': 661,
#  'truly': 662,
#  'holding': 663,
#  'charger': 664,
#  'later': 665,
#  'wood': 666,
#  'inch': 667,
#  'looked': 668,
#  'mix': 669,
#  'sitting': 670,
#  'professional': 671,
#  'view': 672,
#  'eyes': 673,
#  'basic': 674,
#  'boots': 675,
#  'turned': 676,
#  'blades': 677,
#  'starts': 678,
#  'mother': 679,
#  'decent': 680,
#  'matter': 681,
#  'advertised': 682,
#  'red': 683,
#  'kid': 684,
#  'chance': 685,
#  'continue': 686,
#  'body': 687,
#  'remove': 688,
#  'card': 689,
#  'owned': 690,
#  'worn': 691,
#  'hair': 692,
#  'loud': 693,
#  'words': 694,
#  'opinion': 695,
#  'poor': 696,
#  'totally': 697,
#  'driver': 698,
#  'heat': 699,
#  'pages': 700,
#  'expecting': 701,
#  'pan': 702,
#  'due': 703,
#  'happened': 704,
#  'features': 705,
#  'player': 706,
#  'picky': 707,
#  'opening': 708,
#  'steel': 709,
#  'five': 710,
#  'knew': 711,
#  'bags': 712,
#  'stick': 713,
#  'twist': 714,
#  'flashlight': 715,
#  'moving': 716,
#  'sex': 717,
#  'useful': 718,
#  'complete': 719,
#  'machine': 720,
#  'rubber': 721,
#  'suspense': 722,
#  'party': 723,
#  'fans': 724,
#  'local': 725,
#  'sets': 726,
#  'remember': 727,
#  'wash': 728,
#  'daughters': 729,
#  'simply': 730,
#  'previous': 731,
#  'safe': 732,
#  'garage': 733,
#  'stop': 734,
#  'brands': 735,
#  'starting': 736,
#  'write': 737,
#  'page': 738,
#  'pay': 739,
#  'taste': 740,
#  'waist': 741,
#  'grandson': 742,
#  'legs': 743,
#  'sad': 744,
#  'sony': 745,
#  'historical': 746,
#  'realistic': 747,
#  'wanting': 748,
#  'cheaper': 749,
#  'normally': 750,
#  'men': 751,
#  'waste': 752,
#  'age': 753,
#  'tiny': 754,
#  'number': 755,
#  'worry': 756,
#  'supposed': 757,
#  'cord': 758,
#  'bulky': 759,
#  'waiting': 760,
#  'imagine': 761,
#  'today': 762,
#  'american': 763,
#  'build': 764,
#  'fairly': 765,
#  'girls': 766,
#  'cards': 767,
#  'variety': 768,
#  'human': 769,
#  'glass': 770,
#  'happen': 771,
#  'learning': 772,
#  'please': 773,
#  'throw': 774,
#  'pants': 775,
#  'smooth': 776,
#  'tree': 777,
#  'group': 778,
#  'sensitive': 779,
#  'belt': 780,
#  'humor': 781,
#  'fiction': 782,
#  'band': 783,
#  'tank': 784,
#  'oh': 785,
#  'table': 786,
#  'sexy': 787,
#  'service': 788,
#  'otherwise': 789,
#  'quiet': 790,
#  'hole': 791,
#  'feeling': 792,
#  'adjust': 793,
#  'portable': 794,
#  'hear': 795,
#  'superb': 796,
#  'actors': 797,
#  'holes': 798,
#  'cast': 799,
#  'headphones': 800,
#  'summer': 801,
#  'face': 802,
#  'kindle': 803,
#  'storage': 804,
#  'travel': 805,
#  'detail': 806,
#  'powerful': 807,
#  'gloves': 808,
#  'walk': 809,
#  'secure': 810,
#  'guys': 811,
#  'wears': 812,
#  'writer': 813,
#  'noticed': 814,
#  'speakers': 815,
#  'plenty': 816,
#  'volume': 817,
#  'assemble': 818,
#  'heavier': 819,
#  'remote': 820,
#  'twice': 821,
#  'wooden': 822,
#  'zipper': 823,
#  'sons': 824,
#  'save': 825,
#  'base': 826,
#  'stuck': 827,
#  'lock': 828,
#  'sit': 829,
#  'mm': 830,
#  'chemistry': 831,
#  'leather': 832,
#  'sent': 833,
#  'art': 834,
#  'ways': 835,
#  'cups': 836,
#  'including': 837,
#  'choice': 838,
#  'screws': 839,
#  'means': 840,
#  'flat': 841,
#  'check': 842,
#  'unfortunately': 843,
#  'wow': 844,
#  'added': 845,
#  'seeing': 846,
#  'immediately': 847,
#  'finding': 848,
#  'drill': 849,
#  'classic': 850,
#  'board': 851,
#  'scene': 852,
#  'seller': 853,
#  'early': 854,
#  'office': 855,
#  'straight': 856,
#  'mouse': 857,
#  'arc': 858,
#  'finished': 859,
#  'moments': 860,
#  'pockets': 861,
#  'sink': 862,
#  'note': 863,
#  'wire': 864,
#  'films': 865,
#  'pros': 866,
#  'plan': 867,
#  'negative': 868,
#  'flimsy': 869,
#  'description': 870,
#  'ends': 871,
#  'sides': 872,
#  'attention': 873,
#  'discount': 874,
#  'lamp': 875,
#  'mat': 876,
#  'th': 877,
#  'handy': 878,
#  'vacuum': 879,
#  'pricey': 880,
#  'behind': 881,
#  'gotten': 882,
#  'chewer': 883,
#  'pick': 884,
#  'unless': 885,
#  'paid': 886,
#  'option': 887,
#  'helpful': 888,
#  'ride': 889,
#  'fire': 890,
#  'normal': 891,
#  'john': 892,
#  'hero': 893,
#  'suction': 894,
#  'bra': 895,
#  'lb': 896,
#  'booki': 897,
#  'accurate': 898,
#  'ice': 899,
#  'snug': 900,
#  'available': 901,
#  'games': 902,
#  'chain': 903,
#  'female': 904,
#  'adapter': 905,
#  'puzzle': 906,
#  'hour': 907,
#  'usual': 908,
#  'shot': 909,
#  'hat': 910,
#  'certainly': 911,
#  'smart': 912,
#  'protect': 913,
#  'jeans': 914,
#  'package': 915,
#  'noise': 916,
#  'stiff': 917,
#  'usa': 918,
#  'pads': 919,
#  'yellow': 920,
#  'mean': 921,
#  'construction': 922,
#  'rating': 923,
#  'provided': 924,
#  'hooked': 925,
#  'leash': 926,
#  'properly': 927,
#  'filled': 928,
#  'deep': 929,
#  'learned': 930,
#  'plug': 931,
#  'chew': 932,
#  'bar': 933,
#  'daily': 934,
#  'returned': 935,
#  'lab': 936,
#  'connection': 937,
#  'xl': 938,
#  'bowl': 939,
#  'granddaughter': 940,
#  'alone': 941,
#  'pump': 942,
#  'taken': 943,
#  'mostly': 944,
#  'compared': 945,
#  'stays': 946,
#  'pet': 947,
#  'details': 948,
#  'crazy': 949,
#  'tape': 950,
#  'missing': 951,
#  'everyday': 952,
#  'paint': 953,
#  'weather': 954,
#  'cleaning': 955,
#  'sizes': 956,
#  'spend': 957,
#  'slip': 958,
#  'annoying': 959,
#  'sleep': 960,
#  'press': 961,
#  'push': 962,
#  'readi': 963,
#  'mess': 964,
#  'walking': 965,
#  'prefer': 966,
#  'realize': 967,
#  'performance': 968,
#  'narrow': 969,
#  'complaints': 970,
#  'likable': 971,
#  'fell': 972,
#  'heard': 973,
#  'brother': 974,
#  'cons': 975,
#  'typical': 976,
#  'science': 977,
#  'worried': 978,
#  'green': 979,
#  'german': 980,
#  'pro': 981,
#  'turning': 982,
#  'stretchy': 983,
#  'hang': 984,
#  'condition': 985,
#  'test': 986,
#  'except': 987,
#  'sounds': 988,
#  'unbiased': 989,
#  'painting': 990,
#  'height': 991,
#  'runs': 992,
#  'recently': 993,
#  'tough': 994,
#  'saying': 995,
#  'ms': 996,
#  'somewhat': 997,
#  'rate': 998,
#  'datahookproductlinklinked': 999,
#  'lead': 1000,
#  ...}

# %%
reviews_data['label'].unique().tolist()
# Out:
# [0, 1]

# %%
y_train = reviews_data['label']
y_train = y_train.values.reshape(-1,1)
# y_test = y_test.reshape(-1,1)

print("y_train shape:", y_train.shape)
# Out:
# y_train shape: (40432, 1)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(x_train,y_train, test_size = 0.2, stratify=y_train,random_state = 42)
X_train.shape
# Out:
# (32345, 150)

# %%
# !wget http://nlp.stanford.edu/data/glove.6B.zip
# Out:
# --2022-11-22 04:14:43--  http://nlp.stanford.edu/data/glove.6B.zip
# Resolving nlp.stanford.edu (nlp.stanford.edu)... 171.64.67.140
# Connecting to nlp.stanford.edu (nlp.stanford.edu)|171.64.67.140|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://nlp.stanford.edu/data/glove.6B.zip [following]
# --2022-11-22 04:14:43--  https://nlp.stanford.edu/data/glove.6B.zip
# Connecting to nlp.stanford.edu (nlp.stanford.edu)|171.64.67.140|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://downloads.cs.stanford.edu/nlp/data/glove.6B.zip [following]
# --2022-11-22 04:14:43--  https://downloads.cs.stanford.edu/nlp/data/glove.6B.zip
# Resolving downloads.cs.stanford.edu (downloads.cs.stanford.edu)... 171.64.64.22
# Connecting to downloads.cs.stanford.edu (downloads.cs.stanford.edu)|171.64.64.22|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 862182613 (822M) [application/zip]
# Saving to: ‘glove.6B.zip.1’
#
# glove.6B.zip.1      100%[===================>] 822.24M  5.02MB/s    in 2m 39s
#
# 2022-11-22 04:17:22 (5.17 MB/s) - ‘glove.6B.zip.1’ saved [862182613/862182613]

# %%
# !unzip glove*.zip
# Out:
# Archive:  glove.6B.zip
# replace glove.6B.50d.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
glv_emb = open('glove.6B.100d.txt', encoding='utf8')

# %%
embeddings_index = {}

for line in glv_emb:
    values = line.split()
    word = values[0]
    vectors = np.asarray(values[1:])
    embeddings_index[word] = vectors
        
glv_emb.close()

print('Found %s word vectors.' %len(embeddings_index))
# Out:
# Found 400000 word vectors.

# %%
#verifying how glove behaves if out of vocabulary is given
embeddings_index.get('recommend').shape

# %%
tokenizer.word_index.items()

# %%
#Finding out of vocabulary words
word_vector_matrix=np.zeros((vocab_size,100))
for word,index in tokenizer.word_index.items():
    vector = embeddings_index.get(word)
    if vector is not None:
      word_vector_matrix[index]=vector
    else:
      print(word)
# Out:
# Streaming output truncated to the last 5000 lines.
# poucha
# hrefgetnakedlowcaloriedentalchewsticksfordogssmallouncestickspackdpbaylnurefcmcrarpdrvwtxtieutfget
# smallounce
# stickspacka
# hrefnboneoralhyginetwistixtwestedstickdogtreatssmallozdpbwflonarefcmcrarpdrvwtxtieutfn
# hygine
# twistix
# twested
# ozanbspand
# hrefbluebuffalominibluebonesnaturaldogdentalchewsdpbbzqbkrefcmcrarpdrvwtxtieutfblue
# chewsa
# bottlemy
# bottlewe
# hrefosteraturbospeedprofessionalanimalclipperdpblrnarefcmcrarpdrvwtxtieutfoster
# clipperanbsphas
# mynbspa
# hrefandiseasyclipproanimalpiecedetachablebladeclipperkitpetgroomingmbgdpbutforefcmcrarpdrvwtxtieutfandis
# easyclip
# humanhome
# highestend
# hrefwahlprofessionalanimalstainlesssteelguidecombsdpbrbwlgrefcmcrarpdrvwtxtieutfwahl
# knowmy
# itemthis
# clothcovered
# downanyway
# trackout
# puppiesdogs
# worsecat
# digestionmy
# idvideoblockravfnw
# heightsize
# tonbspa
# anbspfor
# clefthoofed
# anbspinstead
# worksworkedetc
# ownerthis
# elsethese
# rainthe
# wellbehavedmy
# antichlorine
# agaefix
# againas
# fountainit
# strictmy
# watchednbspa
# hrefameliadpbsloprefcmcrarpdrvwtxtieutfameliaanbspon
# idvideoblockrmehzybglcv
# glasstitanium
# habitsmy
# treatsi
# earthfriendly
# diapersi
# babygate
# prduct
# reviewrating
# domedfront
# antiemetics
# tbonz
# threwup
# spanielmix
# giveortake
# threestep
# cratethis
# twopack
# onepack
# shreddingtearing
# doesi
# rabbitmousefieldrat
# preventic
# basisi
# reviewsin
# cuttersimply
# filtersi
# backmy
# cfuv
# primmer
# trqumatized
# bydns
# hrefomegapawtrickytreatballdpbdkmrefcmcrarpdrvwtxtieutfomega
# tinlike
# antislideantiskid
# indipets
# reviewermost
# noisiness
# durableworks
# greatour
# imitationknockoff
# softflex
# refundmy
# apartmy
# presized
# behaviori
# hooflex
# horseshoers
# hoofrelated
# acides
# pulloff
# scratchesshakes
# foodthe
# bellrock
# overwatered
# wholesaled
# antidig
# ebeta
# thitd
# everafter
# thankssherry
# intriging
# noraffilte
# breenaes
# autora
# fernandas
# hartnady
# weekhave
# definatly
# amaizing
# trenier
# almostlike
# unusua
# writtenpulled
# delevershams
# growwas
# storynovella
# jasinda
# styleits
# chisholms
# meryton
# suspensful
# endabout
# differentand
# whodoneit
# kadence
# needsto
# linegood
# teay
# tierna
# vinienne
# romntica
# predecible
# shiftervampire
# wouls
# forgivenesss
# condorspirit
# aurthor
# morningthanks
# storiesbut
# yesssss
# militarytype
# motherthe
# braydons
# themewell
# greatbook
# threenot
# muchit
# slowwith
# seriesit
# brendons
# brotherstheir
# goodcharacters
# backbonelove
# mysteryromance
# encontrars
# bearfield
# intriga
# suspenso
# hildebrands
# rememberthat
# bridenapping
# perspectivei
# addae
# leerlo
# engancha
# recomendado
# megapacks
# freei
# pstec
# dericci
# speshly
# didit
# linechampion
# exhilaratinglove
# esasy
# facethis
# icluding
# readenjoyed
# readingcharacters
# bookkept
# endcannot
# autbor
# typoerrors
# emulsfying
# developedpoor
# froggie
# writted
# ninie
# turnerbut
# adamss
# damnhad
# uncertiny
# bodiceripper
# bighter
# beaston
# characterswell
# writtenwould
# timepages
# debiera
# tomarla
# perderse
# marquie
# aporta
# storyadventurous
# storyall
# scanguard
# goodgrammargoodsense
# divertidisimo
# magistralmente
# creditnot
# testiment
# sugestions
# esenario
# judgementalthe
# floridawise
# teammoniandomega
# tahani
# awesomecharacters
# intertaining
# morethat
# withmystery
# romanceaction
# charactersgreat
# dpwn
# lovewhat
# postapartheid
# evvie
# teai
# tearyeyed
# dragonfury
# coreenes
# inconclusion
# dwel
# nadjas
# sidebut
# lexs
# denisty
# natalies
# dayit
# vivs
# reasoners
# moneybut
# storylinejust
# readingjust
# affairsi
# storynot
# thirtiesbut
# shyt
# bookespecially
# storiesnovellas
# iove
# acontecimientos
# involucrar
# secundarios
# moneygreed
# ericthey
# manloved
# gessilyn
# toooo
# sommerland
# bruuuh
# awwwwww
# comming
# jerra
# diddyshe
# waching
# fictionscience
# killingsdirty
# diesno
# characterslots
# doctorsread
# exarmy
# didint
# kalnay
# slove
# ghosttype
# curvyfigured
# suspensefilled
# putneys
# encontrarse
# encarcelada
# babysitte
# lilke
# graisons
# fallons
# kiplings
# bookplease
# pleasehurry
# hisher
# accesible
# lessman
# taideni
# sawyeri
# storhy
# welldevelopedthis
# islooking
# didwow
# absouletley
# readwould
# quicki
# zabria
# treathoping
# compellingeverything
# amaterurish
# rageand
# feeing
# mysreery
# bookbut
# justdifferent
# tensionthe
# lovethe
# smokesit
# awesometotally
# creativityoh
# bookmeantime
# booksand
# rereadthe
# slades
# tiffanys
# readersbut
# albrincks
# saywhat
# usthis
# alexxs
# malaprops
# withher
# unyeiding
# symones
# crixus
# caisen
# allegras
# thoughtthe
# wellconnected
# suspenful
# sweetshifter
# storiesstraight
# neaty
# griddy
# omwu
# friessen
# rollerco
# eightnovel
# farevery
# fsog
# writtenyou
# dutchs
# bytch
# cryinglaughing
# comicas
# maravillosos
# atrapa
# greybear
# dunnit
# diety
# blays
# mercuris
# freaken
# amazingeverything
# lucyethel
# betterhe
# yess
# blockka
# ageplay
# bookshe
# insaecurity
# dixiedixon
# appearred
# katts
# oldestbut
# romancelove
# ndea
# vday
# sennah
# hotsteamy
# intenseintriguing
# aimeewell
# turnerhard
# booksprout
# yeagar
# totaly
# cindys
# lyssandras
# perfectespecially
# mallorys
# knighthorse
# mysteryloved
# offchris
# unravelthis
# withlings
# readyforanything
# tommys
# bookloved
# spellcheck
# selfopinionated
# aaliyahs
# jvion
# agendastheir
# recomment
# wowwhat
# shadowcatcher
# pjparrish
# minifarm
# feetawesome
# warravaged
# airus
# answears
# hearbreakingly
# miixed
# danais
# wowzers
# ashed
# isnbspa
# hrefcinderellageekdprefcmcrarpdrvwtxtieutfcinderella
# geeka
# selfpublishing
# storymystery
# jennas
# misprinting
# smoof
# mildep
# kilough
# vampirehuman
# bookno
# sssssssstace
# roughohbugger
# endingtwisting
# hmmmmmmgrab
# stivali
# liveloveloved
# linewe
# therea
# butjust
# predicateble
# availablethis
# handyit
# vivianyour
# aetheral
# sonstreet
# muscian
# offtoo
# definitelyi
# beeven
# exlover
# southworths
# raspbody
# longercant
# deliemas
# chanceis
# sydneys
# teacherstudent
# krustaez
# simplebasic
# thenbut
# throughouti
# pettifor
# storyfirst
# desertsall
# lifesoh
# aslong
# nealwait
# attitudeyes
# keishs
# edrise
# treston
# maclomain
# sonow
# authora
# nicholass
# missionall
# zenina
# grgrandson
# maclarens
# shirleen
# kincaids
# navada
# rasleys
# betterwhat
# annamae
# howeys
# angstfree
# rickjordan
# himthere
# owyn
# siblingspolygamous
# corsonknowles
# sisterbig
# rissoli
# teenshe
# niecey
# mykell
# ramons
# windedand
# kerrigans
# uuuhhhhhh
# werebear
# againsalami
# ferraros
# meby
# emotionly
# emergance
# followable
# hushhush
# hercreepyor
# reunionhot
# timestimes
# brandys
# readingwaiting
# ownermanager
# cammile
# worthcannot
# enforcementibid
# mustreadon
# exdividend
# wolfhero
# andexcellent
# maravillosame
# amorcantada
# contejo
# goodyou
# sydlynn
# herhow
# mindfulnessbased
# arikeels
# grovels
# chicknothing
# tgis
# readim
# lils
# siher
# sters
# comedyit
# mindfull
# happinessfor
# livvy
# mischevious
# otk
# conviences
# waitthere
# yepi
# rachelfor
# couldshould
# sightthe
# pseudoparental
# lifedreams
# filmaking
# selectionsand
# kolee
# sexsigh
# mcnares
# goodlots
# kidsoh
# boyyou
# bartal
# meanswhich
# headtripping
# aliomenti
# shelleyi
# wtg
# inand
# muchthe
# amaazing
# addcited
# casstiel
# olivias
# grossmammi
# intoand
# ajaxumyeah
# ladieswe
# townand
# herothe
# squeeeeeeeeeei
# seriesfantastic
# cecy
# chaptersespecially
# storyfast
# meacutenage
# ffmf
# longerscurries
# nolas
# studiocool
# chemistryswooney
# zaraiah
# scalzis
# beaudelaire
# airlea
# therepist
# chemestry
# airleas
# attitide
# bladons
# mindfck
# sophias
# deltaburly
# takenoprisoner
# capshured
# pirits
# jav
# izafter
# fantasyparanormal
# beingscreatures
# dugoni
# sympathyand
# evanovitch
# hrefthewidowsrevengedpbgemcprefcmcrarpdrvwtxtieutfthe
# revengea
# divorcesat
# treatslectures
# allyns
# boribgvworld
# erotism
# kellens
# afghanstan
# backtoback
# arabellabob
# killiyama
# sardelle
# gwenvale
# dagmars
# celwyn
# anwyn
# yunglit
# awwwww
# brightley
# brightleys
# fartcs
# piecestcs
# couragefemale
# bagin
# trulie
# shorteasily
# devestated
# sittingi
# harlows
# noxs
# gordonlevitt
# theneditor
# thendeputy
# oneday
# laughoutaloud
# struggledenialmistrustcompelling
# thereu
# centurys
# meatbased
# dabelard
# impetous
# dolike
# hanleys
# bikericeand
# nates
# relativel
# granolay
# oversharing
# mzc
# soanother
# richies
# dohis
# versionnbspa
# hrefmansfieldparkdprefcmcrarpdrvwtxtieutfmansfield
# superflu
# werenot
# politicalmilitary
# howby
# helpbut
# serveup
# mowdown
# jesss
# screenthis
# hmmmmmm
# demonhunters
# strengthpower
# pyramiding
# businessminded
# jelousy
# onebecause
# tijan
# analise
# inaya
# portershe
# platypires
# consenquences
# readsobs
# cayson
# trinitys
# reccommend
# tergonian
# lovelove
# bookhighly
# allytastic
# onnbspa
# hrefspiritfilledkindledpbhburefcmcrarpdrvwtxtieutfspirit
# kindlea
# olearys
# threequarters
# mellington
# reviewtanner
# groaningly
# errorwrong
# wordlack
# pluraletc
# seriesthere
# meetfireworks
# bentini
# suble
# copyeditor
# everythinglove
# hrefbrigittamoondpbdxtdvrefcmcrarpdrvwtxtieutfbrigitta
# moona
# lanr
# abbys
# instaspark
# seriouslythis
# drakka
# cravingis
# stupendousuntil
# lossemptinessconfusionloneliness
# providesget
# itbecause
# emilys
# swimmed
# wordsmisused
# brokeni
# itwhen
# cynthias
# eroticai
# ksmooth
# teenyoung
# wellthought
# dirtytalking
# tatted
# voxleys
# corgans
# yemelean
# wowzer
# siden
# bels
# navelgazing
# facetoface
# havenoah
# secondchance
# unforgivableand
# khis
# jourfin
# kaedees
# creepsomething
# sloans
# reviewsthis
# mccafrey
# paranormalthis
# booktime
# mcclintocks
# codys
# willamae
# cinderfella
# afterwhether
# felans
# photoshopi
# rylon
# qualitysmokin
# nickis
# davinas
# loversi
# nurians
# plaging
# sicariussicariusness
# sightone
# amandas
# monthsthis
# desolator
# kirpalani
# kurious
# readbecause
# translater
# belador
# evalle
# againoff
# othersthe
# tragedys
# linethis
# developmenti
# alessandres
# andee
# profitthe
# characteri
# pleeeaaasssssssseeeeee
# gretchens
# paranormalshifter
# authormuch
# emotionssome
# legalgrayarea
# worldsomething
# readand
# burnz
# recieves
# libbys
# lovedshe
# townfolki
# demoshe
# overthen
# tourthat
# nolens
# apocalpse
# hapen
# invloved
# affairswhat
# copfirefightergeneric
# seacrets
# digure
# atrong
# decruyenere
# imoortant
# mandaline
# psyic
# endconsidering
# ellies
# bathroomand
# incher
# revisedfall
# nexta
# trueax
# lovei
# amazonca
# summertimes
# knowstart
# againawesome
# magicits
# yaaaaaaaaaayyyyyy
# beginnerthe
# jenasbookreviews
# knoxs
# carrignton
# ocassions
# sammys
# markinsons
# kellisamberlee
# werecattiger
# controlhandle
# movethis
# humansthis
# carlan
# smartmouthed
# bestfriend
# deshydratation
# gathrered
# reviewreviewed
# compaired
# thoughtout
# cixin
# threebody
# weeksbut
# muchugh
# hidingthe
# macgyvershe
# stadiumnot
# tudawgs
# distractingconfusing
# stalkerish
# oneliner
# tibbitts
# basiliuss
# peoplespecies
# lezare
# themesromance
# rierdane
# valethe
# spokeyeah
# slaveanother
# disclosureas
# britishnigerian
# dialectsaccents
# wordsphrases
# merissa
# feudscause
# krystals
# girlsand
# havewrittenabooknowwhat
# bombays
# drunkest
# andreis
# mafiaorganized
# tiredbut
# predicatable
# isthen
# fastpacededge
# dangerwhere
# middlebeginning
# underhandedness
# dragonstyle
# greatgrandmother
# highstatus
# sulty
# chelseas
# houseboys
# hangingi
# occulthorror
# donemega
# speciali
# fastforward
# lewiss
# dissappoint
# winsom
# farendale
# enoughoh
# noher
# falcot
# marriagebasically
# strongminded
# eshe
# theeesome
# footbinding
# buktus
# nefertitis
# fetishy
# fifteenminute
# wellchosen
# kammie
# fleixs
# fabergeacute
# elsewhat
# potentialbut
# excellentyou
# storyone
# becausewhat
# nowwho
# thereplus
# irmc
# hvz
# societyhaunted
# shadowhaunted
# wrongagain
# natayla
# alecs
# moonredstar
# interation
# eath
# oteh
# vpowerful
# sisland
# malcolms
# welovekinkdotcom
# mcgreers
# lovescan
# tstl
# dayreader
# reviewit
# faithe
# simones
# jessicas
# volthooms
# reright
# blaines
# baeli
# favoritesthis
# momentsthis
# elodies
# oceanias
# fivepart
# fluwith
# cytokene
# kingsthe
# standworked
# immari
# kneupper
# genomancer
# biogenetics
# medeas
# vonbrandt
# vonbrandts
# dammmnnnn
# tramas
# grisgris
# proofer
# writtenedited
# dungeonsanddragonstype
# nonplayercharacters
# reat
# daryls
# deleverso
# eightpart
# autobuy
# happensthis
# unknownsbut
# himmiranda
# selenas
# polyforms
# enjoyability
# semicrazy
# couldwould
# bryces
# warningyou
# abrigo
# malmborgs
# lowstakes
# martialarts
# buttkicking
# innermonologues
# yeagernot
# spoilersbut
# itempting
# fiancei
# exhusbands
# explaination
# phoebes
# altobellis
# spritelike
# urgggg
# shownshared
# bookbooks
# dellosso
# dissapear
# hrefthepianoitspurchaseandcaredpbaosfjyrefcmcrarpdrvwtxtieutfthe
# carea
# lucianos
# coltbut
# obran
# techoriented
# vocabularywise
# acceptablebut
# exsistsshe
# eitherhe
# meetto
# moneyhe
# doesnther
# moneyhis
# masoor
# paustik
# andvegetable
# toher
# peerfect
# angstcheck
# mencheck
# sexcheck
# entresss
# himselfa
# malebut
# hackingai
# smexiness
# vampchick
# wiedmeier
# midshift
# asimovs
# jonathas
# manthis
# strongwill
# afxisi
# korbai
# motherfatherbrother
# caitrina
# sportochicksmusings
# cring
# doughhead
# faboulos
# mysterythriller
# ashers
# lovelyand
# wildehmmm
# yuckiness
# goea
# authorjulie
# keiths
# livesbecause
# realtionship
# nerdville
# mcdare
# fove
# posessive
# lilianas
# sleezy
# filterso
# tripi
# hmmmi
# ceony
# studentteacher
# excellwent
# tantilise
# sabrinas
# subteens
# brothelescort
# skyped
# keelins
# hopeyou
# babesi
# peggys
# selfcontrol
# wellplanned
# keptmeupreadingallnight
# griffs
# againbut
# fairytail
# sevenyearold
# lukana
# spirita
# hartling
# romancechick
# misusedtypod
# selfpubbed
# naughtyraunchyhystericalsweetmostofalldirty
# pulsepounding
# romanceaholic
# jessies
# wiers
# shortstory
# hubbywatchingwifeflirtinginabar
# riskandreward
# ironclaws
# quietstronghandsomeshy
# cappys
# chaters
# linuss
# airika
# hospitaloffice
# obstaclesadam
# livesays
# aspergers
# nemuri
# usand
# ronnell
# dporter
# caths
# robbedcheated
# trabsolutely
# aack
# thayen
# stylos
# housealibi
# shasa
# welleducated
# grammartype
# wouza
# daryk
# beautifullywritten
# agehow
# oneonone
# moellers
# frostborn
# shouldnt
# tofind
# theevil
# arival
# mcthe
# chicagoa
# fatherwell
# trueit
# casss
# bookgrind
# nicoles
# wellappears
# clientbydefault
# lapbut
# mindys
# joels
# doneor
# oldwell
# einherjer
# husbandfathers
# ninetyseven
# charlenes
# dayam
# kemmerers
# conflictromance
# othersor
# kysons
# hillarious
# teammaters
# fks
# tbqs
# novelnot
# eyesetc
# meetshe
# dramahe
# protectsthey
# sexher
# againthere
# sexthen
# latereither
# togethernone
# ronans
# vessa
# corbit
# twobook
# fernandos
# vinnies
# assery
# portrail
# teagans
# friendcoworker
# serenadeswoon
# somethingpure
# thisdark
# satisfyingthe
# thatbecause
# darmackenzie
# juliens
# landgrabbing
# couplethis
# bereaves
# inconspiciousness
# shawntelle
# romancesthis
# cliffhangeri
# strangermr
# katys
# skygod
# kelsye
# daphnes
# kissesoh
# selfassertive
# topsyturvy
# retchet
# annora
# okthey
# bookseries
# bourbonville
# caroles
# wynters
# sylvans
# kaceys
# colieded
# carmodys
# petken
# embarasses
# netgalleycom
# trendl
# geekyness
# blatent
# mentuons
# intrest
# concieving
# rereadable
# auntiehood
# faade
# nondating
# fantasytime
# occjd
# pacificans
# pararescuer
# deleuzes
# zekes
# lilliana
# hypersleep
# lifeand
# sexwhen
# costumesa
# pepperton
# wolffs
# allconsuming
# repetitivechloe
# reallllly
# bloodlings
# mikas
# jenns
# kinlock
# arizonas
# scorchin
# trenham
# onenighter
# thirtyfour
# dereks
# shadrak
# liche
# blightey
# ilesa
# shapeshiftingillusion
# selfneed
# sportochicks
# dekierans
# haarb
# verdantian
# dealbero
# veacon
# blogi
# avelyns
# fourpart
# sonnick
# instalust
# rightoff
# seriesbook
# compasss
# techmagic
# purman
# workplaceoffice
# coowner
# thirtyone
# shawnas
# wittiness
# dewintons
# dewinton
# allbusiness
# inkmonster
# rahakok
# saythe
# listmania
# toguides
# twostar
# selfpromotions
# pagesthis
# roxys
# theshortreviewerblogspotcom
# foryou
# squicked
# wifeinlaw
# motherinlaws
# buckwine
# lanceso
# laterdaym
# therei
# gideonhe
# zanei
# vamplove
# piei
# mannnn
# tanyatanya
# princewho
# brants
# shifterswhoaaaa
# thatkeep
# barners
# foreal
# georgettes
# meachys
# brielles
# netgally
# oohhhh
# stuckup
# moremaybe
# nogooddoer
# dominantsubmissive
# fetlife
# reveiw
# flove
# tashas
# scense
# luckys
# mrsconditreadsbooks
# comindex
# easytofollow
# testtaste
# brothe
# lierally
# handsy
# kians
# forwarx
# chayot
# halftamed
# lousisanna
# dacy
# welovekink
# melini
# talesi
# aririely
# athenadenali
# dayneshacesar
# questionwho
# whimi
# startsand
# timechunks
# omghow
# hollys
# helpif
# forauthor
# werewolfs
# fantasymagic
# magicfantasy
# withit
# selftalk
# furtherif
# crimeit
# yeswe
# selflove
# upwe
# hrefimnotperfectanditsokaydpbegpizsrefcmcrarpdrvwtxtieutfi
# okaya
# memorys
# allistair
# hokay
# kieras
# endingit
# importexport
# wandas
# mensforth
# smashwords
# arlena
# omgthat
# frohoff
# carrigans
# amazonwarrior
# gaylesbian
# wellwhat
# beforeslept
# wasromantic
# hearta
# twistshe
# relationshipafter
# itafter
# deadwow
# nextno
# doctorto
# beccas
# thingthen
# enstallment
# yourseld
# pearces
# mexr
# rehzs
# welltodo
# stressless
# libbies
# paasch
# damians
# sistercousin
# alavar
# kellans
# ensconcing
# neanderthalithic
# timesyesi
# repetitivenot
# headso
# nowthey
# femalesdominant
# triadgive
# unenjoyablei
# troisromance
# womanthis
# wowser
# reegan
# reegans
# newonthescene
# trajean
# offthecharts
# isobels
# funnyit
# coupledom
# unequalthere
# gutwrenching
# itokay
# leilathe
# upjackson
# slooooooow
# awworthy
# freethis
# worksinprogress
# hotthencold
# seths
# mccade
# devlins
# smilingi
# awesomeexcitingraptouroussp
# livesher
# contentbut
# chptr
# chptrs
# yourselfbut
# charactersfrom
# tyrones
# domsub
# steamyiexclkiexclkiexclkiexclkiexclk
# assanine
# isaiahiexcls
# doesniexclt
# heiexcld
# thereiexcls
# youiexclre
# hallidays
# romanceserial
# mhisery
# ageold
# portias
# horrorsupernatural
# recentlydeceased
# onetrackmind
# thrilleradventuremilitary
# audiobookreviewer
# afotama
# adrenalinepacked
# disappointshe
# soooooooooo
# readtoreview
# kreisman
# timetravelcomingofage
# jumbuck
# ryshia
# kennie
# iteam
# romanticfunny
# readingand
# rereadingdyers
# endingvery
# anothergreat
# middleearth
# trimly
# thepast
# talesinteresting
# httpbooksandbarrels
# comrosesleilameacham
# readingalways
# nesboll
# downbrilliant
# readrecommended
# readreally
# colwin
# meonly
# myselfnot
# grandchildrens
# endwas
# movingyou
# goodnot
# funnythe
# bonebrave
# understandvery
# maizie
# pullitzer
# recylerviews
# agesvery
# slowforced
# readone
# heartthis
# loooved
# fascinatingreally
# mankindwhy
# thirdperson
# bookeven
# bookshots
# cosidering
# authorshe
# stopa
# favority
# prattchett
# satisfys
# pinkalicous
# allfast
# ncav
# recommendlooking
# interestingvery
# crichtons
# anyonecan
# jeopardyand
# holmeseque
# seatas
# beleavable
# fashiondesigners
# bookalready
# familyfirst
# wimans
# entertainingyou
# bookhave
# ubdoubtably
# seroes
# readingthis
# raneys
# touchingreally
# pleasureso
# entertainingsuch
# coversationsand
# bolitar
# shenaneginsgreat
# excellentcannot
# gamachebeauvoir
# lowells
# scoopes
# heartstopping
# booksihave
# noncohesive
# stillereddie
# seriesenjoyed
# themlots
# kristans
# differenet
# copywrite
# worldbulding
# loveed
# versin
# amust
# anyoneespecially
# leding
# todayanother
# romancejust
# readhave
# dday
# ssymmer
# prevoking
# dalllas
# matesexybreasted
# lchose
# leadersi
# itdanielle
# twoyear
# interestthe
# irvings
# oftrepeated
# voicespoints
# originalally
# welldil
# classesleaders
# zamazimngly
# readreminds
# mitchner
# vowells
# enjoyablestayed
# kidi
# worksheetsthey
# yourselfvery
# solang
# dominics
# studets
# lotu
# pseudointerviews
# devinci
# handprovided
# uou
# endersgame
# endbut
# worldi
# charlieandthechocolatefactory
# nonexpert
# pinkers
# wendigs
# iloved
# jemisin
# walshs
# cashore
# gooda
# thoughtfulrespectful
# mysteryd
# arqueolgica
# llen
# enlighting
# gladwells
# wites
# hollywoodbilila
# trigianis
# peopleeven
# maggies
# clussler
# falcontry
# horsestories
# caseys
# initiatiors
# encrossing
# bookright
# americani
# preggers
# sinklair
# betsys
# protesant
# mysteriesbut
# snufftoo
# infrastructurei
# etclol
# nightwalker
# amazingand
# recommendedan
# ilonas
# booksk
# taraborrellis
# houcks
# chrstmas
# hecticness
# presnt
# facinating
# comparion
# tabloidish
# recordtime
# deckerrina
# starteven
# wantneedto
# austn
# malarky
# natzi
# boilernone
# actionwell
# writtenand
# dietin
# woweasy
# nroberts
# interestvery
# grandchildrengreat
# perfectgot
# cymbalas
# gobis
# anticoal
# heroinei
# booklove
# whisprey
# dialoge
# specialistlibrarian
# illustrationswonderful
# longthere
# kingit
# bookes
# lahayes
# angelous
# tinaif
# releasehmmm
# andfunny
# detailsi
# worldthrough
# aherns
# riordian
# serously
# wthe
# kerrelyn
# trsnslations
# felixs
# actiongood
# spievack
# scarilycurrent
# riyria
# lashner
# ondaatjes
# mansons
# notsosmall
# researchy
# prakenskii
# sitchins
# fuhrmans
# languagegreat
# histoically
# turabian
# niecesnephews
# weeklike
# extactly
# writtenpages
# oneaday
# salesy
# thinnk
# equilly
# downunbelievably
# stpehen
# tanj
# padrick
# bookif
# prineas
# programmerhacker
# huffpo
# crisisa
# heartvery
# doyou
# yhe
# bookhope
# auful
# naugh
# jjt
# alwaysgreat
# readnothing
# debonairgreat
# texass
# sciencyfictiony
# myoshi
# pnly
# folletts
# againor
# bachlorette
# outexcept
# bookmy
# wallender
# succeding
# multilay
# kingslover
# niccolograve
# recommendan
# holacaust
# helperteachercaregiver
# thkn
# racismi
# draanen
# sammitriffic
# seriesas
# manthe
# readinteresting
# consciusness
# seriesno
# precollege
# auggies
# mudt
# cinderellaisabella
# ballbut
# princeprincess
# heartpounding
# rereaders
# karons
# leibovitzs
# wroughtiron
# allupper
# femalethere
# paleotype
# outfrom
# boringi
# writingand
# storytrue
# usaussr
# coldwar
# broshs
# karenia
# cialdinis
# strayeds
# selfdeprecation
# formakes
# preceived
# vunerable
# situationsset
# porgressed
# pennys
# indianpakistani
# publishready
# tiredespecially
# trashout
# belowthesurface
# nowill
# helpprotection
# quickturnaround
# followon
# penguine
# stanny
# characterspretty
# mysterydetective
# karys
# boyfriendafter
# youwill
# fivecourse
# schamas
# orhottesthot
# freemarketers
# despus
# adolescención
# adreno
# detruntar
# whfor
# daykeep
# coatails
# girlbut
# booksas
# happpened
# rons
# writingi
# jonathans
# igguldens
# awh
# dacher
# metoo
# everthe
# frenentic
# carthoris
# familarity
# knowshow
# starsa
# muchmuch
# decied
# trygreat
# allof
# mediumlevel
# megapopular
# grishan
# wouold
# mmy
# detectivesarah
# saltin
# denizensblack
# whiteas
# areand
# betterbut
# flightyou
# scientifichistorical
# reexperience
# greany
# nonwriters
# tanias
# characterssetting
# laughoutlouduntiltearsrundownyourface
# treesharing
# irrating
# cheesie
# lerners
# opras
# dorathea
# mistresss
# josephines
# noviks
# napoleanic
# franscell
# readingthe
# chapionship
# gamebackup
# italyand
# livelyfastmoving
# hilariousgrisham
# artbut
# lightquickand
# neglective
# otherway
# suspisions
# rudethus
# movinghard
# helprins
# giullanis
# writingvery
# compellingdid
# downread
# wildernesscoincidentally
# maybeand
# honestythat
# elisabeths
# factuallybased
# lendable
# lrh
# sluyters
# bookread
# daysbeth
# writerone
# bestthere
# betterhighly
# booksyou
# cookingenjoy
# covertocover
# confidencebooster
# readthrough
# consumeristic
# schoolspreschools
# sawotherwise
# lugavere
# commonfolk
# usedvery
# lifei
# brynley
# stephine
# hampster
# rylynn
# rylynndex
# jordonthe
# alighieris
# landscapesbuildings
# postparis
# kreacher
# attrated
# admitedly
# touchyfeely
# moviequirky
# groupgender
# fatherofthebride
# preachey
# jrrtolkien
# distils
# rylants
# lifeaffirming
# parentsgrandparents
# parentgranddaughterthis
# foolet
# trlogy
# nnovel
# choelhos
# seldons
# torkos
# languge
# informativein
# ripi
# worldmeets
# officil
# steelhearts
# grrm
# playrichard
# iiipublished
# signets
# tenleys
# notsoglittery
# againanother
# dosurvive
# geillis
# carand
# childporn
# villians
# editorbut
# belafontes
# upclose
# childteenager
# thinkingis
# worldsthe
# spiritualfor
# lifecommitment
# emerys
# movebut
# diarys
# booknbspa
# hrefunderstandingtrainofthoughtdprefcmcrarpdrvwtxtieutfunderstanding
# thoughta
# nuttsl
# bleh
# pilotinstead
# clavells
# vampwho
# lovehow
# mcculloughs
# johnandabigail
# wellresearched
# everevolving
# seati
# bookyou
# strectch
# wolfhusky
# wideeyed
# connelleys
# lettersstatements
# unoffical
# trafficing
# beliveable
# jschool
# rachmans
# lindquisti
# dillian
# endand
# allout
# roadmovie
# riddleys
# girlswho
# scarey
# oneil
# childred
# throughtout
# leadi
# gogivers
# settingi
# seriesone
# rolicking
# virustrope
# nienties
# gottliebs
# interestingthis
# wasas
# writingreading
# heartthrough
# megabomber
# davenportthis
# middleend
# guitarcentric
# dayand
# welllaid
# thirdgrader
# confessionthis
# seebachs
# unixmac
# problemsolving
# ataglance
# stasiland
# ddrs
# travalogue
# charecter
# remarkableinspiring
# leightons
# knightleys
# writerhe
# recentered
# southi
# understandability
# rebelious
# treaumatic
# turnssome
# reaaly
# stylethis
# broadstroke
# lienhards
# engineerphilosopher
# ingeniusly
# textreally
# wrongbut
# historiani
# disracting
# rebeccasreads
# presentday
# dirctions
# prechristian
# archtypical
# informationdirection
# factbased
# trumpedup
# repetoire
# followingnbspa
# hrefrabidanoveldprefcmcrarpdrvwtxtieutfrabid
# novelanbspby
# kenyonnbspa
# hrefsexwarsanovelofgildedagenewyorkdprefcmcrarpdrvwtxtieutfsex
# yorkanbspby
# andnbspa
# hreforlandopenguinmodernclassicsdprefcmcrarpdrvwtxtieutforlando
# classicsanbspby
# notsofictional
# oilenergy
# selfidentified
# youbad
# thouroughly
# openuponmydeath
# picassoesque
# homocides
# tostay
# backtogether
# adreneline
# bookexcept
# tryit
# meatandpotatoes
# caralee
# sewalls
# dickinsons
# wellbeaten
# iliked
# anglofrancocentric
# germanaustrohungarianpolish
# zbaraz
# beresteczko
# gypsey
# mankinds
# foleys
# dognapping
# shimfissle
# nonnew
# militaryminded
# heaberlin
# autofac
# rautavaaras
# lmrs
# assighning
# raylands
# hoever
# welltrained
# stehpanie
# wrth
# grapics
# ivyrachel
# justnot
# towho
# ryodan
# lisss
# campanology
# beautifullydrawn
# flewellings
# nightrunner
# bookit
# allnighter
# unlovably
# pettifogging
# chaucerian
# eversoslight
# nonlucrative
# fascintation
# hugettes
# authorpublisher
# shdaar
# geobobspinellidotblogspotdotcom
# strangersin
# morpurgos
# littledifferent
# asajj
# vosasajj
# truei
# agamemmnon
# buildingi
# rodner
# powerprep
# leaveabooktakeabook
# subjegation
# okaybesides
# raeanne
# gunho
# yippity
# catepillar
# mischievious
# bottner
# centurythis
# oldfamilytiesthatbindjustmightendupkillingyou
# hereandnow
# submarie
# crapola
# syu
# adversitywhile
# unneccesary
# smoothshiny
# sciencethis
# subchapters
# hmmchildren
# jovahs
# moonchildren
# triumphantes
# everdeen
# charactershadnt
# exsteeplechase
# writingthis
# studentsi
# selfconsciously
# virusendstheworld
# admittoo
# parkours
# beachthis
# gastner
# corruptionso
# unplausable
# daniken
# charector
# charectors
# greated
# writtten
# whileso
# mcgees
# slightlyintense
# matteroffactly
# scifithe
# sharpes
# hardtobuyfor
# brandonjulian
# liliths
# vangils
# discriptive
# tilneys
# lifethis
# dunna
# kurts
# illusionsbeing
# filmmakerpresents
# secondhandtelling
# languageand
# monseiur
# purdu
# selfrealizatios
# tuchmans
# alshafi
# curreny
# maisies
# woodsmall
# waterbrook
# hrefaseasonfortendingbookoneintheamishvinesandorchardsseriesdprefcmcrarpdrvwtxtieutfa
# disapointing
# mentionings
# smmore
# booknot
# timebut
# inpossible
# crimnals
# deffently
# mealit
# ohsogood
# eastons
# skylers
# berkleynal
# colethe
# definintely
# unbelievablein
# toooooo
# dateperhaps
# formulistic
# landons
# connectionseemed
# tryi
# everybodys
# samhalldon
# eileenruth
# bathmohawk
# wynam
# governmentrun
# christiansi
# raptureready
# scifitechno
# beachbook
# osterlund
# romancefantasy
# larskeppler
# indridasons
# erlendur
# nesbo
# gogetter
# mysteriesi
# gallaways
# wellwrought
# umwhat
# yumminess
# comparation
# psychocybernetics
# kidlitexchange
# interspersion
# hungriesessentially
# hungries
# sponsorseven
# arborville
# annagrace
# nightowlreviewscom
# httpwpmeppjitf
# httpswwwgoodreadscomreviewshow
# godfaith
# relgions
# bronsons
# vanns
# sukkwan
# selfdetermination
# slowso
# heyit
# horrorsuspense
# pariss
# sincewell
# wellelizabeth
# anothermy
# readcomplex
# salisburys
# fiveyear
# happenedi
# alianne
# misfigures
# bedwarmer
# misfavor
# reyesoh
# workrelationship
# nowin
# degreegreat
# grandd
# tcells
# readingif
# readingchallengestoryofhtml
# whispies
# fucky
# subjectit
# kinsell
# hawthornes
# prequelsequel
# illinformed
# revolutionthis
# alcoholandtobaccofree
# thirtysome
# rickmans
# sobut
# vickiebrendamelaniejosh
# vickies
# attornies
# orgranization
# jandy
# likegreat
# motivationalinspirationalselfhelp
# antiamerican
# marinei
# hartceller
# antiangloprotestantism
# histoical
# joness
# genrecategory
# virgils
# evopsychology
# militaryspecific
# militarys
# rolealexs
# usalex
# alexand
# interestwise
# althor
# callandor
# ravensbrooke
# chya
# pterrys
# embuggerance
# pattersoni
# weigels
# childrenmy
# nowbecause
# newbut
# tissueit
# beautifula
# hrefalongcameyoudprefcmcrarpdrvwtxtieutfalong
# youa
# macombers
# oneselfthe
# selfawarenessmindfulness
# gabbys
# vospers
# uswe
# germanyi
# sawlike
# infrastructureclimate
# viraloutbreak
# discriptions
# dogeatdog
# dimons
# nonhumanesque
# electronicsetc
# buildingetc
# warthis
# mournfulness
# byatts
# christobels
# imigrants
# mexicanisms
# wordcount
# teaberry
# teabody
# looooong
# foxhunt
# allmaybe
# novellength
# alrashid
# swordandsorcery
# moreabout
# jojos
# hajars
# superslow
# overfocuses
# novelit
# twistn
# warricks
# physicianturnedsuicide
# walawis
# alqaeda
# finchs
# everests
# lineupone
# informativei
# slowgoing
# woodennot
# fleshandblood
# leadrship
# nassiar
# satired
# mishimas
# standalones
# radling
# carlas
# explainations
# seriesand
# childern
# cardiofacioutaneous
# learnsteaches
# sexfest
# kidnapforced
# malemale
# himselfbelieve
# offyou
# willand
# shalvis
# streeps
# hiddenit
# animalsa
# friendshipi
# streetsrios
# trinityrios
# shamelhis
# sallyhis
# cuttyanother
# hoodrat
# ghostwalkers
# utimate
# arutha
# borric
# nakor
# somethingss
# needsa
# slatfatf
# guibords
# chaucy
# torahfaithful
# gallaty
# postflags
# tverberg
# firstcentury
# hairraising
# nerveracking
# intriguedit
# afterthe
# vattas
# bashares
# fantasythrilleradventure
# elenas
# sookies
# buffys
# clicheacuted
# boundries
# woudnt
# stephenies
# rarety
# paupered
# bosuns
# yardarms
# alikei
# feiffers
# comedyan
# duchon
# foxs
# antogonist
# fwvb
# doorhan
# celias
# nonoverwhelming
# williamsgarcia
# reasonsone
# herselfand
# doingputting
# painand
# pastrunning
# paininto
# pctnot
# hermuch
# wildunlike
# mccandlessfortunately
# cherylher
# pathsearching
# somethingseek
# madeand
# diedhe
# inspirationaland
# mcewans
# crushworthy
# enemythe
# painballers
# peaceloving
# lipservice
# krigers
# enjoyeduntil
# magnitudal
# otoole
# lacksadaisical
# teeni
# heavyhandedness
# drttmk
# moriartys
# httpmelissasbookpicks
# notshould
# valks
# murdermystery
# mayles
# sleuthtrouble
# reboul
# tapassmall
# lockedroom
# globalscale
# suzes
# jesses
# barbieesque
# coherts
# memoiranalytical
# favoritei
# substatiated
# theonly
# turows
# lipramzer
# rustys
# unwomanly
# nusiance
# berkelee
# baringgoulds
# toof
# coursebe
# afterwars
# traventravistallisetc
# barrado
# ballardesque
# halfsiblings
# comicopera
# juanlespins
# provenal
# suskinds
# curriculur
# osteens
# charactersa
# paperthis
# damali
# clichethe
# evilshe
# guythe
# deadyadda
# elitesnobs
# timestoo
# credibleoverall
# coorain
# nathaniels
# largerthanlife
# spiceries
# miltons
# marielaures
# rogets
# wordfinder
# paraarcheologist
# convience
# selfpropelled
# onwardit
# detailsactions
# heorine
# insufferrable
# reaon
# smdh
# sterotype
# worldbuilder
# passiveaggressive
# historydropping
# rothchilds
# onother
# bupkis
# cleshaes
# exploriations
# likeing
# generaly
# favorsi
# readingtodistraction
# buddhai
# informativethis
# derleths
# halfforgotten
# relativefriend
# cthulu
# slease
# exnfl
# crampled
# charactersed
# glickas
# readbytheauthor
# hookedi
# amelias
# fifteenyearold
# ablom
# deathit
# lessoni
# litfuse
# beatrices
# dauntlessborn
# rosannes
# leatherbound
# rustbrown
# sixandahalf
# fullcolour
# artisthoweverhere
# eileens
# ottessa
# dislikeable
# xville
# worlduntil
# mauzer
# chicklitlite
# lapds
# protecthelp
# washad
# securitygemini
# bonansinga
# hanguns
# steelplated
# intriguingtwo
# syds
# stegners
# pennyi
# weaveworld
# imajica
# allages
# chickentown
# attorcities
# operendi
# audas
# ffordes
# novareviews
# voldor
# whillikers
# whata
# posiiton
# novemberi
# centuryi
# superinteresting
# sothis
# oncecharming
# stultifyingly
# faretheewell
# decifer
# quazisensitive
# readunless
# pedestalhe
# fatherlike
# justtoo
# beinteresting
# antiscience
# tsurani
# gwali
# classici
# monththis
# dictionarys
# overuses
# startupa
# hreftheleanstartuphowtodaysentrepreneursusecontinuousinnovationtocreateradicallysuccessfulbusinessesdprefcmcrarpdrvwtxtieutfthe
# businessesa
# uncertaintythe
# investpurchase
# startupnow
# todayas
# nonrecoverable
# daymichael
# egthe
# nonmoralistic
# welloff
# eightday
# yirmiyahu
# captian
# charachters
# stageboston
# luthers
# livesyour
# serverbased
# desktopbased
# issueslimitations
# suzzane
# serioushardworking
# typeand
# livelong
# readerthis
# connellys
# screencutter
# peccavi
# gerritsens
# rizzolis
# bussler
# zingarettis
# vigta
# montelusa
# cogitations
# seriesplot
# counterplot
# halfserious
# halfmocking
# forgivenessi
# soukups
# onetimedanger
# monstersand
# eyeopeners
# goonch
# humungous
# mankillers
# fishlife
# jacobsin
# kelks
# readersthis
# stardomand
# hasbeen
# claptons
# minilp
# jimis
# lifeokay
# situationit
# thurmans
# thirtytwo
# houserent
# thrillseeking
# lightskinned
# darkskinned
# goodfornothing
# buffi
# catholicprotestant
# crystallizations
# plausibilitys
# halfi
# historyif
# tabloidstyle
# goddroid
# yeahit
# notsogirly
# mindcontrolling
# lucifers
# forgiveable
# markhamthis
# hoags
# machismoselfdestruction
# nazisurpressed
# crimeauthor
# larmoyant
# selfpitiful
# personalitymixturehybrid
# bonnelling
# mauds
# monkwho
# failedtoappear
# warmthickbloodsex
# wineskins
# loveitorhateit
# bloodlight
# eyeballsucking
# yeuch
# slowmoving
# involvedmarshall
# stinnet
# msgs
# englishjapanese
# nagumos
# oneeightyfour
# haveing
# selfpreservation
# msdus
# livesi
# thirteenyearold
# postwwii
# enervates
# payoffwhich
# fashionfeels
# targetaudience
# jargonfree
# hollyn
# filmtext
# knowlove
# cinemaneonate
# satacracy
# nicheobscure
# conflictis
# trasks
# straightup
# clichefree
# anansis
# adventurethis
# twotime
# waybut
# borogrovian
# seveal
# borogrovia
# maladict
# wazzer
# largerthan
# chracters
# arehave
# mexcio
# teareyed
# actordirector
# mandom
# relationshipsi
# twentyeight
# pretertiary
# weakminded
# nospin
# carrigers
# mechanimals
# sophronoia
# submerse
# ignorethecollateraldamage
# annabels
# bashingyouovertheheadwithreligion
# baliff
# febrez
# sharpshotter
# lovetoy
# dicked
# obstacleobstacleobstacleboss
# detectivei
# writersi
# mannerparticularly
# hrefrichdadpoordadwhattherichteachtheirkidsaboutmoneythatthepoorandthemiddleclassdonotdpxrefcmcrarpdrvwtxtieutfrich
# moneythat
# notanbspif
# cepan
# randstostipher
# tallnlankyrn
# chabons
# taxidermic
# berniers
# fursts
# picswith
# gsmm
# wifred
# streamorconsciousness
# rolemodel
# charrierpapillona
# conditon
# spoilerfilled
# comwatchvfwlswrfdc
# bookrelated
# abouttoread
# ejr
# charactersmany
# humanpanzee
# nastinessit
# ernestthe
# postmodernistfeminist
# gutwrenchingly
# wizpod
# bajillion
# thoughto
# nitas
# otherit
# dairine
# franzens
# onegood
# disenchantments
# alexayounger
# tattoes
# wonderfulandamazing
# wordsexpressions
# spencerflemings
# drawingthis
# kojiyama
# speart
# beatendown
# koole
# wainscotts
# midseries
# fletchlike
# alousan
# highwalled
# norstead
# wereriders
# wererider
# tregarth
# hallack
# twentyfirst
# mattersdoes
# lovelike
# comingi
# lesswell
# millenniumthe
# fluttermill
# adolesence
# superfudge
# swifly
# nabakovs
# relateable
# sexualpredator
# sexaddled
# celetes
# zeidners
# pepperland
# postmans
# huxleys
# empirei
# disrespectfulness
# stroustrups
# chiefton
# ailigs
# cheifton
# epilog
# priscillas
# herwait
# itbehind
# hutchs
# dysangelist
# hrefwhatthegospelsmeantdprefcmcrarpdrvwtxtieutfwhat
# hrefwhatjesusmeantdpxrefcmcrarpdrvwtxtieutfwhat
# murdersuicide
# ahhsuch
# timesthis
# stubburn
# incredibally
# fortunatly
# incrediable
# likly
# dieing
# booo
# witht
# dorrados
# zamar
# bysen
# bysmart
# sweetthis
# tearling
# shtuff
# ittybitty
# gaias
# crushiness
# mclanahans
# kyrian
# worldthis
# rereviewing
# handground
# handgrinder
# daahling
# ratherrr
# puhleeze
# windowglass
# lynsay
# coanchor
# onetrick
# lesserlength
# selfmutilations
# wowwed
# entertainedi
# twelveyearold
# drewesque
# booklook
# httpbooklookbloggerscom
# httpwwwaccessgpogovnaracfrwaisidxcfrhtml
# broard
# sexierthansin
# heavyonthelovescenes
# almostgirlfriend
# maternallyinclined
# lessattractive
# funville
# sexytimes
# daughterinlaws
# waterbrookmultnomah
# biblei
# disappointi
# elsies
# carneige
# boooring
# nonsmiling
# depressionera
# tiajuana
# abolutely
# mertons
# xinran
# xinrans
# notheless
# constructionmilitary
# selfstudy
# eevees
# paralleluniverse
# chineselanguage
# headofficeimposed
# trustbuilding
# tagalong
# fastmoving
# movingthis
# samei
# endedi
# schickers
# heinlien
# hrefourkidsbuildingrelationshipsintheclassroomdprefcmcrarpdrvwtxtieutfour
# classrooma
# jewishamerican
# coverthe
# kalams
# lebinizian
# jennifers
# obgyn
# forprofit
# undeadlies
# rhyannon
# firstclass
# scrupulousity
# burstoutloud
# thingsome
# wholefamily
# pagewhere
# omalleys
# journeyi
# tobaccoinfluenced
# cammers
# histrical
# countrya
# deepseated
# moscows
# stalins
# convictsso
# lifewalks
# anarchonisms
# dedicacy
# scandlemonger
# lewiski
# hemmins
# ancedote
# recommand
# pointofview
# powerhungry
# languagethis
# scottolines
# dinunzios
# rosatas
# martas
# bennies
# pickingattracting
# avilas
# encouraginghelping
# lovetype
# autisticlike
# warfaretravel
# bernsten
# jrwardesque
# ubermale
# urbangangsta
# selfperceived
# machinegunned
# survivedfinished
# siblingsall
# fatherslife
# honkydory
# lighta
# wordsregina
# monthonend
# bingesshe
# reginano
# yourselfleft
# notregina
# hrefthedreamofthedreamdprefcmcrarpdrvwtxtieutfthe
# dreama
# hrefthedreamofthedreamofthedukedprefcmcrarpdrvwtxtie
# offthewall
# souleating
# waythis
# nonchristian
# nameis
# amazingcharactericeberg
# bookleave
# kiyah
# jawdropping
# caloriecounting
# nfcs
# agesex
# attachmentfocused
# highlyskilled
# saydo
# fathermother
# cleages
# goalto
# girlwoman
# liad
# meits
# eightysome
# advicei
# bakopoulos
# sarahs
# toosimple
# tooready
# forshadowing
# mackeltars
# sharons
# runofthemill
# menthink
# classicnbspa
# hreftheaccidentaltouristdprefcmcrarpdrvwtxtieutfthe
# touristanbspor
# recentnbspa
# hrefthebeginnersgoodbyedprefcmcrarpdrvwtxtieutfthe
# goodbyea
# pennywell
# turnseg
# editioni
# selfsatisfaction
# feelingsi
# churchi
# coulters
# seatneighbor
# tiein
# oulander
# pleasent
# travelromance
# nationi
# spocklike
# ashaya
# aleine
# ashayas
# psychangeling
# guins
# gethen
# dickersons
# bookperhapsi
# sojust
# vivians
# httpviviansbookpavilion
# savianos
# educatedinformed
# militarya
# lattimores
# bradburys
# sideruss
# kobes
# assalults
# adventuremysteryplot
# anachonistic
# superdetective
# usuaaly
# cherryhs
# cyteen
# sixtyyearold
# ledwidges
# gutcheon
# murderfirst
# chaoticand
# gutheons
# fasterthen
# characterstheir
# waywithout
# moraless
# delilahs
# selfappointed
# ocallaghan
# monings
# whackamole
# exactress
# kellermans
# vineripened
# thurbers
# silverhaired
# steelyeyed
# tearjerking
# spinetingling
# breathtakeoscope
# jonrosh
# hotelhot
# byliner
# entertainingbut
# thisismysymphony
# jances
# elequently
# doubledback
# useage
# anglund
# necessaryand
# addadhd
# televisioncomputers
# humanitys
# civilizationcan
# behaviorswe
# readathon
# defintely
# stealingpages
# macleodsmackinnonsde
# piagets
# invovle
# descritpions
# jbogue
# paperandlace
# subjecti
# jacobsens
# quentins
# thoughgreens
# coywolves
# humanscomputers
# canadausmexico
# youthe
# romancea
# mindrape
# observantbright
# lengels
# wholecloth
# villification
# prevelance
# quoatation
# erausually
# qoutes
# zafns
# semperes
# anyoneit
# tenyearold
# coubert
# windthe
# daviss
# differentlysometimes
# followit
# zafn
# outmy
# fnaf
# conditionvery
# adultsmy
# shippinggreat
# loooove
# gengar
# ugglys
# crazepony
# fpvalittle
# poohthis
# toyscute
# withoutmy
# silvercore
# lovesthough
# granbaby
# itcutewe
# dasughter
# beautifulvery
# cutekind
# candywell
# yaaas
# rving
# seenno
# adorablethere
# heregreat
# excitied
# moter
# trackmaster
# wristbandsthis
# findthis
# underclothing
# loces
# figurebut
# clawesome
# forwe
# puzzlesand
# nonannoying
# learnplay
# cpks
# microbead
# microbeads
# twowheeled
# togetherotherwise
# wellbut
# birthdayhe
# gamevery
# piecescutewe
# polybags
# christmasthis
# reckamed
# flippush
# kods
# pricequantity
# batgirlvery
# horseshe
# cerakote
# hset
# fixto
# lizardsnake
# specificlly
# waterreveal
# happyvery
# custume
# amazinglove
# catwomans
# pappou
# cutesies
# flashberg
# blased
# makebelieve
# gfit
# nieceshe
# pricecame
# pochettes
# shufflling
# invisi
# cardboardvery
# gilrs
# wobblers
# flopsie
# thik
# somene
# ppony
# diffenitly
# umizoomi
# funmy
# hexbugs
# marblesreally
# decorarion
# greatniece
# riskreward
# tablecover
# playdough
# geniuswe
# etchasketch
# likenthem
# caboos
# trackbut
# suoper
# fastflowing
# stuffie
# greata
# ngrandson
# homeschooler
# geppettos
# woodbase
# andd
# mixel
# orbeez
# moldmildewfunky
# matterthe
# woodys
# expectedmy
# himslef
# piececute
# greatgranddaughters
# bbought
# nitnis
# expectedwanted
# abusemy
# ballooon
# displayability
# teachs
# jetwash
# tablepool
# savox
# puzzlesolvers
# puzzlesolving
# culdesac
# mannervery
# pokiemon
# followi
# varyinggreat
# angelcare
# orderpurchase
# boyhe
# deliveryeasel
# promisedrecommendwould
# giftvery
# weere
# alllllll
# idvideoblockriihkwfvza
# valuehttpsimagesnasslimagesamazoncomimagesiaubzdolxsmp
# valuehttpsimagesnasslimagesamazoncomimagesiapysprlpng
# classvideoslateimgurlnbspa
# thisalthough
# coukld
# waterballons
# retreaving
# togetherbut
# bebut
# gobblet
# chompies
# skylanders
# skylander
# costumeplus
# figuresgreat
# frozenthemed
# funtouse
# figma
# semiclosed
# halfclosed
# sippies
# squashy
# stickygreasy
# sizeshape
# resummoning
# funsuch
# costcos
# cutes
# movieaccurate
# batmanvery
# triggerjust
# doorso
# themkids
# idvideoblockrgzuxhbchj
# boughtem
# hreftraintrackscompletesetdpbzebmtzyrefcmcrarpdrvwtxtieutftrain
# kuhtuhnaw
# armshands
# nondigital
# gamebut
# puzzzle
# lalalove
# woild
# wastefuland
# basiccheapy
# schleigh
# extrememly
# hausjam
# yummyjust
# perfectloved
# capullo
# firecord
# soundsit
# okdoes
# bellylegs
# agesinterests
# notsoyoung
# calderatornado
# epx
# megabloks
# spektrumfatshark
# funprobably
# mustbuy
# amazondid
# greatgrandsons
# jellycat
# handsdown
# cutestsoftest
# batmanmy
# preschoolkindergartener
# regifted
# worryfree
# boxplay
# underdtand
# qualitybut
# screwunscrew
# unmolding
# expectedis
# alreadyassemble
# cheapthey
# drivewayi
# rescribe
# viewmasters
# happensnoises
# jesta
# taptap
# daysits
# headbandswould
# thesethe
# whilenice
# fuggedaboudit
# stickbots
# rearely
# sculp
# dinoloving
# swaped
# yesthere
# basicschildren
# hotwheel
# babyvery
# minniebut
# safarithemed
# familywe
# petshopmy
# poniville
# silverwareplatescups
# immpressive
# staticy
# acquarium
# collarleash
# biggerbut
# twozies
# tabletopics
# tamashii
# flowingthis
# giftbags
# tabaxi
# accessoriesmy
# greatings
# puple
# hreflegotoystoryconstructabuzzdpbrlvysrefcmcrarpdrvwtxtieutflego
# dollthe
# chessex
# lotrs
# squirter
# musiclike
# nospill
# bzzagentcom
# hrefkeyelitebabygranddpbbljyrefcmcrarpdrvwtxtieutf
# grandathis
# schoenhut
# playthegame
# fingerlights
# blocksi
# anywaybut
# qould
# thise
# musicmy
# buycute
# microsol
# stepsfirst
# interestingand
# challengiingif
# herebut
# poppit
# mickeyminnie
# panscookie
# allllll
# allll
# followme
# bagpurse
# lke
# cuddley
# groots
# solidlybuilt
# eflite
# eagleand
# carbut
# tooused
# tooit
# phrasesbut
# anpther
# highdef
# bumbo
# bigin
# figuressuper
# suring
# amuzing
# fruitveggie
# oillubricantplastic
# loopin
# umph
# storytimes
# mauis
# cardbased
# ciggeret
# someome
# neibor
# loveit
# juunky
# easytooperate
# grandchilds
# collectionthe
# rattley
# hahahaha
# wellwow
# orchastra
# etracks
# designglitter
# commentsi
# crazybut
# scen
# idvideoblockrxtgbwtmw
# didlooks
# begesus
# toptier
# growsgreatthis
# thoughthis
# elavated
# tunnelnot
# amazonto
# misadvertised
# ofthere
# idvideoblockrxzjhmrfil
# partythese
# dxi
# flysky
# crashrepair
# httpswwwamazoncomreviewrafusujczbairefcmcrrdpperm
# stairsyeah
# spinrgs
# herwe
# mechlike
# madethis
# wellwe
# childthe
# emoji
# tothere
# canterlot
# headphoneglasses
# sofachair
# stargreat
# startthis
# seenhad
# asingle
# electronicsmy
# zeg
# sooooooooooooo
# chairthat
# looooove
# lacqured
# monthtwo
# vincis
# leappadmy
# mckeyla
# brylen
# hrefradioflyerallterrainwagondpbytrefcmcrarpdrvwtxtieutfradio
# wagona
# xmasthey
# piata
# triggerpulls
# brownmedium
# yro
# oneyearold
# musicmoo
# mooooo
# manylol
# butwhat
# marketif
# roadi
# himbig
# charcoaled
# closesopens
# mademy
# postchew
# staightit
# reasoni
# featuresnice
# growsgreat
# expensiveyou
# toddlerfriendly
# mathfriendly
# genderneutral
# rightrc
# minifigue
# dispay
# birthdaywe
# unsticking
# fimo
# airdry
# cowsheep
# thinkfun
# instructionssolutions
# frig
# letternumber
# littlei
# jumparoo
# trampolinebut
# cyclebatcycle
# batcycle
# baymax
# stuffermy
# readytouse
# kidsteens
# timefiller
# zuppies
# buildityourself
# schoolage
# basketballlike
# erevo
# revobuggy
# helpguidance
# handeye
# assembledisassemble
# destuctive
# handseye
# girlperfect
# trickortreating
# innotab
# giftgreat
# bluepurple
# yumbox
# magicmy
# sylveon
# massproduced
# teether
# hrefmegablokslilpinkbusdpbprtxrefcmcrarpdrvwtxtieutfmega
# busanbspfor
# easytopoor
# dealbreaking
# montholds
# girlgreat
# gamewright
# prereading
# barbiesized
# overlylarge
# acotrs
# coollooking
# spudscrabby
# crabbybecause
# anywho
# ahembehind
# grandmasevery
# nannys
# constantlyand
# dupos
# qaqc
# closingfolding
# projectthe
# stuckfalls
# startersthis
# capullos
# offbrand
# nodie
# vmsile
# alphabetit
# aroundyes
# inall
# vsmile
# idvideoblockraurblu
# comimagesiaqfuqvs
# comimagesijcvsccxs
# classvideoslateimgurlnbspmy
# dishonnest
# precolored
# discounti
# irridescent
# printedit
# kidss
# biofino
# linehowever
# strunge
# petswe
# geeking
# frontwindowcompartment
# driversseat
# windowcompartment
# soundeffects
# idvideoblockrvolzpxfqau
# magworld
# opoly
# lincon
# nowshe
# oftenthese
# oneofakind
# fanlove
# bluewhite
# irradic
# usmy
# agescute
# setsmy
# blackandred
# yellowandgrey
# seaweedtype
# undressredress
# superbest
# lensesone
# mangnifier
# anythingjust
# itenjoy
# gamergreat
# adorbs
# scootaround
# beginnerthis
# cutewe
# hrefleapfroglearningfriendsplayanddiscoverschoolplaysetdpbjlhvwuurefcmcrarpdrvwtxtieutfleapfrog
# playsetanbspwhich
# pushpulled
# apraxic
# againhe
# keepingit
# thatinitially
# viperine
# stheno
# viperines
# jinafires
# himwe
# doorporch
# bigheavy
# mailperson
# idvideoblockrtjzzyohujin
# valuehttpsimagesnasslimagesamazoncomimagesiakgftrbjvsmp
# valuehttpsimagesnasslimagesamazoncomimagesiisnvdajspng
# hatribbon
# imaginets
# bettr
# bcause
# manlier
# shos
# wantd
# genewarped
# warwolf
# stewies
# rewardspenalty
# gameit
# attqchment
# balloonsjust
# partythis
# toomy
# sizethese
# characterstoys
# dragonso
# paintingit
# outofthisworld
# toysthis
# frozenthis
# salegreat
# bzzagent
# grumpiest
# repumping
# hrefbabygeniuscolorsandshapessoftactivitybookwithsoundforinfantsbymanhattantoydpbwpwiurefcmcrarpdrvwtxtieutfbaby
# toyanbspas
# resewn
# musicsinging
# dougs
# learngreat
# playmats
# hergrandson
# playgreat
# granddaughterwe
# doubletriple
# grandchildrenawesome
# familygrandson
# bathtime
# simliar
# purposei
# forbefore
# boysnow
# kidkraft
# roughthis
# imposable
# gamesi
# playthroughs
# highlyreviewed
# halfprice
# lbssurprisingly
# tauntaun
# ittauntauns
# snowtroopers
# tauntan
# wampa
# atats
# spiraltop
# selfdestructing
# childthis
# cluei
# enthusiastbought
# historymaking
# beardeprived
# bearlover
# parentswitch
# iquest
# guundam
# globed
# peopleit
# bigboned
# winoccasionally
# velcros
# boxtravel
# monkeythis
# lanzillotto
# schistsong
# wwwannielanzillottocom
# hreflisforlionanitalianbronxbutchfreedommemoirsunyseriesinitalianamericanculturedprefcmcrarpdrvwtxtieutfl
# italianamerican
# culturea
# hrefschistsongviafoliosdprefcmcrarpdrvwtxtieutfschistsong
# hrefbluepilldpbgjbyrefcmcrarpdrvwtxtieutfblue
# hrefcarrymycoffeelivedpbnvyarefcmcrarpdrvwtxtieutfcarry
# livea
# hrefelevenrecitationsdpbngarefcmcrarpdrvwtxtieutfeleven
# recitationsa
# ballsized
# wordnice
# muchthis
# wftfor
# tosuck
# animalpillow
# choicemy
# connectorsand
# seantree
# noloss
# buymy
# hobbyzone
# trainthis
# cheapernbspa
# hrefmegabloksassassinscreeddpbmytvrefcmcrarpdrvwtxtieutfmega
# creedanbspornbspa
# hrefcallofdutymobofthedeaddpbjmwvrefcmcrarpdrvwtxtieutfcall
# deadanbspblock
# collectormy
# battyvery
# primascolor
# prismas
# hrefdisneyprincessprincesssnowwhitedolldpbbtdyrefcmcrarpdrvwtxtieutfdisney
# dollanbspis
# doublesided
# packagethis
# hardtowash
# sheriffdeputy
# phonei
# springaction
# idvideoblockruuxzoneu
# valuehttpsimagesnasslimagesamazoncomimagesibcnkzjumlsmp
# valuehttpsimagesnasslimagesamazoncomimagesibuorizspng
# classvideoslateimgurlnbspdiamond
# dollmy
# rattly
# hrefhasbroplayskoolletsplaytogetherfillnspillfishdpbfknqherefcmcrarpdrvwtxtieutfhasbro
# fishanbspwe
# fishie
# partyi
# fungreat
# arcle
# drinkingplates
# decorationstablecloth
# toovery
# thesemy
# soakers
# itemeffectively
# toysthese
# flexiblity
# itnbspa
# hrefbinsampthingsstackablestoragecontainerperfectforshopkinslittlestpetshoprainbowloombeadsdisneytsumtsumfiguresandartsampcraftsaccessorieswithadjustablecompartmentsdpbdxpirefcmcrarpdrvwtxtieutfbins
# compartmentsa
# chaching
# askedthere
# gamewell
# sothen
# iteventuallyhowever
# kidgreat
# predrilling
# pseudowood
# judgesome
# welllabeled
# basketmy
# disappointedwe
# distictive
# friendthis
# setour
# midcircle
# hitgreat
# boltsshockswild
# growthcounterspell
# underfilled
# counterspell
# onsold
# gamewe
# camelcamelcamelcom
# ipadso
# decentgreat
# girlsgreat
# eldrazi
# mirrodin
# snapstyle
# yearswe
# animalsfood
# nephewi
# jusdge
# monrow
# influece
# optiongreat
# syma
# xieda
# highside
# apartthe
# itsyourturn
# idvideoblockrvbxfgjbdt
# valuehttpsimagesnasslimagesamazoncomimagesidxbpbmasmp
# valuehttpsimagesnasslimagesamazoncomimagesivvruabspng
# doingthe
# wrinting
# contoller
# flymy
# showervery
# lookingmy
# showerthis
# youmy
# treadswhen
# smilingmy
# childrenthis
# newlybuilt
# tunnles
# frivilous
# imaginine
# granddaughtermy
# alfreds
# stingsmostly
# stringwhich
# quitar
# miniamp
# strenthen
# ehhhhh
# diaphragmab
# usualbefore
# sculptdesign
# repulsors
# anthonyscustoms
# realisticmy
# goesgreat
# puzzlethis
# parentgrandparent
# motorosi
# italianspeaking
# machino
# schnells
# maniezbruno
# motoreau
# gorvettes
# pittyjohn
# lassetire
# collectori
# lastthis
# waysi
# uscanada
# manovering
# wdrawer
# whilethis
# partsall
# koopalings
# dollsthis
# titanfall
# strengthyounger
# birthdaythis
# lanefirst
# nonflexible
# numbersthis
# trixies
# colorthey
# goand
# giftgiving
# lightsthis
# shanshad
# puzzlestrategy
# kanoodle
# numbersgreat
# sharkrepelent
# biiig
# tusch
# closecuddling
# cbatteries
# dealnbspa
# hrefnerfnstrikeelitedartrefillpackdartsdpbtxzvqrefcmcrarpdrvwtxtieutfnerf
# dartsa
# storedo
# daughterwho
# carthis
# wellcoloured
# jasonwell
# dealmy
# roomread
# batbot
# manufacturingdate
# originalmy
# phalatefree
# bakedin
# buildthis
# batteriesvery
# coollaud
# xwings
# atat
# girlmy
# childit
# idvideoblockrnpdfjzretjlx
# severeal
# roboraptor
# furbee
# negligiblehe
# oball
# piratethemed
# childrenwe
# snowspeeder
# consideredthis
# builtdurable
# cockpitthere
# springshooting
# qualitylove
# collectorbought
# overnbspa
# hreftheoldversiondpbivfccmarefcmcrarpdrvwtxtieutfthe
# versiona
# diarytype
# hrefoldfashionedlockingdiarydpbnyagmqrefcmcrarpdrvwtxtieutfoldfashioned
# diaryanbspmay
# invisibleish
# soldseparately
# tieins
# expansionsreplay
# hrefthemagiclabyrinthboardgamedpbrdjymmrefcmcrarpdrvwtxtieutfthe
# gameanbspandnbspa
# hrefhideandeeekdpbdepqmrefcmcrarpdrvwtxtieutfhide
# eeekanbspafter
# buildingmy
# pushesthe
# lastnight
# backfor
# overandover
# arrowshaped
# legostyle
# coincollecting
# secretfinding
# trainsmy
# movienbspa
# hrefbarbiehersistersinaponytaledpbeaebcrefcmcrarpdrvwtxtieutfbarbie
# talea
# dolllessnbspa
# hrefbarbieandhersistersinaponytalervvehicledpbcpvqqrefcmcrarpdrvwtxtieutfbarbie
# vehiclea
# idvideoblockrfmuibdn
# decorationsit
# marklin
# chirstmas
# announcementsmy
# didbut
# buildmy
# lastsmy
# itawesomegreat
# speicherstadt
# meatierdeeper
# kidssize
# topheavy
# yoinked
# doublea
# klunky
# octonauts
# brilliantentertaining
# gamethe
# schooltype
# howevercare
# mouthas
# bindingso
# flatthe
# difficultystarterjuniorexpertmaster
# wizardeach
# hourbut
# solvethe
# sothere
# suitsable
# cellopane
# etcbottles
# reattachable
# looppreviously
# exitso
# additionsubtraction
# gamereview
# charactersmy
# idvideoblockrnrmaerku
# projectat
# himthis
# pieceswe
# meeples
# learningperfect
# growsthis
# unexplainably
# calibrationmotors
# lowerstar
# frustrationfree
# leakfree
# samey
# zillionz
# windblade
# idvideoblockrloxwdavw
# featureswhen
# itmost
# girlsif
# oldwe
# intenseforlorn
# colorways
# twylas
# purplypink
# howleen
# lockset
# altmode
# shippingmy
# hitthis
# selfrespecting
# fantoys
# amdhis
# myimg
# tshapes
# collagehat
# dollhousemy
# granddaughtersi
# colorlove
# megablok
# hottub
# idvideoblockrrcjocucsopz
# valuehttpsimagesnasslimagesamazoncomimagesigcrbjgarsmp
# valuehttpsimagesnasslimagesamazoncomimagesixmaeejyspng
# classvideoslateimgurlnbspwhat
# idvideoblockrsdkaxmnm
# princesss
# overral
# upsize
# wallhanging
# beyou
# hrefvintagevacationspiecepuzzledpbrojpdrefcmcrarpdrvwtxtieutfvintage
# puzzleanbspit
# beginnerintermediate
# airhog
# accusim
# xheli
# zombicide
# colornumber
# flippies
# wellwife
# shirtand
# nosepads
# seleeping
# materialsummer
# attachdoes
# moucha
# perfectspotted
# describedgreat
# breastsvery
# purchaseso
# softspots
# exsentuates
# exoected
# forhead
# slingback
# ownedvery
# deliverythe
# calvesdisappointed
# picturevery
# businessthis
# bevery
# greatcute
# shynny
# colorbecame
# wastoo
# baglove
# travelgood
# tomsi
# colorit
# blousey
# triednice
# theml
# mexicocaribbean
# panites
# exofficio
# butit
# lowcomfortable
# abdit
# flatchested
# xxxw
# xxxxw
# scarfthe
# exceptation
# empyrosis
# lether
# purchasedbut
# expecred
# dressundress
# daughtershe
# awfull
# dufflebag
# medeviel
# perfectshe
# daughtervery
# incute
# narrowish
# havepair
# gooooooood
# expectit
# blzaer
# parislondon
# abusulutley
# sunnies
# supercute
# tagless
# bagnice
# diferant
# spacous
# nonactivity
# flagastaff
# sucido
# adolescencia
# smallmed
# durableand
# greattrue
# confy
# thinjust
# archless
# freediscounted
# comefortable
# ssoooo
# comfysecond
# earvery
# yearsvery
# originalwife
# diacutea
# mercanciacutea
# enambradoa
# brokei
# vintagey
# calfs
# wearfur
# guppie
# portrayedmore
# expectingvery
# wellvery
# lengthi
# tremendo
# funciones
# buenisimas
# funcionan
# brandnamed
# softnice
# uncomfortableand
# thakns
# militarypolice
# breetches
# brasuuuuuuuuuuper
# supportwent
# nicelooks
# shortshe
# talkfun
# minimalost
# wantedwife
# wellgreati
# granchild
# minuse
# designvery
# saidtheir
# husbandlove
# shortgreat
# showthrough
# braceletbut
# alwaysi
# tightgreat
# madeforgirls
# neckwill
# manclothes
# shortsswimshorts
# xweek
# comfortablenice
# greatwife
# workpants
# fitheel
# daughteri
# hitnice
# pocketsvery
# holderhe
# sleves
# coloradovery
# lightinfused
# scarvesthrowswraps
# prettywent
# qualityonly
# leatherplastic
# meeded
# innice
# smallbut
# dealvery
# sperrys
# shacket
# henleys
# purplebordeaux
# redbut
# stsrted
# allgreat
# supportno
# supportfor
# chiquitas
# elaboradas
# delicadas
# empacadas
# indudablemente
# volvera
# toeheel
# jointskeeps
# feetthese
# heelstrap
# nownice
# romika
# meshlike
# accured
# goodflesh
# twoyou
# overshirt
# tooooo
# dresswill
# gstring
# sixtys
# methat
# stiched
# flowey
# chuckslove
# oing
# purchades
# lable
# rebutton
# boardshorts
# earthies
# beforeworth
# oldand
# haircolorist
# fittedoverall
# thimgs
# superwarm
# washeswears
# icesnow
# beautifulcomfortable
# sholls
# wonderwink
# versitile
# birthdaythe
# beautifulbut
# flawthe
# loosewhen
# properlyi
# doshe
# offno
# gelnimbus
# pairwear
# chacos
# lunarglides
# tightsmall
# tweenager
# vshaped
# complimentsi
# teadying
# offwhite
# stitchings
# sizelxl
# narrowcramped
# nonmesh
# blundstone
# wastei
# waffleknit
# woolx
# tighti
# leggs
# inov
# fantasitc
# squating
# labelbeen
# racerback
# nubbs
# looknice
# neededthis
# gorun
# floorsouch
# haflingers
# iridescentblack
# shoesget
# hallooween
# lbsi
# ultrasale
# plussized
# comfortableon
# gansta
# bonusvery
# bestmost
# comfortabledurableworm
# onesnap
# butlow
# tieks
# onsie
# levelthey
# snugglely
# leatherall
# underwirei
# branow
# likeslightly
# soproblem
# nordstorm
# racknever
# stilletto
# crosstraining
# tallish
# lowas
# lowa
# feetroomy
# frontas
# bewithout
# ggh
# enell
# clipons
# wallssometimes
# largenice
# velcrozipperbuttonsetc
# daydate
# fiddley
# absolutley
# topnot
# sooooooooo
# tassles
# thingalthough
# shockmy
# rubberyvinylpvc
# attacher
# smallesttighteneat
# hardside
# cowneck
# smallso
# courseit
# securethe
# dosnt
# skirtit
# clothesgreat
# goldplated
# leverbacks
# headthat
# bandaids
# hudge
# onsies
# wearsvery
# highwaist
# pursehas
# softersquisher
# softsmooth
# dressskirt
# medlarge
# alsoharley
# ironedat
# crossdresser
# mediumwidth
# toestrap
# gunna
# summergreat
# muxxn
# rpost
# largeri
# pregancy
# eachs
# txthe
# passerbys
# boxerbriefs
# preferated
# mooz
# brai
# publici
# settingthis
# jeansuntil
# decemberit
# bargainbasement
# mockneck
# materialfabric
# walmarts
# earlypregnancy
# cameracarrier
# easilyadjusted
# crossstrap
# expecteda
# perfectlygreat
# bootslove
# jeggings
# wiould
# bigsecond
# widthi
# vionic
# illfitted
# illtreated
# deterence
# fasciatis
# ruches
# perfectlyit
# helpfulthe
# vkneck
# pruchased
# sqeezes
# plastick
# pairsi
# purchaseed
# amazontimberland
# sharpstylish
# leathercolor
# colorsheights
# travelingadventure
# clothingwhich
# graypink
# blueyellow
# dritz
# woolfree
# notappropriatelywarmenough
# anyonethey
# baggreat
# skeletoes
# vibramsnear
# bearfoot
# holesports
# thinish
# woth
# onlinw
# discountpromotional
# rubberi
# wearlove
# streetor
# meotherwise
# dewrinkle
# finethe
# mordenmiss
# stylewise
# plussize
# ithowever
# mrignt
# longrun
# gowalk
# comfygreat
# yearswhich
# walletsi
# itss
# sizethis
# ahnu
# parachutestyle
# sansrough
# leathermanmade
# grippier
# pairsize
# sizeseason
# tomscom
# omapc
# capnozzle
# tshirtbasic
# xmsa
# realction
# cutelove
# kodakx
# pacsafe
# shippingsign
# lilyette
# minimizers
# emptylarge
# downnot
# fakeshirt
# buttonside
# materialflap
# stupidlooking
# silvergoldbronze
# noisierclunkier
# toolarge
# wrinklefold
# idvideoblockrboevzdogp
# comimagesiejwpsrb
# shoethe
# liquidy
# cardsand
# machineperson
# bucksuntil
# quess
# overtheknee
# lookfeel
# bestfitting
# wellexecuted
# ajustable
# attentionthe
# notexpect
# thisbra
# sleeplounge
# returnshipping
# pairgood
# tighty
# manties
# ballhuggers
# ddds
# makenna
# innersole
# favs
# backclosure
# nothowever
# bootvery
# gluedscrewed
# makedo
# midshaft
# birthdayvery
# headsize
# largesized
# hatsizes
# nonwindy
# sleeveit
# pmcom
# headsyou
# accomodates
# neccesary
# materialgreat
# laceless
# yethopefully
# luminox
# pairthe
# companyi
# nonsandal
# thinmedium
# pronate
# merrills
# averagewidth
# threeday
# quicklyeasily
# returningexchanging
# collapsiblealso
# netbooklaptop
# carhartts
# comfortablelove
# inexpensivecheap
# widebreasted
# lumed
# chronodiver
# adrina
# helpthe
# hidding
# amzaon
# shoehead
# waayy
# sliptype
# teenwear
# figuredwoman
# hoseyounger
# handwashed
# newclear
# poetgwennewclear
# socksthese
# allterrains
# themexcept
# sleekcool
# pricecategory
# regularalarm
# watchdisplays
# boneoff
# ambrielle
# intogreat
# pocketsgreat
# travelzen
# honestunbiased
# goldbrown
# bustshoulder
# notit
# littlethe
# unthorough
# wellreceived
# cellbattery
# bujy
# widebrimmed
# diveiders
# bitmy
# averagesized
# storecoffee
# foldover
# pantyline
# babypink
# llbean
# noticedhowever
# truebut
# caratswhich
# kingand
# dcmdva
# boxsizing
# pearshaped
# allblack
# pattyb
# metalic
# untucking
# happygreat
# disappointedit
# midthigh
# smoothers
# apparentlyi
# mediumthe
# restroomunless
# dirtyso
# idvideoblockrkbkezfnf
# comimagesiejwmpsrb
# vsvqvn
# looseish
# topthis
# velcrosealed
# deadbang
# bootcuts
# inseamed
# buyfantastic
# rediculous
# thatll
# foldswrinkles
# batwings
# clothingshoponline
# extrahuge
# mostand
# threefoottall
# itsince
# storesgreat
# comfortablethese
# monthmy
# medela
# youknowwhere
# thoroughbuttothepoint
# warmthtreadhiking
# shortlegged
# stretchesadjusts
# qualitywarmth
# lacezip
# sneakersshoes
# couldve
# fourwheel
# inchers
# qualityfit
# fitthis
# fryes
# themyet
# martinlooking
# springfall
# rdit
# pocketscompartment
# idvideoblockrhlbtvzqxs
# valuehttpsimagesnasslimagesamazoncomimagesiejwmpsrbmp
# valuehttpsimagesnasslimagesamazoncomimagesiffsvsvqvnpng
# cutefunny
# comei
# bootsmy
# fandigital
# brandexpresssaks
# macysseriously
# midrises
# thinthick
# incheszipper
# yearthese
# inbetweener
# guesslol
# designedgives
# consistancy
# sneakes
# sandalthis
# extrely
# groundgrass
# treatedsprayed
# stiffener
# picturesbut
# thissuper
# workpant
# ruggedby
# noteda
# duragold
# finelove
# suitthese
# smallerthese
# moneyfits
# sanuks
# supportcomfort
# sweatersweatshirt
# whitetanblue
# narrowi
# kneehighs
# heightweight
# ussized
# pantyhosestockingsetc
# washesdries
# beautifulin
# bandsscarfs
# yearlove
# unlatchedlost
# purposethese
# lowheel
# clothingcolor
# stylewhich
# strapsall
# nonei
# edgeoutline
# giftwrapping
# blacki
# brasthis
# tback
# lowestlongest
# shirtvery
# hipbutt
# colorlike
# spotsgo
# ivorybut
# spunkysoul
# guardsunscreen
# superachey
# preicous
# upperfoot
# pinkcoral
# slashcut
# getgo
# winterintended
# cavityopening
# paperdocuments
# scubahowever
# nonscuba
# sportsbeachknockaraound
# timedaydate
# amws
# largerboned
# midpalm
# bigbusted
# ekouaer
# bandings
# mediumthis
# himbought
# oooed
# ahhhhhhd
# reship
# offness
# differencegreat
# idvideoblockrerzqwxpctg
# valuehttpsimagesnasslimagesamazoncomimagesicfnjhjtssmp
# valuehttpsimagesnasslimagesamazoncomimagesizzpxgomuspng
# classvideoslateimgurlnbspfor
# atacs
# assemblysewing
# girlthank
# footsmart
# fityes
# bearsized
# eyeappeal
# timepiecewhich
# hrefinvictamenssubaquanomaivcollectionchronographblackpolyurethanewatchdpbpjjsrefcmcrarpdrvwtxtieutfinvicta
# subaqua
# watchanbspcomes
# brightyellow
# dravis
# sizesi
# pursei
# muchneeded
# wantneed
# underband
# northface
# thennbspa
# hreftevamensanisoeventwaterproofbreathabletrailshoedpbcpgogrefcmcrarpdrvwtxtieutfteva
# aniso
# contagrip
# ortholite
# likea
# hrefadidasmensastrailrunningshoedpbrscrefcmcrarpdrvwtxtieutfadidas
# timemy
# tetron
# vneckline
# comfortablevery
# builtup
# dealsi
# bucklebondage
# compsxa
# hikerstrail
# crossmax
# speedlaces
# gortex
# climashield
# waterproofness
# muddywet
# weaing
# perfectionseiko
# titlethis
# soundso
# areyou
# roundthese
# ihave
# areato
# workappropriate
# wellfitted
# zigzagstitched
# muscleheads
# momentto
# cheerleadingso
# saidoooo
# pricenot
# slipons
# redit
# soworks
# skirti
# betterbest
# preggo
# insteps
# theselove
# soonlove
# everydaythis
# sizingbut
# midheight
# daytype
# looklove
# tintedmuch
# quartera
# wristand
# shadessilver
# colorthe
# largebusted
# lowimpact
# highimpact
# requiredjust
# photographerwhich
# hrefcanoneosrebeltdpbjyurefcmcrarpdrvwtxtieutfcanon
# lowepro
# insertsyou
# oofosi
# blacksilver
# oolala
# ettellut
# supportwhich
# materialand
# cupsi
# littletono
# bouncinglike
# biggerthere
# armitron
# havenbspa
# hrefggiinternationalwtkmetalwatchrepairkitdpbkjsmokrefcmcrarpdrvwtxtieutfggi
# wtk
# kitanbspits
# morebought
# sizecolor
# hippora
# hyvent
# dwrthis
# propertys
# jacketit
# timemans

# %%
from sklearn.linear_model import PassiveAggressiveClassifier
from sklearn.metrics import accuracy_score,confusion_matrix
linear_clf = PassiveAggressiveClassifier(random_state=42)
linear_clf.fit(X_train, Y_train.ravel())
pred = linear_clf.predict(X_test)
score = accuracy_score(Y_test,pred)
print(score)
print(confusion_matrix(Y_test,pred))
print(classification_report(Y_test, pred))
# Out:
# 0.5161370100160751
# [[1278 2766]
#  [1147 2896]]
#               precision    recall  f1-score   support
#
#            0       0.53      0.32      0.40      4044
#            1       0.51      0.72      0.60      4043
#
#     accuracy                           0.52      8087
#    macro avg       0.52      0.52      0.50      8087
# weighted avg       0.52      0.52      0.50      8087

# %%
from sklearn.svm import SVC
clf = SVC()
# train the model
clf.fit(X_train,Y_train.ravel())
# use the model to predict the testing instances
y_pred = clf.predict(np.array(X_test))
# generate the classification report
print(classification_report(Y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.72      0.83      0.77      4044
#            1       0.80      0.68      0.74      4043
#
#     accuracy                           0.76      8087
#    macro avg       0.76      0.76      0.75      8087
# weighted avg       0.76      0.76      0.75      8087

# %%
LR = 1e-3
EMBEDDING_DIM = 100
BATCH_SIZE = 64
EPOCHS = 8

# %%
import tensorflow as tf
embedding_layer = tf.keras.layers.Embedding(vocab_size,
                                          EMBEDDING_DIM,
                                          weights=[word_vector_matrix],
                                          input_length=150,
                                          trainable=False)

# %% [markdown]
# ##Modelling

# %% [markdown]
# ##BILSTM WITH GLOVE

# %%
lstm_model = Sequential()
lstm_model.add(embedding_layer)
lstm_model.add(Bidirectional(LSTM(64)))
lstm_model.add(Dropout(0.4))
lstm_model.add(Dense(1, activation = 'sigmoid'))
lstm_model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['acc'])
print(lstm_model.summary())
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_4 (Embedding)     (None, 150, 100)          4817800
#
#  bidirectional_4 (Bidirectio  (None, 128)              84480
#  nal)
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  dense_4 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 4,902,409
# Trainable params: 84,609
# Non-trainable params: 4,817,800
# _________________________________________________________________
# None

# %%
# %%time
from keras.callbacks import ReduceLROnPlateau
#reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, min_lr=1e-6, verbose=1)
early_stop = EarlyStopping(monitor='val_loss', min_delta=0, patience=10, mode='auto')
mc = ModelCheckpoint('best_model.h5', monitor='val_acc', mode='max', verbose=1, save_best_only=True)
batch_size = 64
epochs  = 8
history = lstm_model.fit(X_train,Y_train,validation_data=(X_test,Y_test), batch_size = batch_size, epochs = epochs,callbacks=[early_stop,mc])
saved_model = load_model('best_model.h5')
# evaluate the model
_, train_acc = saved_model.evaluate(X_train, Y_train, verbose=0)
_, test_acc = saved_model.evaluate(X_test, Y_test, verbose=0)
print('Train: %.3f, Test: %.3f' % (train_acc, test_acc))
# Out:
# Epoch 1/8
# 506/506 [==============================] - ETA: 0s - loss: 0.4738 - acc: 0.7583
# Epoch 1: val_acc improved from -inf to 0.78719, saving model to best_model.h5
# 506/506 [==============================] - 142s 274ms/step - loss: 0.4738 - acc: 0.7583 - val_loss: 0.4289 - val_acc: 0.7872
# Epoch 2/8
# 506/506 [==============================] - ETA: 0s - loss: 0.3627 - acc: 0.8294
# Epoch 2: val_acc improved from 0.78719 to 0.84024, saving model to best_model.h5
# 506/506 [==============================] - 138s 272ms/step - loss: 0.3627 - acc: 0.8294 - val_loss: 0.3417 - val_acc: 0.8402
# Epoch 3/8
# 506/506 [==============================] - ETA: 0s - loss: 0.3060 - acc: 0.8618
# Epoch 3: val_acc improved from 0.84024 to 0.86336, saving model to best_model.h5
# 506/506 [==============================] - 137s 271ms/step - loss: 0.3060 - acc: 0.8618 - val_loss: 0.2984 - val_acc: 0.8634
# Epoch 4/8
# 506/506 [==============================] - ETA: 0s - loss: 0.2759 - acc: 0.8771
# Epoch 4: val_acc improved from 0.86336 to 0.87251, saving model to best_model.h5
# 506/506 [==============================] - 142s 280ms/step - loss: 0.2759 - acc: 0.8771 - val_loss: 0.2865 - val_acc: 0.8725
# Epoch 5/8
# 506/506 [==============================] - ETA: 0s - loss: 0.2509 - acc: 0.8896
# Epoch 5: val_acc improved from 0.87251 to 0.87795, saving model to best_model.h5
# 506/506 [==============================] - 139s 275ms/step - loss: 0.2509 - acc: 0.8896 - val_loss: 0.2712 - val_acc: 0.8780
# Epoch 6/8
# 506/506 [==============================] - ETA: 0s - loss: 0.2291 - acc: 0.9009
# Epoch 6: val_acc did not improve from 0.87795
# 506/506 [==============================] - 140s 277ms/step - loss: 0.2291 - acc: 0.9009 - val_loss: 0.2769 - val_acc: 0.8762
# Epoch 7/8
# 506/506 [==============================] - ETA: 0s - loss: 0.2087 - acc: 0.9121
# Epoch 7: val_acc improved from 0.87795 to 0.89118, saving model to best_model.h5
# 506/506 [==============================] - 138s 272ms/step - loss: 0.2087 - acc: 0.9121 - val_loss: 0.2498 - val_acc: 0.8912
# Epoch 8/8
# 506/506 [==============================] - ETA: 0s - loss: 0.1960 - acc: 0.9178
# Epoch 8: val_acc did not improve from 0.89118
# 506/506 [==============================] - 140s 278ms/step - loss: 0.1960 - acc: 0.9178 - val_loss: 0.2534 - val_acc: 0.8897
# Train: 0.926, Test: 0.891
# CPU times: user 33min 11s, sys: 2min 15s, total: 35min 26s
# Wall time: 19min 24s

# %%
def plot_loss_epochs(history):
    epochs = np.arange(1,len(history.history['acc']) + 1,1)
    train_acc = history.history['acc']
    train_loss = history.history['loss']
    val_acc = history.history['val_acc']
    val_loss = history.history['val_loss']

    fig , ax = plt.subplots(1,2, figsize=(7,3))
    ax[0].plot(epochs , train_acc , '.-' , label = 'Train Accuracy')
    ax[0].plot(epochs , val_acc , '.-' , label = 'Validation Accuracy')
    ax[0].set_title('Train & Validation Accuracy')
    ax[0].legend()
    ax[0].set_xlabel("Epochs")
    ax[0].set_ylabel("Accuracy")

    ax[1].plot(epochs , train_loss , '.-' , label = 'Train Loss')
    ax[1].plot(epochs , val_loss , '.-' , label = 'Validation Loss')
    ax[1].set_title('Train & Validation Loss')
    ax[1].legend()
    ax[1].set_xlabel("Epochs")
    ax[1].set_ylabel("Loss")
    fig.tight_layout()
    fig.show()
plot_loss_epochs(history)

# %%
import seaborn as sns
#text_test_tok = tokenizer.texts_to_sequences(xtest)
pred = (lstm_model.predict(X_test) > 0.5).astype("int32")
print("accuracy:",accuracy_score(Y_test,pred)*100)
print(classification_report(Y_test, pred, target_names = ['Fake','Not Fake'])) 
cm = pd.DataFrame(confusion_matrix(Y_test,pred))

fig , ax = plt.subplots(figsize = (2,2))
ax = sns.heatmap(cm, annot = True, xticklabels = ['Fake','True'] , yticklabels = ['Fake','True'], cbar = False, fmt='')
ax.set_xlabel("Predicted"); ax.set_ylabel("Actual"); fig.show()
# Out:
# 253/253 [==============================] - 11s 42ms/step
# accuracy: 88.96995177445282
#               precision    recall  f1-score   support
#
#         Fake       0.92      0.85      0.89      4044
#     Not Fake       0.86      0.93      0.89      4043
#
#     accuracy                           0.89      8087
#    macro avg       0.89      0.89      0.89      8087
# weighted avg       0.89      0.89      0.89      8087

# %% [markdown]
# ##GRU with Glove Embeddings

# %%
gru_model = Sequential()
gru_model.add(Embedding(vocab_size, EMBEDDING_DIM, trainable = False, weights=[word_vector_matrix]))
#gru_model.add(Dropout(0.2))
gru_model.add(Bidirectional(GRU(64)))
#gru_model.add(Dense(64, activation='relu'))
gru_model.add(Dropout(0.2))
gru_model.add(Dense(1, activation = 'sigmoid'))
gru_model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['acc'])
print(gru_model.summary())
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_5 (Embedding)     (None, None, 100)         4817800
#
#  bidirectional_5 (Bidirectio  (None, 128)              63744
#  nal)
#
#  dropout_5 (Dropout)         (None, 128)               0
#
#  dense_5 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 4,881,673
# Trainable params: 63,873
# Non-trainable params: 4,817,800
# _________________________________________________________________
# None

# %%
# %%time
from keras.callbacks import ReduceLROnPlateau
#reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, min_lr=1e-6, verbose=1)
early_stop = EarlyStopping(monitor='val_loss', min_delta=0, patience=1, mode='auto')
mc = ModelCheckpoint('best_model.h5', monitor='val_acc', mode='max', verbose=1, save_best_only=True)
batch_size = 64
epochs  = 8
history = gru_model.fit(X_train,Y_train,validation_data=(X_test,Y_test), batch_size = batch_size, epochs = epochs,callbacks=[early_stop,mc])
saved_model = load_model('best_model.h5')
# evaluate the model
_, train_acc = saved_model.evaluate(X_train, Y_train, verbose=0)
_, test_acc = saved_model.evaluate(X_test, Y_test, verbose=0)
print('Train: %.3f, Test: %.3f' % (train_acc, test_acc))
# Out:
# Epoch 1/8
# 506/506 [==============================] - ETA: 0s - loss: 0.4847 - acc: 0.7493
# Epoch 1: val_acc improved from -inf to 0.81959, saving model to best_model.h5
# 506/506 [==============================] - 108s 206ms/step - loss: 0.4847 - acc: 0.7493 - val_loss: 0.3885 - val_acc: 0.8196
# Epoch 2/8
# 506/506 [==============================] - ETA: 0s - loss: 0.3519 - acc: 0.8374
# Epoch 2: val_acc improved from 0.81959 to 0.85174, saving model to best_model.h5
# 506/506 [==============================] - 99s 196ms/step - loss: 0.3519 - acc: 0.8374 - val_loss: 0.3263 - val_acc: 0.8517
# Epoch 3/8
# 506/506 [==============================] - ETA: 0s - loss: 0.2954 - acc: 0.8683
# Epoch 3: val_acc improved from 0.85174 to 0.86386, saving model to best_model.h5
# 506/506 [==============================] - 99s 196ms/step - loss: 0.2954 - acc: 0.8683 - val_loss: 0.3087 - val_acc: 0.8639
# Epoch 4/8
# 506/506 [==============================] - ETA: 0s - loss: 0.2575 - acc: 0.8860
# Epoch 4: val_acc improved from 0.86386 to 0.88253, saving model to best_model.h5
# 506/506 [==============================] - 99s 196ms/step - loss: 0.2575 - acc: 0.8860 - val_loss: 0.2633 - val_acc: 0.8825
# Epoch 5/8
# 506/506 [==============================] - ETA: 0s - loss: 0.2301 - acc: 0.8989
# Epoch 5: val_acc improved from 0.88253 to 0.88920, saving model to best_model.h5
# 506/506 [==============================] - 100s 197ms/step - loss: 0.2301 - acc: 0.8989 - val_loss: 0.2463 - val_acc: 0.8892
# Epoch 6/8
# 506/506 [==============================] - ETA: 0s - loss: 0.2028 - acc: 0.9117
# Epoch 6: val_acc did not improve from 0.88920
# 506/506 [==============================] - 99s 196ms/step - loss: 0.2028 - acc: 0.9117 - val_loss: 0.2551 - val_acc: 0.8864
# Train: 0.921, Test: 0.889
# CPU times: user 18min 53s, sys: 31.3 s, total: 19min 25s
# Wall time: 11min 6s

# %%
def plot_loss_epochs(history):
    epochs = np.arange(1,len(history.history['acc']) + 1,1)
    train_acc = history.history['acc']
    train_loss = history.history['loss']
    val_acc = history.history['val_acc']
    val_loss = history.history['val_loss']

    fig , ax = plt.subplots(1,2, figsize=(7,3))
    ax[0].plot(epochs , train_acc , '.-' , label = 'Train Accuracy')
    ax[0].plot(epochs , val_acc , '.-' , label = 'Validation Accuracy')
    ax[0].set_title('Train & Validation Accuracy')
    ax[0].legend()
    ax[0].set_xlabel("Epochs")
    ax[0].set_ylabel("Accuracy")

    ax[1].plot(epochs , train_loss , '.-' , label = 'Train Loss')
    ax[1].plot(epochs , val_loss , '.-' , label = 'Validation Loss')
    ax[1].set_title('Train & Validation Loss')
    ax[1].legend()
    ax[1].set_xlabel("Epochs")
    ax[1].set_ylabel("Loss")
    fig.tight_layout()
    fig.show()
plot_loss_epochs(history)

# %%
import seaborn as sns
#text_test_tok = tokenizer.texts_to_sequences(xtest)
pred = (gru_model.predict(X_test) >0.5).astype("int32")
print("accuracy:",accuracy_score(Y_test,pred)*100)
print(classification_report(Y_test, pred, target_names = ['Fake','Not Fake'])) 
cm = pd.DataFrame(confusion_matrix(Y_test,pred))

fig , ax = plt.subplots(figsize = (2,2))
ax = sns.heatmap(cm, annot = True, xticklabels = ['Fake','True'] , yticklabels = ['Fake','True'], cbar = False, fmt='')
ax.set_xlabel("Predicted"); ax.set_ylabel("Actual"); fig.show()
# Out:
# 253/253 [==============================] - 9s 34ms/step
# accuracy: 88.63608260170645
#               precision    recall  f1-score   support
#
#         Fake       0.92      0.84      0.88      4044
#     Not Fake       0.86      0.93      0.89      4043
#
#     accuracy                           0.89      8087
#    macro avg       0.89      0.89      0.89      8087
# weighted avg       0.89      0.89      0.89      8087
